# %% [markdown]
# # Modelo de NLP para Reconhecimento de Entidades em Documentos Jurídicos

# %% [markdown]
# A solução que criei é capaz de identificar automaticamente informações críticas, como nomes das partes envolvidas, datas relevantes e dispositivos legais citados, em contratos, petições e jurisprudências. O projeto simula um cenário real, no qual uma grande empresa de advocacia precisava de uma forma eficiente de extrair dados importantes de um volume significativo de textos legais. Com essa solução, demonstrei como a IA pode ser aplicada para agilizar a análise de documentos, reduzir erros manuais e melhorar a gestão de processos no setor jurídico.
#
# Além do desenvolvimento do algoritmo de machine learning, foi criada uma aplicação interativa para visualizar os resultados do modelo de reconhecimento de entidades nomeadas. Essa aplicação permite que os usuários insiram textos ou carreguem arquivos para análise, proporcionando uma interface intuitiva para explorar as entidades extraídas pelo modelo.

# %% [markdown]
# # Leitura dos textos

# %%
import zipfile

# %%
with zipfile.ZipFile('/content/texts.zip', 'r') as zip:
    print(zip.namelist())

# %%
with zipfile.ZipFile('/content/texts.zip', 'r') as zip:
    print(*zip.namelist(), sep = '\n')
# Out:
# ADI2TJDFT.txt
# adi3767.txt
# Ag10000170733596001.txt
# Ag10105170208398001.txt
# AgAIRR11889820145030011.txt
# AgCr10582160008758001.txt
# AgRgSTJ1.txt
# AgRgSTJ2.txt
# AgRgTSE1.txt
# AgRgTSE3.txt
# AIAgRAgI6193ARAGUARIMG.txt
# airr801422012.txt
# AIRR3999520145020086.txt
# AIRR15708820115050222.txt
# AP00000794920137060006.txt
# AP00001415620157010201.txt
# AP00001441420167030203.txt
# AP771420167080008PA.txt
# CP32320177080008PA.txt
# DespSEPLAGDF.txt
# ED1STM.txt
# ED1TJAC.txt
# EDAgRgTSE2.txt
# EDEDARR208420135040232.txt
# EDRR1TST.txt
# EEDRR9715120105020002.txt
# ERR731004520105130003.txt
# HC110260SP.txt
# HC151914AgRES.txt
# HC340624SP.txt
# HC418951PR.txt
# HC70000845920187000000.txt
# lei11340.txt
# Lei11788.txt
# LoaDF2018.txt
# Pet128TSE5.txt
# Port77DF.txt
# Rcl3495STJ.txt
# REE5908TSE4.txt
# REsp1583083RS.txt
# RR474820145230056.txt
# RR942006420095040028.txt
# RR2574407120025020372.txt
# TCU4687.txt
# TSTRR16037920105200001.txt
# AC1TCU.txt
# AC1TJAC.txt
# AC1TJMG.txt
# AC2.txt
# ACORDAOTCU25052016.txt

# %%
with zipfile.ZipFile('/content/texts.zip', 'r') as zip:
    with zip.open('ADI2TJDFT.txt') as arquivo:
        texto = arquivo.read().decode('utf-8')

# %%
# print(texto)

# %% [markdown]
# **Reconhecendo as entidades no texto**

# %% [markdown]
# > Para fazer o reconhecimento das entidades nos textos, usarei a biblioteca `SpaCy`, na qual me permite utilizar modelos já treinados e personalizá-los para atender ao problema específico.

# %%
# !pip install -U spacy

# %%
# !python -m spacy download pt_core_news_sm

# %%
import spacy
import pt_core_news_sm

modelo_ner = pt_core_news_sm.load()

# %%
doc = modelo_ner(texto)

for entidade in doc.ents:
    print(f'{entidade.text} -> {entidade.label_}')
# Out:
# Órgão -> LOC
# Conselho Especial
# Classe -> ORG
# DISTRITO FEDERAL E TERRITÓRIOS
# Requerido(s -> LOC
# DA CÂMARA -> ORG
# DISTRITO FEDERAL E OUTRO(S)
# Relator -> LOC
# LEIS DISTRITAIS -> MISC
# COMPLEMENTAR DISTRITAL -> MISC
# FORMAL -> ORG
# LEI ORGÂNICA -> MISC
# DISTRITO FEDERAL -> LOC
# ÁREA PÚBLICA -> LOC
# DO GOVERNADOR -> MISC
# DISTRITO FEDERAL -> LOC
# VÍCIO FORMAL -> ORG
# Decreto n.º 10.829/87 -> MISC
# Portaria n.º 314/92 -> ORG
# Instituto Brasileiro do Patrimônio Cultural  IBPC -> LOC
# Instituto do Patrimônio Histórico e Artístico Nacional  IPHAN -> LOC
# Governador do Distrito Federal -> LOC
# Distrito Federal -> LOC
# ACÓRDÃO -> ORG
# Acordam os Desembargadores do Conselho Especial do Tribunal de Justiça do Distrito Federal -> MISC
# Territórios LÉCIO RESENDE  Relator -> ORG
# JOÃO MAIORISI -> PER
# Vogal -> ORG
# VIEIRA  Vogal -> LOC
# SÉRGIO BITTENCOURT  Vogal -> ORG
# LECIR MANOEL DA LUZ -> ORG
# Vogal -> LOC
# CARMELITA BRASIL -> ORG
# Vogal -> LOC
# WALDIR LEÔNCIO -> PER
# J.J. COSTA CARVALHO -> PER
# Vogal -> LOC
# HUMBERTO -> LOC
# Vogal -> LOC
# NÍDIA CORRÊA LIMA  Vogal -> ORG
# CRUZ -> LOC
# Vogal -> LOC
# ROBERBAL CASEMIRO BELINATI -> MISC
# Vogal -> LOC
# SILVÂNIO -> ORG
# Vogal -> ORG
# OTÁVIO AUGUSTO  Vogal -> LOC
# Desembargador OTÁVIO AUGUSTO -> MISC
# JULGOU-SE PROCEDENTE -> PER
# MAIORIA -> MISC
# Brasília -> LOC
# DF -> LOC
# Des -> MISC
# LÉCIO -> MISC
# DISTRITO FEDERAL E TERRITÓRIOS propõe Ação Direta de Inconstitucionalidade -> LOC
# Leis distritais n.º 747 -> MISC
# Lei Complementar -> MISC
# Região Administrativa do Paranoá  RA VII -> LOC
# XI -> LOC
# XXI -> LOC
# Lei Orgânica do Distrito Federal  LODF -> MISC
# Narra -> LOC
# Chefe do Poder Executivo -> MISC
# Poder Legislativo -> PER
# Requer -> PER
# Leis distritais n.º 747/1994 -> MISC
# Lei Complementar distrital n.º 380/2001 -> MISC
# fls -> MISC
# Presidente da Câmara Legislativa do Distrito Federal -> MISC
# fls -> MISC
# Governador do Distrito Federal -> LOC
# Sustenta -> LOC
# Câmara distrital -> LOC
# LODF -> ORG
# Governador do Distrito Federal -> LOC
# fls -> MISC
# Procurador-Geral -> LOC
# Distrito Federal -> LOC
# fls -> MISC
# Parecer Ministerial de fls -> MISC
# Relatório -> LOC
# O Senhor Desembargador LÉCIO RESENDE   -> MISC
# DISTRITO FEDERAL E TERRITÓRIOS propõe Ação Direta de Inconstitucionalidade -> LOC
# Leis distritais n.º 747 -> MISC
# Lei Complementar -> MISC
# Região Administrativa do Paranoá  RA VII -> LOC
# Chefe do Poder Executivo -> MISC
# Poder Legislativo -> PER
# XI -> LOC
# XXI -> LOC
# Lei Orgânica do Distrito Federal  LODF -> MISC
# Requer -> PER
# Lei Orgânica do Distrito Federal -> MISC
# Ação Direta -> PER
# Carta Magna -> LOC
# Ação Direta de Inconstitucionalidade -> MISC
# I -> MISC
# Carta Magna -> LOC
# Constituição Federal -> ORG
# Estados -> LOC
# Constituição -> ORG
# Estados -> LOC
# Constituição -> ORG
# Distrito Federal -> LOC
# Lei Orgânica -> MISC
# Distrito Federal -> LOC
# Federação brasileira -> LOC
# Ministro CELSO DE MELLO -> PER
# ADI -> ORG
# A Lei Orgânica do Distrito Federal -> MISC
# Federação brasileira -> LOC
# Distrito Federal -> LOC
# A Lei Orgânica -> MISC
# Constituições -> LOC
# DJU de 13 -> MISC
# Lei Orgânica do Distrito Federal -> MISC
# Estados-membros -> MISC
# Supremo Tribunal Federal -> LOC
# ADI -> ORG
# DF -> LOC
# Tribunal de Justiça do Distrito Federal -> ORG
# Territórios -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Ação Direta de Inconstitucionalidade -> MISC
# Ação Declaratória de Constitucionalidade -> ORG
# Tribunal de Justiça do Distrito Federal -> ORG
# Territórios -> LOC
# Carta Magna -> ORG
# III -> LOC
# Regimento Interno -> MISC
# Tribunal de Justiça -> ORG
# Procurador-Geral de Justiça do Distrito Federal e Territórios -> LOC
# Ação Direta de Inconstitucionalidade -> MISC
# Admito -> MISC
# Excelentíssima Senhora PROCURADORA-GERAL DE JUSTIÇA DO -> MISC
# DISTRITO FEDERAL E TERRITÓRIOS -> LOC
# Leis distritais -> MISC
# Nº 747 -> MISC
# Autor do Projeto -> MISC
# Deputado Salviano Guimarães -> PER
# Promulgação -> MISC
# Sr. -> LOC
# Distrito Federal -> LOC
# Projeto de Lei -> MISC
# Autoriza o Poder Executivo -> PER
# Zona de Expansão Urbana do Paranoá  7 ZEU -> LOC
# Câmara Legislativa do Distrito Federal -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Lei nº 747 -> MISC
# Art. 1º Fica o Poder Executivo -> MISC
# Zona de Expansão Urbana 1 -> LOC
# Paranoá  7 ZEU -> MISC
# Lei nº 353 -> MISC
# Vila Paranoá -> LOC
# Programa de Assentamento da População de Baixa Renda -> MISC
# O Poder Executivo -> MISC
# Decreto nº 11.208 -> MISC
# Associação de Moradores do Paranoá -> ORG
# Zona de Expansão Urbana 1 -> LOC
# Paranoá  7 ZEU -> MISC
# Área de Proteção Ambiental -> ORG
# Lago Paranoá -> LOC
# Poder Executivo -> PER
# Lei -> MISC
# Art. 5º -> MISC
# Nº -> MISC
# Autoria do Projeto -> MISC
# Deputado José Edmar -> PER
# Destina -> PER
# Complexo Vivencial -> LOC
# Esportivo do Paranoá -> LOC
# Região Administrativa do Paranoá  RA VII -> LOC
# Câmara Legislativa do Distrito Federal -> LOC
# Governador do Distrito Federal -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Presidente da Câmara Legislativa do Distrito Federal -> LOC
# Lei:
# Art. 1º -> MISC
# Complexo Vivencial -> LOC
# Esportivo do Paranoá -> LOC
# Região Administrativa do Paranoá  RA VII -> LOC
# Quadras 3 -> MISC
# DF -> LOC
# DF -> LOC
# IV -> MISC
# Região Administrativa do Paranoá -> LOC
# O Complexo Vivencial -> MISC
# Esportivo do Paranoá -> LOC
# Local do Paranoá -> LOC
# Plano Diretor de Ordenamento Territorial do Distrito Federal  PDOT -> MISC
# Art. 4º -> MISC
# Nº 380 -> MISC
# Autoria do Projeto -> MISC
# Deputado César Lacerda -> PER
# Região Administrativa do Paranoá  RA VII -> LOC
# Presidente da Câmara Legislativa do Distrito Federal -> MISC
# Lei Orgânica do Distrito Federal -> MISC
# Lei Complementar -> PER
# Projeto -> MISC
# Governador do Distrito Federal -> LOC
# Câmara Legislativa do Distrito Federal -> LOC
# Região Administrativa do Paranoá  RA VII -> LOC
# DF-001 -> LOC
# Estrada Parque Contorno  EPCT -> LOC
# Região Administrativa do Paranoá  RA VII -> LOC
# Rodovia DF-001 -> LOC
# EPCT -> MISC
# Anexo II da Lei Complementar -> LOC
# Art. 2º Fica -> MISC
# Norma de Edificação -> MISC
# Uso -> LOC
# Gabarito  NGB -> LOC
# Lei Complementar -> PER
# Região Administrativa do Paranoá  RA VII -> LOC
# O Poder Executivo -> MISC
# Lei Complementar -> PER
# Art. 5º -> MISC
# Lei Complementar -> PER
# Lei Orgânica do Distrito Federal -> MISC
# Distrito Federal -> LOC
# XI -> LOC
# Brasília -> LOC
# Livro do Tombo Histórico -> MISC
# Decreto n.º 10.829, de 2 de outubro de 1987 -> MISC
# Portaria n.º 314 -> ORG
# Instituto Brasileiro do Patrimônio Cultural -> LOC
# Instituto do Patrimônio Histórico e Artístico Nacional -> LOC
# Inciso -> PER
# Emenda a Lei Orgânica n.º 12 -> MISC
#  DODF -> MISC
# Poder Executivo -> MISC
# Distrito Federal -> LOC
# Câmara Legislativa -> LOC
# Governador do Distrito Federal -> LOC
# Lei Orgânica -> MISC
# XXI -> LOC
# Poder Executivo conduzir -> MISC
# Distrito Federal -> LOC
# grifo nosso -> MISC
# Deputados Distritais -> PER
# fls -> MISC
# Poder Legislativo -> PER
# Distrito Federal -> LOC
# Chefe do Poder Executivo -> MISC
# Corte -> LOC
# Governador do Distrito Federal -> LOC
# Distrito Federal -> LOC
# DIRETA DE INCONSTITUCIONALIDADE -> MISC
# AUTORIA PARLAMENTAR -> LOC
# COLIDÊNCIA -> ORG
# A LEI ORGÂNICA -> MISC
# DISTRITO FEDERAL -> LOC
# RESERVA DE INICIATIVA -> ORG
# VÍCIO -> ORG
# FORMAL DE INCONSTITUCIONALIDADE -> MISC
# DO GOVERNADOR -> MISC
# DISTRITO FEDERAL PARA A PROPOSITURA DE LEIS -> LOC
# ÂMBITO -> MISC
# Tribunal de Justiça -> ORG
# Poder Legislativo -> PER
# Distrito Federal -> LOC
# Governador do Distrito Federal -> LOC
# XI -> LOC
# inciso VI -> PER
# Lei Orgânica do Distrito Federal -> MISC
# Lei Complementar -> PER
# Câmara Legislativa do Distrito Federal -> LOC
# Lei Complementar Distrital -> MISC
# ADI 2010002007992-9 -> MISC
# Conselho Especial -> ORG
# Relator Desembargador NATANAEL CAETANO -> MISC
# DJ-e de 17/11/2010 -> MISC
# AÇÃO DIRETA DE INCONSTITUCIONALIDADE -> MISC
# LEIS COMPLEMENTARES DISTRITAIS -> MISC
# 569/02 -> LOC
# USO -> ORG
# OCUPAÇÃO -> MISC
# DEPUTADOS DISTRITAIS -> MISC
# FORMAL -> ORG
# INAPLICABILIDADE -> LOC
# Distrito Federal -> LOC
# Governador -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Lei nº 9.868/99 -> MISC
# ADI 2010002002050-8 -> MISC
# Conselho Especial -> ORG
# DJ-e de 17/11/2010 -> MISC
# ADMINISTRATIVO -> ORG
# DIRETA DE INCONSTITUCIONALIDADE -> MISC
# COMPLEMENTAR DISTRITAL -> MISC
# Nº 788 -> MISC
# DESAFETAÇÃO DE ÁREAS -> MISC
# RA IV -> MISC
# FORMAL -> ORG
# EMENDA PARLAMENTAR -> PER
# OFENSA -> ORG
# À LEI ORGÂNICA -> MISC
# DISTRITO FEDERAL E AOS -> LOC
# ADMINISTRATIVOS -> ORG
# Lei Complementar -> LOC
# Brazlândia-DF  Região Administrativa IV -> LOC
# Distrito Federal -> LOC
# Chefe do Poder Executivo -> MISC
# Corte -> LOC
# ADI 2009002013564-6 -> MISC
# Conselho Especial -> ORG
# Relator Desembargador CRUZ -> PER
# DJ-e -> MISC
# Distrito Federal -> LOC
# Decreto n.º 10.829/1987 -> MISC
# Portaria n.º 314/1992 -> ORG
# Instituto Brasileiro do Patrimônio Histórico e Artístico Nacional  IPHAN -> LOC
# Governador -> LOC
# Distrito Federal -> LOC
# Câmara Legislativa -> LOC
# Vejamos -> MISC
# XI -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Distrito Federal -> LOC
# XI -> LOC
# Brasília -> LOC
# Livro do Tombo Histórico -> MISC
# Decreto -> PER
# Portaria n 314 -> ORG
# Instituto Brasileiro do Patrimônio Cultural  IBPC -> LOC
# Instituto do patrimônio Histórico e Artístico Nacional  IPHAN -> LOC
# Decreto -> MISC
# Portaria n.º 314/1992 -> ORG
# Governador do Distrito Federal -> LOC
# Distrito Federal -> LOC
# Governador do Distrito Federal -> LOC
# Distrito Federal -> LOC
# Decreto n.º 10.829/87 -> MISC
# Lei Orgânica do Distrito Federal -> MISC
# Emenda n.º 12/96 -> MISC
# VI -> LOC
# LODF -> LOC
# Governador do Distrito Federal -> LOC
# Distrito Federal -> LOC
# Decreto n.º 10.829/87 -> MISC
# Portaria n.º 314/92 -> ORG
# IPHAN -> ORG
# LODF -> ORG
# Distrito Federal -> LOC
# JULGO -> LOC
# Leis distritais n.º 747 -> MISC
# Lei Complementar -> MISC
# O Senhor Desembargador JOÃO MARIOSI -> MISC
# Vogal
# Senhor Presidente -> PER
# Constituição de 1988 -> ORG
# Distrito Federal -> LOC
# Ministro Celso de Mello -> PER
# S. -> PER
# Tribunal -> LOC
# Judiciário -> MISC
# Constituição -> ORG
# Constituição -> ORG
# “ -> MISC
# Tribunal -> LOC
# Câmara Legislativa -> LOC
# Governador do Distrito Federal -> LOC
# Supremo -> LOC
# Tribunal? -> ORG
# Evidentemente -> MISC
# Lei Orgânica do Distrito Federal -> MISC
# Constituições Estaduais -> LOC
# Constituições Estaduais -> LOC
# Estados -> LOC
# Federação -> LOC
# Distrito Federal -> LOC
# Judiciário -> PER
# Ministério Público -> ORG
# Ministério Público -> ORG
# Distrito Federal -> LOC
# Tribunal de Contas -> ORG
# Digo -> LOC
# Vencido -> MISC
# O Senhor Desembargador ROMÃO -> MISC
# Desembargador João Mariosi -> PER
# Relator -> MISC
# O Senhor Desembargador DÁCIO VIEIRA  Vogal
#  -> MISC
# Ação Direta de Inconstitucionalidade -> MISC
# Procuradora-Geral de Justiça do Distrito Federal e Territórios -> ORG
# Leis Distritais -> MISC
# Lei Complementar -> PER
# Região Administrativa do Paranoá  RA VII -> LOC
# XI -> LOC
# XXI -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Sustenta -> PER
# “ -> MISC
# “ -> MISC
# Deputados Distritais -> PER
# Governador do Distrito Federal -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Órgão Especial -> LOC
# Distrito Federal -> LOC
# Governador do Distrito Federal -> LOC
# ”(Conselho Especial -> MISC
# ADI -> ORG
# Rel -> PER
# Des -> PER
# Romão C. Oliveira -> PER
# Reg -> PER
# Ac -> MISC
# DIRETA DE INCONSTITUCIONALIDADE -> MISC
# LEIS COMPLEMENTARES DISTRITAIS -> MISC
# Nº 660 -> MISC
# CEILÂNDIA -> ORG
# BRASÍLIA -> MISC
# OCUPAÇÃO -> ORG
# DISTRITO FEDERAL -> LOC
# ALEGAÇÃO DE INCONSTITUCIONALIDADE -> MISC
# À LEI ORGÂNICA -> MISC
# DISTRITO FEDERAL -> LOC
# PROCEDÊNCIA -> ORG
# Procedência -> PER
# Lei Orgânica do Distrito Federal -> MISC
# Decreto nº 10.829/1987 -> MISC
# XI -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Chefe do Poder Executivo -> MISC
# Relator MARIO MACHADO -> MISC
# Conselho Especial -> ORG
# DJ -> ORG
# AÇÃO DIRETA DE INCONSTITUCIONALIDADE -> MISC
# Nº -> MISC
# FORMAL -> ORG
# DO GOVERNADOR -> MISC
# DISTRITO FEDERAL -> LOC
# SOBRE OCUPAÇÃO -> ORG
# SOLO -> MISC
# Excelentíssimo -> LOC
# Governador do Distrito Federal -> LOC
# Distrito Federal -> LOC
# Conselho Especial -> ORG
# ADI -> ORG
# Rel -> ORG
# Des -> PER
# Lécio Resende -> PER
# Reg -> PER
# Ac -> MISC
# AÇÃO DIRETA DE INCONSTITUCIONALIDADE -> MISC
# Nº -> MISC
# PRELIMINAR DE INÉPCIA -> MISC
# INICIAL REJEITADA -> MISC
# MÉRITO: ADMINISTRAÇÃO DE ÁREAS PÚBLICAS -> MISC
# SOBRE OCUPAÇÃO -> ORG
# SOLO -> ORG
# VÍCIO -> MISC
# DISTRITO FEDERAL -> LOC
# Relator DÁCIO VIEIRA -> PER
# Conselho Especial -> ORG
# DJ -> ORG
# Destarte -> LOC
# Leis -> LOC
# Governador -> LOC
# Feitas -> PER
# Leis -> PER
# O Senhor Desembargador SÉRGIO BITTENCOURT  Vogal
# Senhor Presidente -> MISC
# Desembargador João Mariosi -> PER
# Conselho -> LOC
# Ação Direta de Inconstitucionalidade -> MISC
# Governador do Distrito Federal -> LOC
# Leis Distritais -> MISC
# Lei Complementar Distrital -> MISC
# Deputados Distritais -> PER
# Aduz -> LOC
# XI -> LOC
# XXI -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Leis Distritais -> PER
# Presidente da Câmara Legislativa -> MISC
# fls -> MISC
# Governador do Distrito Federal -> LOC
# Procurador-Geral -> LOC
# Distrito Federal -> LOC
# fls -> MISC
# Procuradoria de Justiça -> MISC
# fls -> MISC
# Leis impugnadas -> MISC
# Deputados Distritais -> PER
# Governador do Distrito Federal -> LOC
# Presidente da Câmara Legislativa -> MISC
# Diplomas -> PER
# Leis Distritais -> PER
# Nº 747 -> MISC
# Autoria do Projeto -> MISC
# Deputado Salviano Guimarães -> PER
# Promulgação -> MISC
# Sr. -> LOC
# Distrito Federal -> LOC
# Projeto de Lei -> MISC
# Autoriza o Poder Executivo -> PER
# Zona de Expansão Urbana do Paranoá  7 ZEU -> LOC
# Câmara Legislativa do Distrito Federal -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Lei nº 747 -> MISC
# Art. 1º Fica o Poder Executivo -> MISC
# Zona de Expansão Urbana 1 -> LOC
# Paranoá  7 ZEU -> MISC
# Lei nº 353 -> MISC
# Vila Paranoá -> LOC
# Programa de Assentamento da População de Baixa Renda -> MISC
# O Poder Executivo -> MISC
# Decreto nº 11.208 -> MISC
# Associação de Moradores do Paranoá -> ORG
# Zona de Expansão Urbana 1 -> LOC
# Paranoá  7 ZEU -> MISC
# Área de Proteção Ambiental -> ORG
# Lago Paranoá -> LOC
# Poder Executivo -> PER
# Lei -> MISC
# Art. 5º -> MISC
# grifo nosso -> MISC
# Nº -> MISC
# Autoria do Projeto -> MISC
# Deputado José Edmar -> PER
# Destina -> PER
# Complexo Vivencial -> LOC
# Esportivo do Paranoá -> LOC
# Região Administrativa do Paranoá  RA VII -> LOC
# Câmara Legislativa do Distrito Federal -> LOC
# Governador do Distrito Federal -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Presidente da Câmara Legislativa do Distrito Federal -> LOC
# Lei:
# Art. 1º -> MISC
# Complexo Vivencial -> LOC
# Esportivo do Paranoá -> LOC
# Região Administrativa do Paranoá  RA VII -> LOC
# Quadras 3 -> MISC
# DF -> LOC
# DF -> LOC
# IV -> MISC
# Região Administrativa do Paranoá -> LOC
# O Complexo Vivencial -> MISC
# Esportivo do Paranoá -> LOC
# Local do Paranoá -> LOC
# Plano Diretor de Ordenamento Territorial do Distrito Federal  PDOT -> MISC
# Art. 4º -> MISC
# Nº 380 -> MISC
# Autoria do Projeto -> MISC
# Deputado César Lacerda -> PER
# Região Administrativa do Paranoá  RA VII -> LOC
# Presidente da Câmara Legislativa do Distrito Federal -> MISC
# Lei Orgânica do Distrito Federal -> MISC
# Lei Complementar -> PER
# Projeto -> MISC
# Governador do Distrito Federal -> LOC
# Câmara Legislativa do Distrito Federal -> LOC
# Região Administrativa do Paranoá  RA VII -> LOC
# DF-001 -> LOC
# Estrada Parque Contorno  EPCT -> LOC
# Região Administrativa do Paranoá  RA VII -> LOC
# Rodovia DF-001 -> LOC
# EPCT -> LOC
# Anexo II da Lei Complementar -> LOC
# Art. 2º Fica -> MISC
# Norma de Edificação -> MISC
# Uso -> LOC
# Gabarito  NGB -> LOC
# Lei Complementar -> PER
# Região Administrativa do Paranoá  RA VII -> LOC
# O Poder Executivo -> MISC
# Lei Complementar -> PER
# Art. 5º -> MISC
# Lei Complementar -> PER
# grifo nosso -> MISC
# Governador do Distrito Federal -> LOC
# XI -> LOC
# XXI -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Distrito Federal -> LOC
# Omissis -> MISC
# XI -> LOC
# Brasília -> LOC
# Livro do Tombo Histórico -> MISC
# Decreto -> PER
# Portaria -> ORG
# Instituto Brasileiro do Patrimônio Cultural  IBPC -> LOC
# Instituto do Patrimônio Histórico e Artístico Nacional  IPHAN -> LOC
# Poder Executivo -> MISC
# Distrito Federal -> LOC
# Câmara Legislativa -> LOC
# Governador do Distrito Federal -> LOC
# Omissis -> MISC
# Lei Orgânica -> MISC
# Poder Executivo conduzir -> MISC
# Distrito Federal -> LOC
# Decreto nº 10.829/1987 -> MISC
# Portaria nº 314/1992 -> ORG
# Instituto Brasileiro do Patrimônio Histórico e Artístico Nacional  IPHAN -> LOC
# Governador do Distrito Federal -> LOC
# Distrito Federal -> LOC
# Governador do Distrito Federal -> LOC
# Distrito Federal -> LOC
# Normas -> LOC
# Câmara Legislativa -> LOC
# Governador do Distrito Federal -> LOC
# Eg -> MISC
# Corte -> LOC
# DIRETA DE INCONSTITUCIONALIDADE -> MISC
# Nº 1.250 -> MISC
# NOVEMBRO -> MISC
# Nº 1.319 -> MISC
# Nº 2.540 -> MISC
# NORMATIVOS LOCAIS -> MISC
# TRIBUNAL DE JUSTIÇA -> ORG
# DISTRITO FEDERAL E TERRITÓRIOS PARA PROCESSAR -> LOC
# OCUPAÇÃO -> ORG
# SOLO -> ORG
# PARLAMENTARES  INCONSTITUCIONALIDADE -> MISC
# COMPETÊNCIA -> ORG
# DO CHEFE -> MISC
# O Conselho Especial do Tribunal de Justiça do Distrito Federal e Territórios -> MISC
# Distrito Federal -> LOC
# Lei Orgânica -> MISC
# Distrito Federal -> LOC
# Governador do Distrito Federal -> LOC
# Rel -> PER
# Des -> PER
# João Mariosi -> PER
# Conselho Especial -> ORG
# DJ-e de 10.02.2010 -> MISC
# COMPLEMENTAR DISTRITAL N. -> MISC
# CONSTRUÇÃO -> ORG
# QUADRA 1 -> MISC
# SETOR -> ORG
# GRÁFICAS -> LOC
# REGIÃO ADMINISTRATIVA -> LOC
# VÍCIO FORMAL -> ORG
# VÍCIO -> ORG
# LEI ORGÂNICA -> MISC
# FEDEAL -> ORG
# A Lei Orgânica do Distrito Federal -> MISC
# XI -> LOC
# Decreto n. 10.829/87 -> MISC
# Governador do Distrito Federal -> LOC
# Distrito Federal -> LOC
# Lei Orgânica -> MISC
# Governador do Distrito Federal -> LOC
# VI -> LOC
# Lei Orgânica -> MISC
# Decreto -> MISC
# Governador -> LOC
# Distrito Federal -> LOC
# Inexiste -> LOC
# Lei Orgânica do Distrito Federal -> LOC
# Distrito Federal -> LOC
# LODF
# Julgado -> LOC
# ADI -> ORG
# Rel -> ORG
# Des -> PER
# J. J. Costa Carvalho -> PER
# Conselho Especial -> ORG
# DJ-e -> MISC
# AÇÃO DIRETA DE INCONSTITUCIONALIDADE -> MISC
# ÁREA PÚBLICA -> LOC
# VÍCIO DE INICIATIVA -> ORG
# FORMAL -> ORG
# PROCEDÊNCIA -> ORG
# EFEITOS EX TUNC -> MISC
# Governador do Distrito Federal -> LOC
# Distrito Federal -> LOC
# Lei n.º 464/1994 -> MISC
# Região Administrativa do Cruzeiro -> LOC
# Relª. Desa -> PER
# Brasil -> LOC
# Conselho Especial -> ORG
# DJ-e de 08.01.2010 -> MISC
# Leis Distritais -> MISC
# Lei Complementar Distrital -> MISC
# O Senhor Desembargador LECIR MANOEL DA LUZ -> MISC
# Vogal -> LOC
# Desembargador Romão C. Oliveira -> PER
# Desembargador -> PER
# Relator -> MISC
# A Senhora Desembargadora CARMELITA BRASIL -> MISC
# Vogal
# Acompanho -> PER
# Relator -> MISC
# O Senhor Desembargador WALDIR LEÔNCIO JÚNIOR  Vogal
#  -> MISC
# Relator -> MISC
# O Senhor Desembargador J. J. COSTA CARVALHO -> MISC
# Vogal
# Senhor Presidente -> PER
# Relator -> MISC
# Desembargador João Mariosi -> PER
# O Senhor Desembargador HUMBERTO ADJUTO ULHÔA -> MISC
# Relator -> MISC
# A Senhora Desembargadora NÍDIA -> MISC
# Desembargador João Mariosi -> PER
# Relator -> MISC
# O Senhor Desembargador CRUZ MACEDO -> MISC
# Vogal
# Acompanho -> PER
# Relator -> MISC
# vênia -> LOC
# A Senhora Desembargadora ANA -> MISC
# Vogal -> LOC
# Relator -> MISC
# O Senhor Desembargador ROBERVAL -> MISC
# BELINATI -> MISC
# Vogal
# Acompanho -> PER
# Relator -> MISC
# vênia -> LOC
# O Senhor Desembargador SILVÂNIO -> MISC
# Vogal -> ORG
# Relator -> MISC
# O Senhor Desembargador OTÁVIO AUGUSTO  Presidente -> MISC
# Vogal
#  -> LOC
# Procuradora-Geral de Justiça do Distrito Federal e Territórios -> ORG
# Leis Distritais -> MISC
# Lei Complementar -> PER
# XI -> LOC
# XXI -> LOC
# Lei Orgânica -> MISC
# DF -> LOC
# Lei Orgânica -> MISC
# XI -> LOC
# inciso VI -> PER
# XXI -> LOC
# Chefe do Poder Executivo -> MISC
# Entende -> PER
# DF -> LOC
# Requer -> MISC
# Deputados Distritais -> PER
# Poder Legislativo -> PER
# Distrito Federal -> LOC
# Governador do Distrito Federal -> LOC
# inciso VI -> PER
# Lei Orgânica do Distrito Federal -> MISC
# Poder Executivo -> MISC
# Distrito Federal -> LOC
# Câmara Legislativa -> LOC
# Governador do Distrito Federal -> LOC
# Lei Orgânica -> MISC
# Poder Executivo conduzir -> MISC
# Distrito Federal -> LOC
# g.n. -> LOC
# DF -> LOC
# Distrito Federal -> LOC
# Poder Executivo -> MISC
# Decreto n. 10.829/87 -> MISC
# XI -> LOC
# LODF -> ORG
# Governador do Distrito Federal -> LOC
# Distrito Federal -> LOC
# VI -> LOC
# Lei Orgânica -> MISC
# Governador do Distrito Federal -> LOC
# VI -> LOC
# Lei Orgânica -> MISC
# Decreto -> MISC
# Governador do Distrito Federal -> LOC
# Conselho -> ORG
# DIRETA DE INCONSTITUCIONALIDADE -> MISC
# LEIS COMPLEMENTARES DISTRITAIS -> MISC
# Nº 660 -> MISC
# CEILÂNDIA -> ORG
# BRASÍLIA -> MISC
# OCUPAÇÃO -> ORG
# DISTRITO FEDERAL -> LOC
# ALEGAÇÃO DE INCONSTITUCIONALIDADE -> MISC
# À LEI ORGÂNICA -> MISC
# DISTRITO FEDERAL -> LOC
# PROCEDÊNCIA -> ORG
# Procedência -> PER
# Lei Orgânica do Distrito Federal -> MISC
# Decreto nº 10.829/1987 -> MISC
# XI -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Chefe do Poder Executivo -> MISC
# Leis Complementares -> MISC
# Relator MARIO MACHADO -> MISC
# Conselho Especial -> ORG
# DJ -> ORG
# g.n. -> LOC
# AÇÃO DIRETA DE INCONSTITUCIONALIDADE -> MISC
# Nº 683 -> MISC
# IMPLANTAÇÃO DO SETOR -> MISC
# CATETINHO -> MISC
# À LEI ORGÂNICA -> MISC
# DISTRITO FEDERAL -> LOC
# COMPROMETIDA -> ORG
# VÍCIO FORMAL -> ORG
# PROCEDÊNCIA -> ORG
# Distrito Federal -> LOC
# Lei Orgânica do Distrito Federal -> MISC
# Chefe do Poder Executivo -> MISC
# Distrito Federal -> LOC
# Procedência -> PER
# Lei Distrital nº 683 -> MISC
# Setor Habitacional Catetinho -> MISC
# Relator HUMBERTO -> MISC
# ULHÔA -> ORG
# Conselho Especial -> ORG
# DJ -> ORG
# g.n. -> LOC
# AÇÃO DIRETA DE INCONSTITUCIONALIDADE -> MISC
# LEI DISTRITAL -> MISC
# NORMA -> MISC
# DISPÕE SOBRE -> ORG
# PARÂMETROS DE OCUPAÇÃO DE ÁREAS SITUADAS NO -> LOC
# VÍCIO DE INICIATIVA -> LOC
# DO GOVERNADOR -> MISC
# DISTRITO FEDERAL -> LOC
# FORMAL -> ORG
# OFENSA -> ORG
# INCISO VI -> PER
# LEI ORGÂNICA -> MISC
# DISTRITO FEDERAL -> LOC
# Lei de autoria -> MISC
# Distrito Federal -> LOC
# Chefe do Poder Executivo -> MISC
# Relator OTÁVIO AUGUSTO -> PER
# Conselho Especial -> ORG
# DJ -> ORG
# g.n. -> LOC
# LEIS COMPLEMENTARES DISTRITAIS -> MISC
# FORMAL -> ORG
# MATERIAL -> ORG
# OCORRÊNCIA -> ORG
# PROCEDÊNCIA -> ORG
# A INCONSTITUCIONALIDADE DAS LEIS -> MISC
# EFEITOS EX TUNCE -> MISC
# EFICÁCIA -> MISC
# LODF -> ORG
# Governador do Distrito Federal -> LOC
# Distrito Federal -> LOC
# LODF -> ORG
# LODF -> ORG
# Ação Direta de Inconstitucionalidade -> MISC
# ADI -> ORG
# Relator Des -> PER
# Hermenegildo Gonçalves -> PER
# DJU -> MISC
# g.n -> LOC
# Manifesto -> MISC
# Distrito Federal -> LOC
# Presidente da Câmara Legislativa -> MISC
# fls -> MISC
# IX -> LOC
# LODF -> ORG
# Câmara Legislativa -> LOC
# LODF -> LOC
# Câmara Legislativa -> LOC
# Distrito Federal -> LOC
# Chefe do Poder Executivo -> MISC
# Distrito Federal -> LOC
# Decreto n. 10.829/87 -> MISC
# Portaria n. 314/92 do -> ORG
# Instituto Brasileiro do Patrimônio Histórico e Artístico Nacional  IPHAN -> LOC
# Senhor Governador do Distrito Federal -> LOC
# Poder Legislativo Distrital -> ORG
# Destarte -> LOC
# Deputados Distritais -> PER
# Poder Executivo -> MISC
# PROCEDENTE -> LOC
# Leis Distritais -> MISC
# Lei Complementar -> MISC
# omnes -> ORG
# D E C I S -> MISC

# %%
import pandas as pd

# %%
entidades = []
labels = []

for entidade in doc.ents:
    entidades.append(entidade.text)
    labels.append(entidade.label_)

# %%
pd.DataFrame({'Entidade': entidades, 'Label': labels})
# Out:
#                                         Entidade Label
# 0                                          Órgão   LOC
# 1                      Conselho Especial\nClasse   ORG
# 2    DISTRITO FEDERAL E TERRITÓRIOS\nRequerido(s   LOC
# 3                                      DA CÂMARA   ORG
# 4           DISTRITO FEDERAL E OUTRO(S)\nRelator   LOC
# ..                                           ...   ...
# 851                                   PROCEDENTE   LOC
# 852                              Leis Distritais  MISC
# 853                             Lei Complementar  MISC
# 854                                        omnes   ORG
# 855                                    D E C I S  MISC
#
# [856 rows x 2 columns]

# %% [markdown]
# **Visualizando as entidades no texto**

# %%
modelo_ner.get_pipe('ner').labels
# Out:
# ('LOC', 'MISC', 'ORG', 'PER')

# %%
print('LOC', spacy.explain('LOC'))
print('MISC', spacy.explain('MISC'))
print('ORG', spacy.explain('ORG'))
print('PER', spacy.explain('PER'))
# Out:
# LOC Non-GPE locations, mountain ranges, bodies of water
# MISC Miscellaneous entities, e.g. events, nationalities, products or works of art
# ORG Companies, agencies, institutions, etc.
# PER Named person or family.

# %%
spacy.displacy.render(doc, style = 'ent', jupyter=True)

# %%
# !python -m spacy download en_core_web_sm

# %%
# import en_core_web_sm

# modelo_ner_ing = spacy.load('en_core_web_sm')
# modelo_ner_ing.get_pipe('ner').labels

# %% [markdown]
# # Tokenizando os dados

# %%
dados = []

# Abre o arquivo ZIP e processa cada arquivo contido nele
with zipfile.ZipFile('/content/texts.zip') as zip:
    for nome_arquivo in zip.namelist():  # Itera sobre a lista de arquivos no ZIP
        with zip.open(nome_arquivo) as arquivo:  # Abre cada arquivo dentro do ZIP
            conteudo = arquivo.read().decode('utf-8')  # Lê e decodifica o conteúdo
            palavras = conteudo.split()  # Divide o conteúdo em palavras
            
            # Adiciona cada palavra junto com o nome do arquivo à lista de dados
            for palavra in palavras:
                dados.append([nome_arquivo, palavra])

# Cria um DataFrame do Pandas com as palavras extraídas e seus arquivos de origem
tabela_palavras = pd.DataFrame(dados, columns=['arquivo', 'palavra'])

# %%
tabela_palavras
# Out:
#                        arquivo              palavra
# 0                ADI2TJDFT.txt                Órgão
# 1                ADI2TJDFT.txt                    :
# 2                ADI2TJDFT.txt             Conselho
# 3                ADI2TJDFT.txt             Especial
# 4                ADI2TJDFT.txt               Classe
# ...                        ...                  ...
# 193487  ACORDAOTCU25052016.txt  Ministro-Substituto
# 193488  ACORDAOTCU25052016.txt              AUGUSTO
# 193489  ACORDAOTCU25052016.txt              SHERMAN
# 193490  ACORDAOTCU25052016.txt           CAVALCANTI
# 193491  ACORDAOTCU25052016.txt              Relator
#
# [193492 rows x 2 columns]

# %%
tabela_palavras.to_csv('palavras.csv', index = False, sep = '\t')

# %% [markdown]
# **Rotulando os dados no formato IOB**

# %% [markdown]
# O formato BIO/IOB ,abreviação de inside, outside, beginning, é um formato de marcação comum para marcar tokens em uma tarefa de agrupamento em linguística computacional (por exemplo, reconhecimento de entidade nomeada).
#
# - O prefixo B antes de uma tag indica que a tag é o início de um pedaço
# - O prefixo I antes de uma tag indica que a tag está dentro de um pedaço.
# - O prefixo O indica que um token não pertence a nenhuma entidade/pedaço.
#
# Exemplo:
#
#
# | **palavra** |     **label** |
# |------------:|--------------:|
# |     ACORDAO |             O |
# |    CONSELHO | B-ORGANIZACAO |
# |    ESPECIAL | I-ORGANIZACAO |
# |          DF |       B-LOCAL |

# %%
tabela_palavras = pd.read_csv('/content/palavras_IOB.tsv', sep = '\t')

# %%
tabela_palavras
# Out:
#                           arquivo     palavra          label
# 0                     TCU4687.txt       GRUPO              O
# 1                     TCU4687.txt           I              O
# 2                     TCU4687.txt      CLASSE              O
# 3                     TCU4687.txt          II              O
# 4                     TCU4687.txt          2ª  B-ORGANIZACAO
# ...                           ...         ...            ...
# 229272  RR2574407120025020372.txt          de              O
# 229273  RR2574407120025020372.txt      Chaves              O
# 229274  RR2574407120025020372.txt    Públicas              O
# 229275  RR2574407120025020372.txt  Brasileira              O
# 229276  RR2574407120025020372.txt           .              O
#
# [229277 rows x 3 columns]

# %%
tabela_palavras['label'].unique()
# Out:
# array(['O', 'B-ORGANIZACAO', 'I-ORGANIZACAO', 'B-JURISPRUDENCIA',
#        'I-JURISPRUDENCIA', 'B-PESSOA', 'I-PESSOA', 'B-LEGISLACAO',
#        'I-LEGISLACAO', 'B-TEMPO', 'B-LOCAL', 'I-LOCAL', 'I-TEMPO'],
#       dtype=object)

# %% [markdown]
# **Transformando um arquivo para o formato SpaCy**

# %% [markdown]
# Formato Spacy:
#
# ```
# tupla = ('texto', {'entities': [(10, 17, 'ORGANIZACAO'), (25,40, 'PESSOA')]})
# ```

# %%
grupos_arquivos = tabela_palavras.groupby(by= 'arquivo')

# %%
grupos_arquivos.get_group('ADI2TJDFT.txt')
# Out:
#              arquivo   palavra          label
# 46105  ADI2TJDFT.txt     Órgão              O
# 46106  ADI2TJDFT.txt         :              O
# 46107  ADI2TJDFT.txt  Conselho  B-ORGANIZACAO
# 46108  ADI2TJDFT.txt  Especial  I-ORGANIZACAO
# 46109  ADI2TJDFT.txt    Classe              O
# ...              ...       ...            ...
# 55911  ADI2TJDFT.txt         a              O
# 55912  ADI2TJDFT.txt      ação              O
# 55913  ADI2TJDFT.txt         ,              O
# 55914  ADI2TJDFT.txt   maioria              O
# 55915  ADI2TJDFT.txt         .              O
#
# [9811 rows x 3 columns]

# %%
# Obtém os dados do grupo 'ADI2TJDFT.txt' contendo palavras e seus respectivos rótulos
tabela_agrupada = grupos_arquivos.get_group('ADI2TJDFT.txt')[['palavra', 'label']].values

# Inicializa uma string para armazenar o conteúdo do texto extraído
conteudo = ''

# Inicializa um dicionário para armazenar as anotações das entidades
anotacoes = {'entities': []}

# Variáveis para armazenar as posições de início e fim das palavras no texto
inicio_palavra = 0
fim_palavra = 0

# Itera sobre cada palavra e seu respectivo rótulo na tabela agrupada
for texto, label in tabela_agrupada:
    texto = str(texto)  # Converte a palavra para string (caso necessário)
    tamanho_texto = len(texto) + 1  # Calcula o tamanho do texto incluindo um espaço

    # Define os índices de início e fim da palavra no texto concatenado
    inicio_palavra = fim_palavra
    fim_palavra = inicio_palavra + tamanho_texto

    # Se o rótulo não for 'O', adiciona a anotação da entidade
    if label != 'O':
        anotacao = (inicio_palavra, fim_palavra - 1, label)
        anotacoes['entities'].append(anotacao)

    # Concatena a palavra ao conteúdo final, adicionando um espaço entre elas
    conteudo = conteudo + texto + ' '

# %%
conteudo
# Out:
# "Órgão : Conselho Especial Classe : ADI Ação Direta de Inconstitucionalidade N . Processo : 2010002019357-4 Requerente ( s ) : PROCURADORA-GERAL DE JUSTIÇA DO DISTRITO FEDERAL E TERRITÓRIOS Requerido ( s ) : PRESIDENTE DA CÂMARA LEGISLATIVA DO DISTRITO FEDERAL E OUTRO ( S ) Relator : Desembargador LÉCIO RESENDE EMENTA AÇÃO DIRETA DE INCONSTITUCIONALIDADE . LEIS DISTRITAIS N.º 747/1994 E 2018/1998 . LEI COMPLEMENTAR DISTRITAL N.º 380/2001 . INCONSTITUCIONALIDADE FORMAL . LEI ORGÂNICA DO DISTRITO FEDERAL . OCUPAÇÃO DE ÁREA PÚBLICA . COMPETÊNCIA PRIVATIVA DO GOVERNADOR DO DISTRITO FEDERAL . AÇÃO JULGADA PROCEDENTE EM RAZÃO DO VÍCIO FORMAL . Tanto o Decreto n.º 10.829/87 , quanto a Portaria n.º 314/92 , do Instituto Brasileiro do Patrimônio Cultural IBPC , hoje Instituto do Patrimônio Histórico e Artístico Nacional IPHAN , conferem ao Governador do Distrito Federal competência privativa para iniciar o processo legislativo , quando se tratar o tema de uso e ocupação do solo em todo o território do Distrito Federal . ACÓRDÃO Acordam os Desembargadores do Conselho Especial do Tribunal de Justiça do Distrito Federal e dos Territórios LÉCIO RESENDE Relator , JOÃO MAIORISI Vogal , ROMÃO C. OLIVEIRA Vogal , DÁCIO VIEIRA Vogal , SÉRGIO BITTENCOURT Vogal , LECIR MANOEL DA LUZ Vogal , CARMELITA BRASIL Vogal , WALDIR LEÔNCIO LOPES JÚNIOR Vogal , J.J. COSTA CARVALHO Vogal , HUMBERTO ADJUTO ULHÔA Vogal , NÍDIA CORRÊA LIMA Vogal , ANA MARIA DUARTE AMARANTE BRITO Vogal , CRUZ MACEDO - Vogal , ROBERBAL CASEMIRO BELINATI Vogal , SILVÂNIO BARBOSA DOS SANTOS Vogal , OTÁVIO AUGUSTO Vogal , sob a presidência do Desembargador OTÁVIO AUGUSTO , em proferir a seguinte decisão : JULGOU-SE PROCEDENTE A AÇÃO , POR MAIORIA , de acordo com a ata do julgamento e notas taquigráficas . Brasília ( DF ) , 17 de maio de 2011 Des . LÉCIO RESENDE Relator R E L A T Ó R I O A PROCURADORA-GERAL DE JUSTIÇA DO DISTRITO FEDERAL E TERRITÓRIOS propõe Ação Direta de Inconstitucionalidade em face das Leis distritais n.º 747 , de 23 de agosto de 1994 , e 2.018 , de 28 de julho de 1998 , e da Lei Complementar distrital n.º 380 , de 4 de abril de 2001 , que tratam da ocupação de áreas públicas na Região Administrativa do Paranoá RA VII , sob a alegação de afronta aos artigos 3º , item XI , 52 , 100 , itens VI e XXI , e 321 , todos da Lei Orgânica do Distrito Federal LODF . Narra que as normas impugnadas padecem de inconstitucionalidade formal , em razão de disciplinarem matérias de iniciativa legislativa do Chefe do Poder Executivo , as quais não poderiam ter sido propostas por membros do Poder Legislativo , em afronta aos dispositivos acima aludidos . Requer a procedência do pedido para declarar , em tese e com efeitos ex tunc e eficácia erga omnes , a inconstitucionalidade das Leis distritais n.º 747/1994 e 2.018/1998 , bem como da Lei Complementar distrital n.º 380/2001 . Com a inicial vieram os documentos de fls . 11/15 . O Presidente da Câmara Legislativa do Distrito Federal , nas informações de fls . 21/25 , afirma que as matérias tratadas nas leis distritais e na lei complementar impugnadas não estão incluídas no rol daquelas cuja iniciativa de lei é privativa do Governador do Distrito Federal , não havendo se falar em vício de iniciativa . Sustenta que é da Câmara distrital a competência para a matéria constante das leis acoimadas de inconstitucional , conforme previsto no art . 58 , da LODF . O Governador do Distrito Federal presta informações às fls . 27/30 , nas quais concorda com o pedido de declaração de inconstitucionalidade das normas objurgadas , em virtude de serem formalmente inconstitucionais . A manifestação do Procurador-Geral do Distrito Federal , às fls . 32/37 , é no sentido de opinar pela procedência do pedido quanto à alegação de inconstitucionalidade formal das normas impugnadas . Parecer Ministerial de fls . 39/43 oficiando pelo conhecimento da ação direta e pela procedência do pedido deduzido na inicial . É o Relatório . V O T O S O Senhor Desembargado ...

# %%
anotacoes
# Out:
# {'entities': [(8, 16, 'B-ORGANIZACAO'),
#   (17, 25, 'I-ORGANIZACAO'),
#   (91, 106, 'B-JURISPRUDENCIA'),
#   (158, 166, 'B-LOCAL'),
#   (167, 174, 'I-LOCAL'),
#   (221, 227, 'B-ORGANIZACAO'),
#   (228, 239, 'I-ORGANIZACAO'),
#   (240, 242, 'I-ORGANIZACAO'),
#   (243, 251, 'I-ORGANIZACAO'),
#   (252, 259, 'I-ORGANIZACAO'),
#   (298, 303, 'B-PESSOA'),
#   (304, 311, 'I-PESSOA'),
#   (358, 362, 'B-LEGISLACAO'),
#   (363, 373, 'I-LEGISLACAO'),
#   (374, 377, 'I-LEGISLACAO'),
#   (378, 386, 'I-LEGISLACAO'),
#   (389, 398, 'B-LEGISLACAO'),
#   (401, 404, 'B-LEGISLACAO'),
#   (405, 417, 'I-LEGISLACAO'),
#   (418, 427, 'I-LEGISLACAO'),
#   (428, 431, 'I-LEGISLACAO'),
#   (432, 440, 'I-LEGISLACAO'),
#   (474, 477, 'B-LEGISLACAO'),
#   (478, 486, 'I-LEGISLACAO'),
#   (487, 489, 'I-LEGISLACAO'),
#   (490, 498, 'I-LEGISLACAO'),
#   (499, 506, 'I-LEGISLACAO'),
#   (575, 583, 'B-LOCAL'),
#   (584, 591, 'I-LOCAL'),
#   (653, 660, 'B-LEGISLACAO'),
#   (661, 664, 'I-LEGISLACAO'),
#   (665, 674, 'I-LEGISLACAO'),
#   (686, 694, 'B-LEGISLACAO'),
#   (695, 698, 'I-LEGISLACAO'),
#   (699, 705, 'I-LEGISLACAO'),
#   (711, 720, 'B-ORGANIZACAO'),
#   (721, 731, 'I-ORGANIZACAO'),
#   (732, 734, 'I-ORGANIZACAO'),
#   (735, 745, 'I-ORGANIZACAO'),
#   (746, 754, 'I-ORGANIZACAO'),
#   (755, 759, 'B-ORGANIZACAO'),
#   (767, 776, 'B-ORGANIZACAO'),
#   (777, 779, 'I-ORGANIZACAO'),
#   (780, 790, 'I-ORGANIZACAO'),
#   (791, 800, 'I-ORGANIZACAO'),
#   (801, 802, 'I-ORGANIZACAO'),
#   (803, 812, 'I-ORGANIZACAO'),
#   (813, 821, 'I-ORGANIZACAO'),
#   (822, 827, 'B-ORGANIZACAO'),
#   (856, 864, 'B-LOCAL'),
#   (865, 872, 'I-LOCAL'),
#   (1007, 1015, 'B-LOCAL'),
#   (1016, 1023, 'I-LOCAL'),
#   (1064, 1072, 'B-ORGANIZACAO'),
#   (1073, 1081, 'I-ORGANIZACAO'),
#   (1082, 1084, 'I-ORGANIZACAO'),
#   (1085, 1093, 'I-ORGANIZACAO'),
#   (1094, 1096, 'I-ORGANIZACAO'),
#   (1097, 1104, 'I-ORGANIZACAO'),
#   (1105, 1107, 'I-ORGANIZACAO'),
#   (1108, 1116, 'I-ORGANIZACAO'),
#   (1117, 1124, 'I-ORGANIZACAO'),
#   (1143, 1148, 'B-PESSOA'),
#   (1149, 1156, 'I-PESSOA'),
#   (1167, 1171, 'B-PESSOA'),
#   (1172, 1180, 'I-PESSOA'),
#   (1189, 1194, 'B-PESSOA'),
#   (1195, 1197, 'I-PESSOA'),
#   (1198, 1206, 'I-PESSOA'),
#   (1215, 1220, 'B-PESSOA'),
#   (1221, 1227, 'I-PESSOA'),
#   (1236, 1242, 'B-PESSOA'),
#   (1243, 1254, 'I-PESSOA'),
#   (1263, 1268, 'B-PESSOA'),
#   (1269, 1275, 'I-PESSOA'),
#   (1276, 1278, 'I-PESSOA'),
#   (1279, 1282, 'I-PESSOA'),
#   (1291, 1300, 'B-PESSOA'),
#   (1301, 1307, 'I-PESSOA'),
#   (1316, 1322, 'B-PESSOA'),
#   (1323, 1330, 'I-PESSOA'),
#   (1331, 1336, 'I-PESSOA'),
#   (1337, 1343, 'I-PESSOA'),
#   (1352, 1356, 'B-PESSOA'),
#   (1357, 1362, 'I-PESSOA'),
#   (1363, 1371, 'I-PESSOA'),
#   (1380, 1388, 'B-PESSOA'),
#   (1389, 1395, 'I-PESSOA'),
#   (1396, 1401, 'I-PESSOA'),
#   (1410, 1415, 'B-PESSOA'),
#   (1416, 1422, 'I-PESSOA'),
#   (1423, 1427, 'I-PESSOA'),
#   (1436, 1439, 'B-PESSOA'),
#   (1440, 1445, 'I-PESSOA'),
#   (1446, 1452, 'I-PESSOA'),
#   (1453, 1461, 'I-PESSOA'),
#   (1462, 1467, 'I-PESSOA'),
#   (1476, 1480, 'B-PESSOA'),
#   (1481, 1487, 'I-PESSOA'),
#   (1498, 1506, 'B-PESSOA'),
#   (1507, 1515, 'I-PESSOA'),
#   (1516, 1524, 'I-PESSOA'),
#   (1533, 1541, 'B-PESSOA'),
#   (1542, 1549, 'I-PESSOA'),
#   (1550, 1553, 'I-PESSOA'),
#   (1554, 1560, 'I-PESSOA'),
#   (1569, 1575, 'B-PESSOA'),
#   (1576, 1583, 'I-PESSOA'),
#   (1627, 1633, 'B-PESSOA'),
#   (1634, 1641, 'I-PESSOA'),
#   (1779, 1787, 'B-LOCAL'),
#   (1788, 1789, 'I-LOCAL'),
#   (1790, 1792, 'I-LOCAL'),
#   (1793, 1794, 'I-LOCAL'),
#   (1797, 1799, 'B-TEMPO'),
#   (1800, 1802, 'I-TEMPO'),
#   (1803, 1807, 'I-TEMPO'),
#   (1808, 1810, 'I-TEMPO'),
#   (1811, 1815, 'I-TEMPO'),
#   (1822, 1827, 'B-PESSOA'),
#   (1828, 1835, 'I-PESSOA'),
#   (1896, 1904, 'B-LOCAL'),
#   (1905, 1912, 'I-LOCAL'),
#   (1983, 1987, 'B-LEGISLACAO'),
#   (1988, 1998, 'I-LEGISLACAO'),
#   (1999, 2002, 'I-LEGISLACAO'),
#   (2003, 2006, 'I-LEGISLACAO'),
#   (2012, 2014, 'B-TEMPO'),
#   (2015, 2017, 'I-TEMPO'),
#   (2018, 2024, 'I-TEMPO'),
#   (2025, 2027, 'I-TEMPO'),
#   (2028, 2032, 'I-TEMPO'),
#   (2037, 2042, 'B-LEGISLACAO'),
#   (2048, 2050, 'B-TEMPO'),
#   (2051, 2053, 'I-TEMPO'),
#   (2054, 2059, 'I-TEMPO'),
#   (2060, 2062, 'I-TEMPO'),
#   (2063, 2067, 'I-TEMPO'),
#   (2075, 2078, 'B-LEGISLACAO'),
#   (2079, 2091, 'I-LEGISLACAO'),
#   (2092, 2101, 'I-LEGISLACAO'),
#   (2102, 2105, 'I-LEGISLACAO'),
#   (2106, 2109, 'I-LEGISLACAO'),
#   (2115, 2116, 'B-TEMPO'),
#   (2117, 2119, 'I-TEMPO'),
#   (2120, 2125, 'I-TEMPO'),
#   (2126, 2128, 'I-TEMPO'),
#   (2129, 2133, 'I-TEMPO'),
#   (2180, 2186, 'B-LOCAL'),
#   (2187, 2201, 'I-LOCAL'),
#   (2202, 2204, 'I-LOCAL'),
#   (2205, 2212, 'I-LOCAL'),
#   (2213, 2215, 'B-LOCAL'),
#   (2216, 2219, 'I-LOCAL'),
#   (2252, 2259, 'B-LEGISLACAO'),
#   (2260, 2262, 'I-LEGISLACAO'),
#   (2263, 2264, 'I-LEGISLACAO'),
#   (2265, 2269, 'I-LEGISLACAO'),
#   (2270, 2272, 'I-LEGISLACAO'),
#   (2273, 2274, 'I-LEGISLACAO'),
#   (2275, 2277, 'I-LEGISLACAO'),
#   (2278, 2279, 'I-LEGISLACAO'),
#   (2280, 2283, 'I-LEGISLACAO'),
#   (2284, 2285, 'I-LEGISLACAO'),
#   (2286, 2291, 'I-LEGISLACAO'),
#   (2292, 2294, 'I-LEGISLACAO'),
#   (2295, 2296, 'I-LEGISLACAO'),
#   (2297, 2300, 'I-LEGISLACAO'),
#   (2301, 2302, 'I-LEGISLACAO'),
#   (2303, 2304, 'I-LEGISLACAO'),
#   (2305, 2308, 'I-LEGISLACAO'),
#   (2309, 2310, 'I-LEGISLACAO'),
#   (2311, 2316, 'I-LEGISLACAO'),
#   (2317, 2319, 'I-LEGISLACAO'),
#   (2320, 2323, 'I-LEGISLACAO'),
#   (2324, 2332, 'I-LEGISLACAO'),
#   (2333, 2335, 'I-LEGISLACAO'),
#   (2336, 2344, 'I-LEGISLACAO'),
#   (2345, 2352, 'I-LEGISLACAO'),
#   (2353, 2357, 'B-LEGISLACAO'),
#   (2774, 2778, 'B-LEGISLACAO'),
#   (2779, 2789, 'I-LEGISLACAO'),
#   (2790, 2793, 'I-LEGISLACAO'),
#   (2794, 2802, 'I-LEGISLACAO'),
#   (2805, 2815, 'B-LEGISLACAO'),
#   (2830, 2833, 'B-LEGISLACAO'),
#   (2834, 2846, 'I-LEGISLACAO'),
#   (2847, 2856, 'I-LEGISLACAO'),
#   (2857, 2860, 'I-LEGISLACAO'),
#   (2861, 2869, 'I-LEGISLACAO'),
#   (2940, 2946, 'B-ORGANIZACAO'),
#   (2947, 2958, 'I-ORGANIZACAO'),
#   (2959, 2961, 'I-ORGANIZACAO'),
#   (2962, 2970, 'I-ORGANIZACAO'),
#   (2971, 2978, 'I-ORGANIZACAO'),
#   (3187, 3195, 'B-LOCAL'),
#   (3196, 3203, 'I-LOCAL'),
#   (3270, 3276, 'B-ORGANIZACAO'),
#   (3277, 3286, 'I-ORGANIZACAO'),
#   (3388, 3391, 'B-LEGISLACAO'),
#   (3392, 3393, 'I-LEGISLACAO'),
#   (3394, 3396, 'I-LEGISLACAO'),
#   (3397, 3398, 'I-LEGISLACAO'),
#   (3399, 3401, 'I-LEGISLACAO'),
#   (3402, 3406, 'I-LEGISLACAO'),
#   (3425, 3433, 'B-LOCAL'),
#   (3434, 3441, 'I-LOCAL'),
#   (3663, 3671, 'B-LOCAL'),
#   (3672, 3679, 'I-LOCAL'),
#   (4001, 4006, 'B-PESSOA'),
#   (4007, 4014, 'I-PESSOA'),
#   (4057, 4065, 'B-LOCAL'),
#   (4066, 4073, 'I-LOCAL'),
#   (4144, 4148, 'B-LEGISLACAO'),
#   (4149, 4159, 'I-LEGISLACAO'),
#   (4160, 4163, 'I-LEGISLACAO'),
#   (4164, 4167, 'I-LEGISLACAO'),
#   (4173, 4175, 'B-TEMPO'),
#   (4176, 4178, 'I-TEMPO'),
#   (4179, 4185, 'I-TEMPO'),
#   (4186, 4188, 'I-TEMPO'),
#   (4189, 4193, 'I-TEMPO'),
#   (4198, 4203, 'B-LEGISLACAO'),
#   (4209, 4211, 'B-TEMPO'),
#   (4212, 4214, 'I-TEMPO'),
#   (4215, 4220, 'I-TEMPO'),
#   (4221, 4223, 'I-TEMPO'),
#   (4224, 4228, 'I-TEMPO'),
#   (4236, 4239, 'B-LEGISLACAO'),
#   (4240, 4252, 'I-LEGISLACAO'),
#   (4253, 4262, 'I-LEGISLACAO'),
#   (4263, 4266, 'I-LEGISLACAO'),
#   (4267, 4270, 'I-LEGISLACAO'),
#   (4276, 4277, 'B-TEMPO'),
#   (4278, 4280, 'I-TEMPO'),
#   (4281, 4286, 'I-TEMPO'),
#   (4287, 4289, 'I-TEMPO'),
#   (4290, 4294, 'I-TEMPO'),
#   (4341, 4347, 'B-LOCAL'),
#   (4348, 4362, 'I-LOCAL'),
#   (4363, 4365, 'I-LOCAL'),
#   (4366, 4373, 'I-LOCAL'),
#   (4374, 4376, 'B-LOCAL'),
#   (4377, 4380, 'I-LOCAL'),
#   (4663, 4670, 'B-LEGISLACAO'),
#   (4671, 4673, 'I-LEGISLACAO'),
#   (4674, 4675, 'I-LEGISLACAO'),
#   (4676, 4680, 'I-LEGISLACAO'),
#   (4681, 4683, 'I-LEGISLACAO'),
#   (4684, 4685, 'I-LEGISLACAO'),
#   (4686, 4688, 'I-LEGISLACAO'),
#   (4689, 4690, 'I-LEGISLACAO'),
#   (4691, 4694, 'I-LEGISLACAO'),
#   (4695, 4696, 'I-LEGISLACAO'),
#   (4697, 4702, 'I-LEGISLACAO'),
#   (4703, 4705, 'I-LEGISLACAO'),
#   (4706, 4707, 'I-LEGISLACAO'),
#   (4708, 4711, 'I-LEGISLACAO'),
#   (4712, 4713, 'I-LEGISLACAO'),
#   (4714, 4715, 'I-LEGISLACAO'),
#   (4716, 4719, 'I-LEGISLACAO'),
#   (4720, 4721, 'I-LEGISLACAO'),
#   (4722, 4727, 'I-LEGISLACAO'),
#   (4728, 4730, 'I-LEGISLACAO'),
#   (4731, 4734, 'I-LEGISLACAO'),
#   (4735, 4743, 'I-LEGISLACAO'),
#   (4744, 4746, 'I-LEGISLACAO'),
#   (4747, 4755, 'I-LEGISLACAO'),
#   (4756, 4763, 'I-LEGISLACAO'),
#   (4764, 4768, 'B-LEGISLACAO'),
#   (5001, 5004, 'B-LEGISLACAO'),
#   (5005, 5013, 'I-LEGISLACAO'),
#   (5014, 5016, 'I-LEGISLACAO'),
#   (5017, 5025, 'I-LEGISLACAO'),
#   (5026, 5033, 'I-LEGISLACAO'),
#   (5104, 5109, 'B-LEGISLACAO'),
#   (5110, 5115, 'I-LEGISLACAO'),
#   (5260, 5266, 'B-LEGISLACAO'),
#   (5267, 5268, 'I-LEGISLACAO'),
#   (5269, 5270, 'I-LEGISLACAO'),
#   (5271, 5272, 'I-LEGISLACAO'),
#   (5273, 5275, 'I-LEGISLACAO'),
#   (5276, 5280, 'I-LEGISLACAO'),
#   (5281, 5282, 'I-LEGISLACAO'),
#   (5283, 5285, 'I-LEGISLACAO'),
#   (5286, 5289, 'I-LEGISLACAO'),
#   (5290, 5291, 'I-LEGISLACAO'),
#   (5292, 5295, 'I-LEGISLACAO'),
#   (5296, 5298, 'I-LEGISLACAO'),
#   (5299, 5304, 'I-LEGISLACAO'),
#   (5305, 5310, 'I-LEGISLACAO'),
#   (5416, 5419, 'B-LEGISLACAO'),
#   (5420, 5421, 'I-LEGISLACAO'),
#   (5422, 5425, 'I-LEGISLACAO'),
#   (5426, 5427, 'I-LEGISLACAO'),
#   (5428, 5429, 'I-LEGISLACAO'),
#   (5430, 5432, 'I-LEGISLACAO'),
#   (5433, 5435, 'I-LEGISLACAO'),
#   (5436, 5448, 'I-LEGISLACAO'),
#   (5449, 5456, 'I-LEGISLACAO'),
#   (5568, 5580, 'B-LEGISLACAO'),
#   (5944, 5952, 'B-ORGANIZACAO'),
#   (5953, 5960, 'I-ORGANIZACAO'),
#   (6180, 6188, 'B-ORGANIZACAO'),
#   (6189, 6196, 'I-ORGANIZACAO'),
#   (6222, 6231, 'B-ORGANIZACAO'),
#   (6232, 6242, 'I-ORGANIZACAO'),
#   (6295, 6300, 'B-PESSOA'),
#   (6301, 6303, 'I-PESSOA'),
#   (6304, 6309, 'I-PESSOA'),
#   (6334, 6337, 'B-JURISPRUDENCIA'),
#   (6338, 6340, 'I-JURISPRUDENCIA'),
#   (6341, 6347, 'I-JURISPRUDENCIA'),
#   (6363, 6366, 'B-LEGISLACAO'),
#   (6367, 6375, 'I-LEGISLACAO'),
#   (6376, 6378, 'I-LEGISLACAO'),
#   (6379, 6387, 'I-LEGISLACAO'),
#   (6388, 6395, 'I-LEGISLACAO'),
#   (6628, 6637, 'B-ORGANIZACAO'),
#   (6638, 6648, 'I-ORGANIZACAO'),
#   (6772, 6780, 'B-LOCAL'),
#   (6781, 6788, 'I-LOCAL'),
#   (7011, 7013, 'B-TEMPO'),
#   (7014, 7016, 'I-TEMPO'),
#   (7017, 7021, 'I-TEMPO'),
#   (7022, 7024, 'I-TEMPO'),
#   (7025, 7029, 'I-TEMPO'),
#   (7180, 7183, 'B-LEGISLACAO'),
#   (7184, 7192, 'I-LEGISLACAO'),
#   (7193, 7195, 'I-LEGISLACAO'),
#   (7196, 7204, 'I-LEGISLACAO'),
#   (7205, 7212, 'I-LEGISLACAO'),
#   (7425, 7432, 'B-ORGANIZACAO'),
#   (7433, 7441, 'I-ORGANIZACAO'),
#   (7442, 7449, 'I-ORGANIZACAO'),
#   (7455, 7458, 'B-JURISPRUDENCIA'),
#   (7459, 7462, 'I-JURISPRUDENCIA'),
#   (7463, 7472, 'I-JURISPRUDENCIA'),
#   (7506, 7514, 'B-ORGANIZACAO'),
#   (7515, 7517, 'I-ORGANIZACAO'),
#   (7518, 7525, 'I-ORGANIZACAO'),
#   (7526, 7528, 'I-ORGANIZACAO'),
#   (7529, 7537, 'I-ORGANIZACAO'),
#   (7538, 7545, 'I-ORGANIZACAO'),
#   (7546, 7547, 'I-ORGANIZACAO'),
#   (7548, 7551, 'I-ORGANIZACAO'),
#   (7552, 7563, 'I-ORGANIZACAO'),
#   (7648, 7651, 'B-LEGISLACAO'),
#   (7652, 7660, 'I-LEGISLACAO'),
#   (7661, 7663, 'I-LEGISLACAO'),
#   (7664, 7672, 'I-LEGISLACAO'),
#   (7673, 7680, 'I-LEGISLACAO'),
#   (7845, 7853, 'B-ORGANIZACAO'),
#   (7854, 7856, 'I-ORGANIZACAO'),
#   (7857, 7864, 'I-ORGANIZACAO'),
#   (7865, 7867, 'I-ORGANIZACAO'),
#   (7868, 7876, 'I-ORGANIZACAO'),
#   (7877, 7884, 'I-ORGANIZACAO'),
#   (7885, 7886, 'I-ORGANIZACAO'),
#   (7887, 7890, 'I-ORGANIZACAO'),
#   (7891, 7902, 'I-ORGANIZACAO'),
#   (7941, 7946, 'B-LEGISLACAO'),
#   (7947, 7952, 'I-LEGISLACAO'),
#   (8139, 8147, 'B-LOCAL'),
#   (8148, 8155, 'I-LOCAL'),
#   (8363, 8371, 'B-LOCAL'),
#   (8372, 8379, 'I-LOCAL'),
#   (8544, 8547, 'B-LEGISLACAO'),
#   (8548, 8550, 'I-LEGISLACAO'),
#   (8551, 8554, 'I-LEGISLACAO'),
#   (8560, 8562, 'B-TEMPO'),
#   (8563, 8565, 'I-TEMPO'),
#   (8566, 8572, 'I-TEMPO'),
#   (8573, 8575, 'I-TEMPO'),
#   (8576, 8580, 'I-TEMPO'),
#   (8611, 8619, 'B-PESSOA'),
#   (8620, 8629, 'I-PESSOA'),
#   (8674, 8682, 'B-LOCAL'),
#   (8683, 8690, 'I-LOCAL'),
#   (8751, 8755, 'B-LOCAL'),
#   (8756, 8758, 'I-LOCAL'),
#   (8759, 8767, 'I-LOCAL'),
#   (8768, 8774, 'I-LOCAL'),
#   (8775, 8777, 'I-LOCAL'),
#   (8778, 8785, 'I-LOCAL'),
#   (8813, 8819, 'B-ORGANIZACAO'),
#   (8820, 8831, 'I-ORGANIZACAO'),
#   (8832, 8834, 'I-ORGANIZACAO'),
#   (8835, 8843, 'I-ORGANIZACAO'),
#   (8844, 8851, 'I-ORGANIZACAO'),
#   (8888, 8889, 'B-LEGISLACAO'),
#   (8890, 8892, 'I-LEGISLACAO'),
#   (8893, 8895, 'I-LEGISLACAO'),
#   (8896, 8899, 'I-LEGISLACAO'),
#   (8900, 8901, 'I-LEGISLACAO'),
#   (8902, 8904, 'I-LEGISLACAO'),
#   (8905, 8907, 'I-LEGISLACAO'),
#   (8908, 8911, 'I-LEGISLACAO'),
#   (8912, 8920, 'I-LEGISLACAO'),
#   (8921, 8923, 'I-LEGISLACAO'),
#   (8924, 8932, 'I-LEGISLACAO'),
#   (8933, 8940, 'I-LEGISLACAO'),
#   (8945, 8948, 'B-LEGISLACAO'),
#   (8949, 8951, 'I-LEGISLACAO'),
#   (8952, 8955, 'I-LEGISLACAO'),
#   (8961, 8963, 'B-TEMPO'),
#   (8964, 8966, 'I-TEMPO'),
#   (8967, 8973, 'I-TEMPO'),
#   (8974, 8976, 'I-TEMPO'),
#   (8977, 8981, 'I-TEMPO'),
#   (9038, 9042, 'B-LOCAL'),
#   (9043, 9045, 'I-LOCAL'),
#   (9046, 9054, 'I-LOCAL'),
#   (9055, 9061, 'I-LOCAL'),
#   (9062, 9063, 'I-LOCAL'),
#   (9064, 9066, 'I-LOCAL'),
#   (9067, 9074, 'I-LOCAL'),
#   (9099, 9102, 'B-LEGISLACAO'),
#   (9103, 9105, 'I-LEGISLACAO'),
#   (9106, 9109, 'I-LEGISLACAO'),
#   (9115, 9117, 'B-TEMPO'),
#   (9118, 9120, 'I-TEMPO'),
#   (9121, 9129, 'I-TEMPO'),
#   (9130, 9132, 'I-TEMPO'),
#   (9133, 9137, 'I-TEMPO'),
#   (9193, 9197, 'B-LOCAL'),
#   (9198, 9205, 'I-LOCAL'),
#   (9427, 9434, 'B-LEGISLACAO'),
#   (9435, 9437, 'I-LEGISLACAO'),
#   (9438, 9444, 'I-LEGISLACAO'),
#   (9450, 9452, 'B-TEMPO'),
#   (9453, 9455, 'I-TEMPO'),
#   (9456, 9462, 'I-TEMPO'),
#   (9463, 9465, 'I-TEMPO'),
#   (9466, 9470, 'I-TEMPO'),
#   (9482, 9492, 'B-ORGANIZACAO'),
#   (9493, 9495, 'I-ORGANIZACAO'),
#   (9496, 9505, 'I-ORGANIZACAO'),
#   (9506, 9508, 'I-ORGANIZACAO'),
#   (9509, 9516, 'I-ORGANIZACAO'),
#   (9542, 9546, 'B-LOCAL'),
#   (9547, 9549, 'I-LOCAL'),
#   (9550, 9558, 'I-LOCAL'),
#   (9559, 9565, 'I-LOCAL'),
#   (9566, 9567, 'I-LOCAL'),
#   (9568, 9570, 'I-LOCAL'),
#   (9571, 9578, 'I-LOCAL'),
#   (9622, 9626, 'B-LOCAL'),
#   (9627, 9629, 'I-LOCAL'),
#   (9630, 9638, 'I-LOCAL'),
#   (9639, 9648, 'I-LOCAL'),
#   (9649, 9651, 'I-LOCAL'),
#   (9652, 9656, 'I-LOCAL'),
#   (9657, 9664, 'I-LOCAL'),
#   (9922, 9925, 'B-LEGISLACAO'),
#   (9926, 9928, 'I-LEGISLACAO'),
#   (9929, 9934, 'I-LEGISLACAO'),
#   (9940, 9942, 'B-TEMPO'),
#   (9943, 9945, 'I-TEMPO'),
#   (9946, 9951, 'I-TEMPO'),
#   (9952, 9954, 'I-TEMPO'),
#   (9955, 9959, 'I-TEMPO'),
#   (9992, 9996, 'B-PESSOA'),
#   (9997, 10002, 'I-PESSOA'),
#   (10089, 10095, 'B-LOCAL'),
#   (10096, 10110, 'I-LOCAL'),
#   (10111, 10113, 'I-LOCAL'),
#   (10114, 10121, 'I-LOCAL'),
#   (10122, 10124, 'B-LOCAL'),
#   (10125, 10128, 'I-LOCAL'),
#   (10148, 10154, 'B-ORGANIZACAO'),
#   (10155, 10166, 'I-ORGANIZACAO'),
#   (10167, 10169, 'I-ORGANIZACAO'),
#   (10170, 10178, 'I-ORGANIZACAO'),
#   (10179, 10186, 'I-ORGANIZACAO'),
#   (10213, 10221, 'B-LOCAL'),
#   (10222, 10229, 'I-LOCAL'),
#   (10246, 10247, 'B-LEGISLACAO'),
#   (10248, 10250, 'I-LEGISLACAO'),
#   (10251, 10253, 'I-LEGISLACAO'),
#   (10254, 10257, 'I-LEGISLACAO'),
#   (10258, 10259, 'I-LEGISLACAO'),
#   (10260, 10262, 'I-LEGISLACAO'),
#   (10263, 10265, 'I-LEGISLACAO'),
#   (10266, 10269, 'I-LEGISLACAO'),
#   (10270, 10278, 'I-LEGISLACAO'),
#   (10279, 10281, 'I-LEGISLACAO'),
#   (10282, 10290, 'I-LEGISLACAO'),
#   (10291, 10298, 'I-LEGISLACAO'),
#   (10334, 10340, 'B-ORGANIZACAO'),
#   (10341, 10352, 'I-ORGANIZACAO'),
#   (10353, 10355, 'I-ORGANIZACAO'),
#   (10356, 10364, 'I-ORGANIZACAO'),
#   (10365, 10372, 'I-ORGANIZACAO'),
#   (10536, 10542, 'B-LOCAL'),
#   (10543, 10557, 'I-LOCAL'),
#   (10558, 10560, 'I-LOCAL'),
#   (10561, 10568, 'I-LOCAL'),
#   (10569, 10571, 'B-LOCAL'),
#   (10572, 10575, 'I-LOCAL'),
#   (10612, 10619, 'B-LOCAL'),
#   (10620, 10621, 'I-LOCAL'),
#   (10622, 10623, 'I-LOCAL'),
#   (10624, 10625, 'I-LOCAL'),
#   (10644, 10651, 'B-LOCAL'),
#   (10652, 10654, 'I-LOCAL'),
#   (10655, 10658, 'I-LOCAL'),
#   (10692, 10699, 'B-LOCAL'),
#   (10700, 10702, 'I-LOCAL'),
#   (10703, 10706, 'I-LOCAL'),
#   (10736, 10742, 'B-LOCAL'),
#   (10743, 10757, 'I-LOCAL'),
#   (10758, 10760, 'I-LOCAL'),
#   (10761, 10768, 'I-LOCAL'),
#   (11360, 11363, 'B-LEGISLACAO'),
#   (11364, 11376, 'I-LEGISLACAO'),
#   (11377, 11379, 'I-LEGISLACAO'),
#   (11380, 11383, 'I-LEGISLACAO'),
#   (11389, 11390, 'B-TEMPO'),
#   (11391, 11393, 'I-TEMPO'),
#   (11394, 11399, 'I-TEMPO'),
#   (11400, 11402, 'I-TEMPO'),
#   (11403, 11407, 'I-TEMPO'),
#   (11440, 11445, 'B-PESSOA'),
#   (11446, 11453, 'I-PESSOA'),
#   (11516, 11522, 'B-LOCAL'),
#   (11523, 11537, 'I-LOCAL'),
#   (11538, 11540, 'I-LOCAL'),
#   (11541, 11548, 'I-LOCAL'),
#   (11549, 11551, 'B-LOCAL'),
#   (11552, 11555, 'I-LOCAL'),
#   (11574, 11580, 'B-ORGANIZACAO'),
#   (11581, 11592, 'I-ORGANIZACAO'),
#   (11593, 11595, 'I-ORGANIZACAO'),
#   (11596, 11604, 'I-ORGANIZACAO'),
#   (11605, 11612, 'I-ORGANIZACAO'),
#   (11638, 11639, 'B-LEGISLACAO'),
#   (11640, 11642, 'I-LEGISLACAO'),
#   (11643, 11645, 'I-LEGISLACAO'),
#   (11646, 11649, 'I-LEGISLACAO'),
#   (11650, 11651, 'I-LEGISLACAO'),
#   (11652, 11654, 'I-LEGISLACAO'),
#   (11655, 11657, 'I-LEGISLACAO'),
#   (11658, 11661, 'I-LEGISLACAO'),
#   (11662, 11670, 'I-LEGISLACAO'),
#   (11671, 11673, 'I-LEGISLACAO'),
#   (11674, 11682, 'I-LEGISLACAO'),
#   (11683, 11690, 'I-LEGISLACAO'),
#   (11768, 11776, 'B-LOCAL'),
#   (11777, 11784, 'I-LOCAL'),
#   (11800, 11806, 'B-ORGANIZACAO'),
#   (11807, 11818, 'I-ORGANIZACAO'),
#   (11819, 11821, 'I-ORGANIZACAO'),
#   (11822, 11830, 'I-ORGANIZACAO'),
#   (11831, 11838, 'I-ORGANIZACAO'),
#   (12023, 12029, 'B-LOCAL'),
#   (12030, 12044, 'I-LOCAL'),
#   (12045, 12047, 'I-LOCAL'),
#   (12048, 12055, 'I-LOCAL'),
#   (12056, 12058, 'B-LOCAL'),
#   (12059, 12062, 'I-LOCAL'),
#   (12131, 12137, 'B-LOCAL'),
#   (12138, 12145, 'I-LOCAL'),
#   (12146, 12152, 'I-LOCAL'),
#   (12153, 12161, 'I-LOCAL'),
#   (12162, 12166, 'I-LOCAL'),
#   (12182, 12188, 'B-LOCAL'),
#   (12189, 12203, 'I-LOCAL'),
#   (12204, 12206, 'I-LOCAL'),
#   (12207, 12214, 'I-LOCAL'),
#   (12215, 12217, 'B-LOCAL'),
#   (12218, 12221, 'I-LOCAL'),
#   (12333, 12340, 'B-LOCAL'),
#   (12341, 12347, 'I-LOCAL'),
#   (12348, 12352, 'I-LOCAL'),
#   (13186, 13191, 'B-LEGISLACAO'),
#   (13192, 13194, 'I-LEGISLACAO'),
#   (13195, 13197, 'I-LEGISLACAO'),
#   (13198, 13201, 'I-LEGISLACAO'),
#   (13202, 13214, 'I-LEGISLACAO'),
#   (13215, 13217, 'I-LEGISLACAO'),
#   (13218, 13220, 'I-LEGISLACAO'),
#   (13226, 13228, 'B-TEMPO'),
#   (13229, 13231, 'I-TEMPO'),
#   (13232, 13237, 'I-TEMPO'),
#   (13238, 13240, 'I-TEMPO'),
#   (13241, 13245, 'I-TEMPO'),
#   (13488, 13494, 'B-LOCAL'),
#   (13495, 13509, 'I-LOCAL'),
#   (13510, 13512, 'I-LOCAL'),
#   (13513, 13520, 'I-LOCAL'),
#   (13521, 13523, 'B-LOCAL'),
#   (13524, 13527, 'I-LOCAL'),
#   (13810, 13813, 'B-LEGISLACAO'),
#   (13814, 13822, 'I-LEGISLACAO'),
#   (13823, 13825, 'I-LEGISLACAO'),
#   (13826, 13834, 'I-LEGISLACAO'),
#   (13835, 13842, 'I-LEGISLACAO'),
#   (13905, 13913, 'B-ORGANIZACAO'),
#   (13914, 13921, 'I-ORGANIZACAO'),
#   (13972, 13980, 'B-LOCAL'),
#   (14097, 14104, 'B-LEGISLACAO'),
#   (14105, 14108, 'I-LEGISLACAO'),
#   (14109, 14115, 'I-LEGISLACAO'),
#   (14121, 14122, 'B-TEMPO'),
#   (14123, 14125, 'I-TEMPO'),
#   (14126, 14133, 'I-TEMPO'),
#   (14134, 14136, 'I-TEMPO'),
#   (14137, 14141, 'I-TEMPO'),
#   (14149, 14157, 'B-LEGISLACAO'),
#   (14158, 14161, 'I-LEGISLACAO'),
#   (14162, 14165, 'I-LEGISLACAO'),
#   (14171, 14172, 'B-TEMPO'),
#   (14173, 14175, 'I-TEMPO'),
#   (14176, 14183, 'I-TEMPO'),
#   (14184, 14186, 'I-TEMPO'),
#   (14187, 14191, 'I-TEMPO'),
#   (14203, 14212, 'B-ORGANIZACAO'),
#   (14213, 14223, 'I-ORGANIZACAO'),
#   (14224, 14226, 'I-ORGANIZACAO'),
#   (14227, 14237, 'I-ORGANIZACAO'),
#   (14238, 14246, 'I-ORGANIZACAO'),
#   (14249, 14253, 'B-ORGANIZACAO'),
#   (14261, 14270, 'B-ORGANIZACAO'),
#   (14271, 14273, 'I-ORGANIZACAO'),
#   (14274, 14284, 'I-ORGANIZACAO'),
#   (14285, 14294, 'I-ORGANIZACAO'),
#   (14295, 14296, 'I-ORGANIZACAO'),
#   (14297, 14306, 'I-ORGANIZACAO'),
#   (14307, 14315, 'I-ORGANIZACAO'),
#   (14318, 14323, 'B-ORGANIZACAO'),
#   (14349, 14355, 'B-LEGISLACAO'),
#   (14356, 14357, 'I-LEGISLACAO'),
#   (14358, 14361, 'I-LEGISLACAO'),
#   (14362, 14370, 'I-LEGISLACAO'),
#   (14371, 14374, 'I-LEGISLACAO'),
#   (14375, 14377, 'I-LEGISLACAO'),
#   (14383, 14385, 'B-TEMPO'),
#   (14386, 14388, 'I-TEMPO'),
#   (14389, 14397, 'I-TEMPO'),
#   (14398, 14400, 'I-TEMPO'),
#   (14401, 14405, 'I-TEMPO'),
#   (14416, 14424, 'B-TEMPO'),
#   (14490, 14498, 'B-ORGANIZACAO'),
#   (14499, 14506, 'I-ORGANIZACAO'),
#   (14522, 14528, 'B-ORGANIZACAO'),
#   (14529, 14540, 'I-ORGANIZACAO'),
#   (14659, 14667, 'B-LOCAL'),
#   (14668, 14675, 'I-LOCAL'),
#   (15014, 15022, 'B-ORGANIZACAO'),
#   (15023, 15030, 'I-ORGANIZACAO'),
#   (15492, 15500, 'B-ORGANIZACAO'),
#   (15501, 15508, 'I-ORGANIZACAO'),
#   (15826, 15834, 'B-LOCAL'),
#   (15835, 15842, 'I-LOCAL'),
#   (15944, 15952, 'B-ORGANIZACAO'),
#   (15953, 15960, 'I-ORGANIZACAO'),
#   (16014, 16017, 'B-LEGISLACAO'),
#   (16018, 16030, 'I-LEGISLACAO'),
#   (16031, 16033, 'I-LEGISLACAO'),
#   (16034, 16039, 'I-LEGISLACAO'),
#   (16092, 16095, 'B-LEGISLACAO'),
#   (16096, 16104, 'I-LEGISLACAO'),
#   (16105, 16107, 'I-LEGISLACAO'),
#   (16108, 16116, 'I-LEGISLACAO'),
#   (16117, 16124, 'I-LEGISLACAO'),
#   (16230, 16238, 'B-LOCAL'),
#   (16239, 16246, 'I-LOCAL'),
#   (16329, 16337, 'B-LOCAL'),
#   (16338, 16345, 'I-LOCAL'),
#   (16536, 16544, 'B-LOCAL'),
#   (16545, 16552, 'I-LOCAL'),
#   (16619, 16627, 'B-LOCAL'),
#   (16628, 16635, 'I-LOCAL'),
#   (16661, 16668, 'B-LEGISLACAO'),
#   (16669, 16671, 'I-LEGISLACAO'),
#   (16672, 16673, 'I-LEGISLACAO'),
#   (16674, 16680, 'I-LEGISLACAO'),
#   (16681, 16683, 'I-LEGISLACAO'),
#   (16684, 16685, 'I-LEGISLACAO'),
#   (16686, 16688, 'I-LEGISLACAO'),
#   (16689, 16690, 'I-LEGISLACAO'),
#   (16691, 16694, 'I-LEGISLACAO'),
#   (16695, 16696, 'I-LEGISLACAO'),
#   (16697, 16703, 'I-LEGISLACAO'),
#   (16704, 16706, 'I-LEGISLACAO'),
#   (16707, 16708, 'I-LEGISLACAO'),
#   (16709, 16711, 'I-LEGISLACAO'),
#   (16712, 16715, 'I-LEGISLACAO'),
#   (16716, 16724, 'I-LEGISLACAO'),
#   (16725, 16727, 'I-LEGISLACAO'),
#   (16728, 16736, 'I-LEGISLACAO'),
#   (16737, 16744, 'I-LEGISLACAO'),
#   (16809, 16812, 'B-LEGISLACAO'),
#   (16813, 16825, 'I-LEGISLACAO'),
#   (16826, 16828, 'I-LEGISLACAO'),
#   (16829, 16834, 'I-LEGISLACAO'),
#   (16862, 16868, 'B-ORGANIZACAO'),
#   (16869, 16880, 'I-ORGANIZACAO'),
#   (16881, 16883, 'I-ORGANIZACAO'),
#   (16884, 16892, 'I-ORGANIZACAO'),
#   (16893, 16900, 'I-ORGANIZACAO'),
#   (17125, 17128, 'B-LEGISLACAO'),
#   (17129, 17141, 'I-LEGISLACAO'),
#   (17142, 17151, 'I-LEGISLACAO'),
#   (17152, 17154, 'I-LEGISLACAO'),
#   (17155, 17157, 'I-LEGISLACAO'),
#   (17163, 17165, 'B-TEMPO'),
#   (17166, 17168, 'I-TEMPO'),
#   (17169, 17178, 'I-TEMPO'),
#   (17179, 17181, 'I-TEMPO'),
#   (17182, 17186, 'I-TEMPO'),
#   (17258, 17261, 'B-JURISPRUDENCIA'),
#   (17262, 17277, 'I-JURISPRUDENCIA'),
#   (17280, 17288, 'B-ORGANIZACAO'),
#   (17289, 17297, 'I-ORGANIZACAO'),
#   (17322, 17330, 'B-PESSOA'),
#   (17331, 17338, 'I-PESSOA'),
#   (17352, 17361, 'B-TEMPO'),
#   (17372, 17382, 'B-TEMPO'),
#   (17448, 17452, 'B-LEGISLACAO'),
#   (17453, 17467, 'I-LEGISLACAO'),
#   (17468, 17478, 'I-LEGISLACAO'),
#   (17479, 17481, 'I-LEGISLACAO'),
#   (17482, 17487, 'I-LEGISLACAO'),
#   (17490, 17495, 'B-LEGISLACAO'),
#   (17498, 17503, 'B-LEGISLACAO'),
#   (17506, 17511, 'B-LEGISLACAO'),
#   (17514, 17520, 'B-LEGISLACAO'),
#   (17523, 17529, 'B-LEGISLACAO'),
#   (17532, 17538, 'B-LEGISLACAO'),
#   (17541, 17547, 'B-LEGISLACAO'),
#   (17550, 17556, 'B-LEGISLACAO'),
#   (17559, 17565, 'B-LEGISLACAO'),
#   (17568, 17574, 'B-LEGISLACAO'),
#   (17577, 17583, 'B-LEGISLACAO'),
#   (17586, 17592, 'B-LEGISLACAO'),
#   (17595, 17601, 'B-LEGISLACAO'),
#   (17604, 17620, 'B-LEGISLACAO'),
#   (17888, 17896, 'B-LOCAL'),
#   (17897, 17904, 'I-LOCAL'),
#   (17958, 17961, 'B-LEGISLACAO'),
#   (17962, 17970, 'I-LEGISLACAO'),
#   (17971, 17973, 'I-LEGISLACAO'),
#   (17974, 17982, 'I-LEGISLACAO'),
#   (17983, 17990, 'I-LEGISLACAO'),
#   (18180, 18183, 'B-LEGISLACAO'),
#   (18184, 18185, 'I-LEGISLACAO'),
#   (18186, 18188, 'I-LEGISLACAO'),
#   (18189, 18191, 'I-LEGISLACAO'),
#   (18192, 18195, 'I-LEGISLACAO'),
#   (18196, 18198, 'I-LEGISLACAO'),
#   (18199, 18207, 'I-LEGISLACAO'),
#   (18240, 18243, 'B-JURISPRUDENCIA'),
#   (18244, 18259, 'I-JURISPRUDENCIA'),
#   (18262, 18270, 'B-ORGANIZACAO'),
#   (18271, 18279, 'I-ORGANIZACAO'),
#   (18304, 18310, 'B-PESSOA'),
#   (18311, 18322, 'I-PESSOA'),
#   (18336, 18345, 'B-TEMPO'),
#   (18356, 18366, 'B-TEMPO'),
#   (18466, 18469, 'B-LEGISLACAO'),
#   (18470, 18482, 'I-LEGISLACAO'),
#   (18483, 18492, 'I-LEGISLACAO'),
#   (18493, 18495, 'I-LEGISLACAO'),
#   (18496, 18499, 'I-LEGISLACAO'),
#   (18500, 18501, 'I-LEGISLACAO'),
#   (18502, 18504, 'I-LEGISLACAO'),
#   (18505, 18515, 'I-LEGISLACAO'),
#   (18581, 18594, 'B-LOCAL'),
#   (18597, 18599, 'B-LOCAL'),
#   (18600, 18602, 'I-LOCAL'),
#   (18668, 18671, 'B-LEGISLACAO'),
#   (18672, 18680, 'I-LEGISLACAO'),
#   (18681, 18683, 'I-LEGISLACAO'),
#   (18684, 18692, 'I-LEGISLACAO'),
#   (18693, 18700, 'I-LEGISLACAO'),
#   (18805, 18808, 'B-LEGISLACAO'),
#   (18809, 18821, 'I-LEGISLACAO'),
#   (18822, 18831, 'I-LEGISLACAO'),
#   (18832, 18834, 'I-LEGISLACAO'),
#   (18835, 18838, 'I-LEGISLACAO'),
#   (18844, 18846, 'B-TEMPO'),
#   (18847, 18849, 'I-TEMPO'),
#   (18850, 18858, 'I-TEMPO'),
#   (18859, 18861, 'I-TEMPO'),
#   (18862, 18866, 'I-TEMPO'),
#   (18972, 18985, 'B-LOCAL'),
#   (18986, 18992, 'B-LOCAL'),
#   (18993, 19007, 'I-LOCAL'),
#   (19008, 19010, 'I-LOCAL'),
#   (19157, 19165, 'B-LOCAL'),
#   (19166, 19173, 'I-LOCAL'),
#   (19331, 19334, 'B-JURISPRUDENCIA'),
#   (19335, 19350, 'I-JURISPRUDENCIA'),
#   (19353, 19361, 'B-ORGANIZACAO'),
#   (19362, 19370, 'I-ORGANIZACAO'),
#   (19395, 19399, 'B-PESSOA'),
#   (19400, 19406, 'I-PESSOA'),
#   (19420, 19429, 'B-TEMPO'),
#   (19440, 19449, 'B-TEMPO'),
#   (19508, 19516, 'B-ORGANIZACAO'),
#   (19517, 19524, 'I-ORGANIZACAO'),
#   (19576, 19583, 'B-LEGISLACAO'),
#   (19584, 19587, 'I-LEGISLACAO'),
#   (19588, 19599, 'I-LEGISLACAO'),
#   (19605, 19613, 'B-LEGISLACAO'),
#   (19614, 19617, 'I-LEGISLACAO'),
#   (19618, 19626, 'I-LEGISLACAO'),
#   (19632, 19641, 'B-ORGANIZACAO'),
#   (19642, 19652, 'I-ORGANIZACAO'),
#   (19653, 19655, 'I-ORGANIZACAO'),
#   (19656, 19666, 'I-ORGANIZACAO'),
#   (19667, 19676, 'I-ORGANIZACAO'),
#   (19677, 19678, 'I-ORGANIZACAO'),
#   (19679, 19688, 'I-ORGANIZACAO'),
#   (19689, 19697, 'I-ORGANIZACAO'),
#   (19698, 19703, 'B-ORGANIZACAO'),
#   (19837, 19845, 'B-LOCAL'),
#   (19846, 19853, 'I-LOCAL'),
#   (19882, 19888, 'B-ORGANIZACAO'),
#   (19889, 19900, 'I-ORGANIZACAO'),
#   (19956, 19962, 'B-LEGISLACAO'),
#   (19963, 19965, 'I-LEGISLACAO'),
#   (19966, 19967, 'I-LEGISLACAO'),
#   (19968, 19972, 'I-LEGISLACAO'),
#   (19973, 19975, 'I-LEGISLACAO'),
#   (19976, 19977, 'I-LEGISLACAO'),
#   (19978, 19980, 'I-LEGISLACAO'),
#   (19981, 19984, 'I-LEGISLACAO'),
#   (19985, 19993, 'I-LEGISLACAO'),
#   (19994, 19996, 'I-LEGISLACAO'),
#   (19997, 20005, 'I-LEGISLACAO'),
#   (20006, 20013, 'I-LEGISLACAO'),
#   (20068, 20076, 'B-ORGANIZACAO'),
#   (20077, 20084, 'I-ORGANIZACAO'),
#   (20133, 20141, 'B-LOCAL'),
#   (20259, 20266, 'B-LEGISLACAO'),
#   (20267, 20269, 'I-LEGISLACAO'),
#   (20270, 20276, 'I-LEGISLACAO'),
#   (20282, 20283, 'B-TEMPO'),
#   (20284, 20286, 'I-TEMPO'),
#   (20287, 20294, 'I-TEMPO'),
#   (20295, 20297, 'I-TEMPO'),
#   (20298, 20302, 'I-TEMPO'),
#   (20310, 20318, 'B-LEGISLACAO'),
#   (20319, 20320, 'I-LEGISLACAO'),
#   (20321, 20324, 'I-LEGISLACAO'),
#   (20330, 20332, 'B-TEMPO'),
#   (20333, 20335, 'I-TEMPO'),
#   (20336, 20343, 'I-TEMPO'),
#   (20344, 20346, 'I-TEMPO'),
#   (20347, 20351, 'I-TEMPO'),
#   (20363, 20372, 'B-ORGANIZACAO'),
#   (20373, 20383, 'I-ORGANIZACAO'),
#   (20384, 20386, 'I-ORGANIZACAO'),
#   (20387, 20397, 'I-ORGANIZACAO'),
#   (20398, 20406, 'I-ORGANIZACAO'),
#   (20407, 20411, 'B-ORGANIZACAO'),
#   (20419, 20428, 'B-ORGANIZACAO'),
#   (20429, 20431, 'I-ORGANIZACAO'),
#   (20432, 20442, 'I-ORGANIZACAO'),
#   (20443, 20452, 'I-ORGANIZACAO'),
#   (20453, 20454, 'I-ORGANIZACAO'),
#   (20455, 20464, 'I-ORGANIZACAO'),
#   (20465, 20473, 'I-ORGANIZACAO'),
#   (20474, 20480, 'B-ORGANIZACAO'),
#   (20550, 20558, 'B-LEGISLACAO'),
#   (20559, 20562, 'I-LEGISLACAO'),
#   (20563, 20571, 'I-LEGISLACAO'),
#   (20600, 20608, 'B-LOCAL'),
#   (20609, 20616, 'I-LOCAL'),
#   (20751, 20759, 'B-LOCAL'),
#   (20760, 20767, 'I-LOCAL'),
#   (20813, 20821, 'B-LOCAL'),
#   (20822, 20829, 'I-LOCAL'),
#   (20930, 20938, 'B-LOCAL'),
#   (20939, 20947, 'I-LOCAL'),
#   (20985, 20992, 'B-LEGISLACAO'),
#   (20993, 20996, 'I-LEGISLACAO'),
#   (20997, 21006, 'I-LEGISLACAO'),
#   (21033, 21036, 'B-LEGISLACAO'),
#   (21037, 21045, 'I-LEGISLACAO'),
#   (21046, 21048, 'I-LEGISLACAO'),
#   (21049, 21057, 'I-LEGISLACAO'),
#   (21058, 21065, 'I-LEGISLACAO'),
#   (21086, 21092, 'B-LEGISLACAO'),
#   (21093, 21096, 'I-LEGISLACAO'),
#   (21097, 21102, 'I-LEGISLACAO'),
#   (21111, 21117, 'B-LEGISLACAO'),
#   (21118, 21121, 'I-LEGISLACAO'),
#   (21122, 21123, 'I-LEGISLACAO'),
#   (21124, 21128, 'I-LEGISLACAO'),
#   (21129, 21131, 'I-LEGISLACAO'),
#   (21132, 21133, 'I-LEGISLACAO'),
#   (21134, 21136, 'I-LEGISLACAO'),
#   (21137, 21141, 'I-LEGISLACAO'),
#   (21197, 21205, 'B-LOCAL'),
#   (21206, 21213, 'I-LOCAL'),
#   (21292, 21300, 'B-LOCAL'),
#   (21301, 21308, 'I-LOCAL'),
#   (21325, 21332, 'B-LEGISLACAO'),
#   (21333, 21336, 'I-LEGISLACAO'),
#   (21337, 21346, 'I-LEGISLACAO'),
#   (21351, 21359, 'B-LEGISLACAO'),
#   (21360, 21363, 'I-LEGISLACAO'),
#   (21364, 21370, 'I-LEGISLACAO'),
#   (21376, 21381, 'B-ORGANIZACAO'),
#   (21526, 21529, 'B-LEGISLACAO'),
#   (21530, 21531, 'I-LEGISLACAO'),
#   (21532, 21534, 'I-LEGISLACAO'),
#   (21535, 21536, 'I-LEGISLACAO'),
#   (21537, 21539, 'I-LEGISLACAO'),
#   (21540, 21544, 'I-LEGISLACAO'),
#   (21742, 21750, 'B-LOCAL'),
#   (21751, 21758, 'I-LOCAL'),
#   (21931, 21935, 'B-LEGISLACAO'),
#   (21936, 21946, 'I-LEGISLACAO'),
#   (21947, 21950, 'I-LEGISLACAO'),
#   (21951, 21954, 'I-LEGISLACAO'),
#   (21960, 21962, 'B-TEMPO'),
#   (21963, 21965, 'I-TEMPO'),
#   (21966, 21972, 'I-TEMPO'),
#   (21973, 21975, 'I-TEMPO'),
#   (21976, 21980, 'I-TEMPO'),
#   (21985, 21990, 'B-LEGISLACAO'),
#   (21996, 21998, 'B-TEMPO'),
#   (21999, 22001, 'I-TEMPO'),
#   (22002, 22007, 'I-TEMPO'),
#   (22008, 22010, 'I-TEMPO'),
#   (22011, 22015, 'I-TEMPO'),
#   (22023, 22026, 'B-LEGISLACAO'),
#   (22027, 22039, 'I-LEGISLACAO'),
#   (22040, 22049, 'I-LEGISLACAO'),
#   (22050, 22053, 'I-LEGISLACAO'),
#   (22054, 22057, 'I-LEGISLACAO'),
#   (22063, 22064, 'B-TEMPO'),
#   (22065, 22067, 'I-TEMPO'),
#   (22068, 22073, 'I-TEMPO'),
#   (22074, 22076, 'I-TEMPO'),
#   (22077, 22081, 'I-TEMPO'),
#   (22118, 22122, 'B-PESSOA'),
#   (22123, 22130, 'I-PESSOA'),
#   (22233, 22245, 'B-LEGISLACAO'),
#   (22246, 22248, 'I-LEGISLACAO'),
#   (22249, 22253, 'I-LEGISLACAO'),
#   (22431, 22439, 'B-ORGANIZACAO'),
#   (22440, 22447, 'I-ORGANIZACAO'),
#   (22613, 22618, 'B-PESSOA'),
#   (22619, 22621, 'I-PESSOA'),
#   (22622, 22627, 'I-PESSOA'),
#   (23514, 23520, 'B-ORGANIZACAO'),
#   (23521, 23532, 'I-ORGANIZACAO'),
#   (23551, 23559, 'B-LOCAL'),
#   (23560, 23567, 'I-LOCAL'),
#   (23634, 23641, 'B-ORGANIZACAO'),
#   (23815, 23818, 'B-LEGISLACAO'),
#   (23819, 23827, 'I-LEGISLACAO'),
#   (23828, 23830, 'I-LEGISLACAO'),
#   (23831, 23839, 'I-LEGISLACAO'),
#   (23840, 23847, 'I-LEGISLACAO'),
#   (24002, 24010, 'B-ORGANIZACAO'),
#   (24011, 24018, 'I-ORGANIZACAO'),
#   (24082, 24092, 'B-ORGANIZACAO'),
#   (24093, 24100, 'I-ORGANIZACAO'),
#   (24131, 24141, 'B-ORGANIZACAO'),
#   (24142, 24149, 'I-ORGANIZACAO'),
#   (24160, 24168, 'B-ORGANIZACAO'),
#   (24169, 24176, 'I-ORGANIZACAO'),
#   (24599, 24604, 'B-PESSOA'),
#   (24605, 24607, 'I-PESSOA'),
#   (24608, 24616, 'I-PESSOA'),
#   (24680, 24684, 'B-PESSOA'),
#   (24685, 24692, 'I-PESSOA'),
#   (24881, 24886, 'B-PESSOA'),
#   (24887, 24893, 'I-PESSOA'),
#   (24995, 25003, 'B-LOCAL'),
#   (25004, 25011, 'I-LOCAL'),
#   (25076, 25080, 'B-LEGISLACAO'),
#   (25081, 25091, 'I-LEGISLACAO'),
#   (25092, 25094, 'I-LEGISLACAO'),
#   (25095, 25098, 'I-LEGISLACAO'),
#   (25104, 25106, 'B-TEMPO'),
#   (25107, 25109, 'I-TEMPO'),
#   (25110, 25116, 'I-TEMPO'),
#   (25117, 25119, 'I-TEMPO'),
#   (25120, 25124, 'I-TEMPO'),
#   (25129, 25131, 'B-LEGISLACAO'),
#   (25132, 25137, 'I-LEGISLACAO'),
#   (25143, 25145, 'B-TEMPO'),
#   (25146, 25148, 'I-TEMPO'),
#   (25149, 25154, 'I-TEMPO'),
#   (25155, 25157, 'I-TEMPO'),
#   (25158, 25162, 'I-TEMPO'),
#   (25177, 25180, 'B-LEGISLACAO'),
#   (25181, 25193, 'I-LEGISLACAO'),
#   (25194, 25196, 'I-LEGISLACAO'),
#   (25197, 25200, 'I-LEGISLACAO'),
#   (25206, 25207, 'B-TEMPO'),
#   (25208, 25210, 'I-TEMPO'),
#   ...]}

# %%
conteudo.find('Conselho Especial')
# Out:
# 8

# %%
conteudo.find('Conselho Especial') + len('Conselho Especial')
# Out:
# 25

# %% [markdown]
# # Transformando todos os dados

# %%
arquivos = grupos_arquivos.groups.keys()

# %%
# arquivos

# %%
documentos = []

# Itera sobre cada arquivo na lista de arquivos
for arquivo in arquivos:
    documento = []  # Inicializa a estrutura do documento
    
    # Obtém a tabela de palavras e rótulos associadas ao arquivo
    tabela_agrupada = grupos_arquivos.get_group(arquivo)[['palavra', 'label']].values
    
    # Inicializa variáveis para armazenar o conteúdo e anotações do documento
    conteudo = ''
    anotacoes = {'entities': []}
    
    # Variáveis para rastrear as posições das palavras dentro do texto
    inicio_palavra = 0
    fim_palavra = 0
    
    # Itera sobre cada palavra e seu respectivo rótulo na tabela agrupada
    for texto, label in tabela_agrupada:
        texto = str(texto)  # Converte o texto para string, se necessário
        tamanho_texto = len(texto) + 1  # Calcula o tamanho da palavra incluindo o espaço
        
        # Define os índices de início e fim da palavra dentro do conteúdo total
        inicio_palavra = fim_palavra
        fim_palavra = inicio_palavra + tamanho_texto
        
        # Se a palavra possuir um rótulo diferente de 'O', registra a anotação
        if label != 'O':
            anotacao = (inicio_palavra, fim_palavra - 1, label)
            anotacoes['entities'].append(anotacao)
        
        # Concatena a palavra ao conteúdo do documento, adicionando um espaço
        conteudo = conteudo + texto + ' '
    
    # Estrutura o documento com seu conteúdo e respectivas anotações
    documento = (conteudo, anotacoes)
    
    # Adiciona o documento processado à lista de documentos
    documentos.append(documento)

# %%
# documentos

# %% [markdown]
# **Separando dados de treino e validação**

# %%
import random

# %%
random.shuffle(documentos)

# %%
# documentos

# %%
len(documentos)
# Out:
# 50

# %%
dados_treino = documentos[:40]
dados_validacao = documentos[40:]

# %%
dados_treino
# Out:
# [("Ementa e Acórdão 11/12/2012 PRIMEIRA TURMA HABEAS CORPUS 110.260 SÃO PAULO RELATOR : MIN . LUIZ FUX PACTE . ( S ) : LAERCIO BRAZ PEREIRA SALES IMPTE . ( S ) : DEFENSORIA PÚBLICA DA UNIÃO PROC . ( A/S ) ( ES ) : DEFENSOR PÚBLICO-GERAL FEDERAL COATOR ( A/S ) ( ES ) : SUPERIOR TRIBUNAL DE JUSTIÇA EMENTA : PROCESSUAL PENAL E CONSTITUCIONAL . HABEAS CORPUS SUBSTITUTIVO DE RECURSO ORDINÁRIO CONSTITUCIONAL . COMPETÊNCIA DO SUPREMO TRIBUNAL PARA JULGAR HABEAS CORPUS : CF , ART . 102 , I , ‘ D ’ E ‘ I ’ . ROL TAXATIVO . MATÉRIA DE DIREITO ESTRITO . INTERPRETAÇÃO EXTENSIVA : PARADOXO . ORGANICIDADE DO DIREITO . AUSÊNCIA DE TERATOLOGIA OU ERROR IN JUDICANDO NO ATO IMPUGNADO . INVIABILIDADE DA ATUAÇÃO , EX OFFICIO , DO SUPREMO TRIBUNAL FEDERAL . HOMICÍDIOS DUPLAMENTE QUALIFICADOS , nan FORMA TENTADA , PRATICADOS CONTRA CÔNJUGE E DESCENDENTE ( CP , ART . 121 , § 2 º , II E IV , C / C ART . 61 , II , E , E 14 , II ) . PRONÚNCIA . EXCESSO DE LINGUAGEM QUANTO AOS CRIMES E ÀS QUALIFICADORAS . INOCORRÊNCIA : MERA REPRODUÇÃO DOS INTERROGATÓRIOS . ANIMUS NECANDI : LINGUAGEM COMEDIDA ( ART . 413 , § 1 º , DO DO CPP . EQUILÍBRIO COM A PRETENDIDA DESCLASSIFICAÇÃO DOS HOMICÍDIOS PARA LESÕES CORPORAIS . FUNDAMENTAÇÃO DAS DECISÕES DO PODER JUDICIÁRIO . ART . 93 , IX , DA CF . 1 . A competência originária do Supremo Tribunal Federal para conhecer e julgar habeas corpus está definida , taxativamente , no artigo 102 , inciso I , alíneas “ d ” e “ i ” , da Constituição Federal , sendo certo que o paciente não está inserido em nenhuma das hipóteses sujeitas à jurisdição desta Corte . 2 . Inexistente teratologia ou error in judicando no acórdão impugnado , resta inviabilizada a atuação ex officio do Supremo Tribunal Federal . 3 . O artigo 413 do Código de Processo Penal determina que “ O juiz , fundamentadamente , pronunciará o acusado , se convencido da materialidade do fato e da existência de indícios suficientes de autoria ou de participação ” , ao Supremo Tribunal Federal Documento assinado digitalmente conforme MP n° 2.200-2/2001 de 24/08/2001 , que institui a Infraestrutura de Chaves Públicas Brasileira - ICP-Brasil . O documento pode ser acessado no endereço eletrônico http : //www.stf.jus.br/portal/autenticacao/ sob o número 3373812 . Supremo Tribunal Federal Inteiro Teor do Acórdão - Página 1 de 20 Ementa e Acórdão HC 110260 / SP passo que seu § 1º estabelece que “ A fundamentação da pronúncia limitar-seá à indicação da materialidade do fato e da existência de indícios suficientes de autoria ou de participação , devendo o juiz declarar o dispositivo legal em que julgar incurso o acusado e especificar as circunstâncias qualificadoras e as causas de aumento de pena ” . 4 . In casu , o paciente foi pronunciado por homicídios duplamente qualificados motivo fútil e emboscada - , na forma tentada ( CP , art . 121 , § 2º , II e IV , c/c art . 14 , II ) , praticados contra a esposa e o filho , tendo as instâncias precedentes refutado a alegação de excesso de linguagem na sentença de pronúncia . 5 . A fundamentação da sentença de pronúncia não se desbordou do figurino legal , por isso não ostenta a nulidade ora suscitada , ressaindo nítido que o Magistrado ateve-se ao relato dos fatos , revelados nos interrogatórios das vítimas , para concluir , fundamentadamente , pela existência de indícios suficientes de autoria e de materialidade , como exigido pelo artigo 413 , por imposição do disposto no art . 93 , IX , da constituição Federal . Precedentes : HC 89420/RS - Relator Min . EROS GRAU , 2ª Turma , DJ de 07/12/2006 6 . A afirmação , na pronúncia , tida como verbalmente excessiva , de que “ a integridade corporal da vítima com disparos de revólver contra região vital do corpo dela o acusado revelou animus necandi , na medida em que essa não é a conduta de quem objetiva somente lesionar ou assustar pois esse resultado poderia ser obtido de maneira menos ofensiva , por exemplo , mediante agressão com as mãos ou utilizando algum instrumento sem potencialidad ...
#   {'entities': [(17, 27, 'B-TEMPO'),
#     (28, 36, 'B-ORGANIZACAO'),
#     (37, 42, 'I-ORGANIZACAO'),
#     (43, 49, 'B-JURISPRUDENCIA'),
#     (50, 56, 'I-JURISPRUDENCIA'),
#     (57, 64, 'I-JURISPRUDENCIA'),
#     (65, 68, 'B-LOCAL'),
#     (69, 74, 'I-LOCAL'),
#     (91, 95, 'B-PESSOA'),
#     (96, 99, 'I-PESSOA'),
#     (116, 123, 'B-PESSOA'),
#     (124, 128, 'I-PESSOA'),
#     (129, 136, 'I-PESSOA'),
#     (137, 142, 'I-PESSOA'),
#     (159, 169, 'B-ORGANIZACAO'),
#     (170, 177, 'I-ORGANIZACAO'),
#     (178, 180, 'I-ORGANIZACAO'),
#     (181, 186, 'I-ORGANIZACAO'),
#     (266, 274, 'B-ORGANIZACAO'),
#     (275, 283, 'I-ORGANIZACAO'),
#     (284, 286, 'I-ORGANIZACAO'),
#     (287, 294, 'I-ORGANIZACAO'),
#     (420, 427, 'B-ORGANIZACAO'),
#     (428, 436, 'I-ORGANIZACAO'),
#     (465, 467, 'B-LEGISLACAO'),
#     (468, 469, 'I-LEGISLACAO'),
#     (470, 473, 'I-LEGISLACAO'),
#     (474, 475, 'I-LEGISLACAO'),
#     (476, 479, 'I-LEGISLACAO'),
#     (480, 481, 'I-LEGISLACAO'),
#     (482, 483, 'I-LEGISLACAO'),
#     (484, 485, 'I-LEGISLACAO'),
#     (486, 487, 'I-LEGISLACAO'),
#     (488, 489, 'I-LEGISLACAO'),
#     (490, 491, 'I-LEGISLACAO'),
#     (492, 493, 'I-LEGISLACAO'),
#     (494, 495, 'I-LEGISLACAO'),
#     (496, 497, 'I-LEGISLACAO'),
#     (498, 499, 'I-LEGISLACAO'),
#     (717, 724, 'B-ORGANIZACAO'),
#     (725, 733, 'I-ORGANIZACAO'),
#     (734, 741, 'I-ORGANIZACAO'),
#     (843, 845, 'B-LEGISLACAO'),
#     (846, 847, 'I-LEGISLACAO'),
#     (848, 851, 'I-LEGISLACAO'),
#     (852, 853, 'I-LEGISLACAO'),
#     (854, 857, 'I-LEGISLACAO'),
#     (858, 859, 'I-LEGISLACAO'),
#     (860, 861, 'I-LEGISLACAO'),
#     (862, 863, 'I-LEGISLACAO'),
#     (864, 865, 'I-LEGISLACAO'),
#     (866, 867, 'I-LEGISLACAO'),
#     (868, 870, 'I-LEGISLACAO'),
#     (871, 872, 'I-LEGISLACAO'),
#     (873, 875, 'I-LEGISLACAO'),
#     (876, 877, 'I-LEGISLACAO'),
#     (878, 879, 'I-LEGISLACAO'),
#     (880, 881, 'I-LEGISLACAO'),
#     (882, 883, 'I-LEGISLACAO'),
#     (884, 887, 'I-LEGISLACAO'),
#     (888, 889, 'I-LEGISLACAO'),
#     (890, 892, 'I-LEGISLACAO'),
#     (893, 894, 'I-LEGISLACAO'),
#     (895, 897, 'I-LEGISLACAO'),
#     (898, 899, 'I-LEGISLACAO'),
#     (900, 901, 'I-LEGISLACAO'),
#     (902, 903, 'I-LEGISLACAO'),
#     (904, 905, 'I-LEGISLACAO'),
#     (906, 908, 'I-LEGISLACAO'),
#     (909, 910, 'I-LEGISLACAO'),
#     (911, 913, 'I-LEGISLACAO'),
#     (1082, 1085, 'B-LEGISLACAO'),
#     (1086, 1087, 'I-LEGISLACAO'),
#     (1088, 1091, 'I-LEGISLACAO'),
#     (1092, 1093, 'I-LEGISLACAO'),
#     (1094, 1095, 'I-LEGISLACAO'),
#     (1096, 1097, 'I-LEGISLACAO'),
#     (1098, 1099, 'I-LEGISLACAO'),
#     (1100, 1101, 'I-LEGISLACAO'),
#     (1102, 1104, 'I-LEGISLACAO'),
#     (1105, 1107, 'I-LEGISLACAO'),
#     (1108, 1111, 'I-LEGISLACAO'),
#     (1247, 1250, 'B-LEGISLACAO'),
#     (1251, 1252, 'I-LEGISLACAO'),
#     (1253, 1255, 'I-LEGISLACAO'),
#     (1256, 1257, 'I-LEGISLACAO'),
#     (1258, 1260, 'I-LEGISLACAO'),
#     (1261, 1262, 'I-LEGISLACAO'),
#     (1263, 1265, 'I-LEGISLACAO'),
#     (1266, 1268, 'I-LEGISLACAO'),
#     (1303, 1310, 'B-ORGANIZACAO'),
#     (1311, 1319, 'I-ORGANIZACAO'),
#     (1320, 1327, 'I-ORGANIZACAO'),
#     (1400, 1406, 'B-LEGISLACAO'),
#     (1407, 1410, 'I-LEGISLACAO'),
#     (1411, 1412, 'I-LEGISLACAO'),
#     (1413, 1419, 'I-LEGISLACAO'),
#     (1420, 1421, 'I-LEGISLACAO'),
#     (1422, 1423, 'I-LEGISLACAO'),
#     (1424, 1431, 'I-LEGISLACAO'),
#     (1432, 1433, 'I-LEGISLACAO'),
#     (1434, 1435, 'I-LEGISLACAO'),
#     (1436, 1437, 'I-LEGISLACAO'),
#     (1438, 1439, 'I-LEGISLACAO'),
#     (1440, 1441, 'I-LEGISLACAO'),
#     (1442, 1443, 'I-LEGISLACAO'),
#     (1444, 1445, 'I-LEGISLACAO'),
#     (1446, 1447, 'I-LEGISLACAO'),
#     (1448, 1450, 'I-LEGISLACAO'),
#     (1451, 1463, 'I-LEGISLACAO'),
#     (1464, 1471, 'I-LEGISLACAO'),
#     (1697, 1704, 'B-ORGANIZACAO'),
#     (1705, 1713, 'I-ORGANIZACAO'),
#     (1714, 1721, 'I-ORGANIZACAO'),
#     (1730, 1736, 'B-LEGISLACAO'),
#     (1737, 1740, 'I-LEGISLACAO'),
#     (1741, 1743, 'I-LEGISLACAO'),
#     (1744, 1750, 'I-LEGISLACAO'),
#     (1751, 1753, 'I-LEGISLACAO'),
#     (1754, 1762, 'I-LEGISLACAO'),
#     (1763, 1768, 'I-LEGISLACAO'),
#     (1954, 1961, 'B-ORGANIZACAO'),
#     (1962, 1970, 'I-ORGANIZACAO'),
#     (1971, 1978, 'I-ORGANIZACAO'),
#     (2020, 2022, 'B-LEGISLACAO'),
#     (2023, 2025, 'I-LEGISLACAO'),
#     (2026, 2038, 'I-LEGISLACAO'),
#     (2042, 2052, 'B-TEMPO'),
#     (2070, 2084, 'B-ORGANIZACAO'),
#     (2085, 2087, 'I-ORGANIZACAO'),
#     (2088, 2094, 'I-ORGANIZACAO'),
#     (2095, 2103, 'I-ORGANIZACAO'),
#     (2104, 2114, 'I-ORGANIZACAO'),
#     (2117, 2127, 'B-ORGANIZACAO'),
#     (2251, 2258, 'B-ORGANIZACAO'),
#     (2259, 2267, 'I-ORGANIZACAO'),
#     (2268, 2275, 'I-ORGANIZACAO'),
#     (2334, 2336, 'B-JURISPRUDENCIA'),
#     (2337, 2343, 'I-JURISPRUDENCIA'),
#     (2344, 2345, 'I-JURISPRUDENCIA'),
#     (2346, 2348, 'I-JURISPRUDENCIA'),
#     (2821, 2823, 'B-LEGISLACAO'),
#     (2824, 2825, 'I-LEGISLACAO'),
#     (2826, 2829, 'I-LEGISLACAO'),
#     (2830, 2831, 'I-LEGISLACAO'),
#     (2832, 2835, 'I-LEGISLACAO'),
#     (2836, 2837, 'I-LEGISLACAO'),
#     (2838, 2839, 'I-LEGISLACAO'),
#     (2840, 2842, 'I-LEGISLACAO'),
#     (2843, 2844, 'I-LEGISLACAO'),
#     (2845, 2847, 'I-LEGISLACAO'),
#     (2848, 2849, 'I-LEGISLACAO'),
#     (2850, 2852, 'I-LEGISLACAO'),
#     (2853, 2854, 'I-LEGISLACAO'),
#     (2855, 2858, 'I-LEGISLACAO'),
#     (2859, 2862, 'I-LEGISLACAO'),
#     (2863, 2864, 'I-LEGISLACAO'),
#     (2865, 2867, 'I-LEGISLACAO'),
#     (2868, 2869, 'I-LEGISLACAO'),
#     (2870, 2872, 'I-LEGISLACAO'),
#     (3426, 3429, 'B-LEGISLACAO'),
#     (3430, 3431, 'I-LEGISLACAO'),
#     (3432, 3434, 'I-LEGISLACAO'),
#     (3435, 3436, 'I-LEGISLACAO'),
#     (3437, 3439, 'I-LEGISLACAO'),
#     (3440, 3441, 'I-LEGISLACAO'),
#     (3442, 3444, 'I-LEGISLACAO'),
#     (3445, 3457, 'I-LEGISLACAO'),
#     (3458, 3465, 'I-LEGISLACAO'),
#     (3482, 3484, 'B-JURISPRUDENCIA'),
#     (3485, 3493, 'I-JURISPRUDENCIA'),
#     (3510, 3514, 'B-PESSOA'),
#     (3515, 3519, 'I-PESSOA'),
#     (3522, 3524, 'B-ORGANIZACAO'),
#     (3525, 3530, 'I-ORGANIZACAO'),
#     (3539, 3549, 'B-TEMPO'),
#     (4317, 4321, 'B-LEGISLACAO'),
#     (4322, 4323, 'I-LEGISLACAO'),
#     (4324, 4327, 'I-LEGISLACAO'),
#     (4328, 4329, 'I-LEGISLACAO'),
#     (4330, 4331, 'I-LEGISLACAO'),
#     (4332, 4334, 'I-LEGISLACAO'),
#     (4335, 4336, 'I-LEGISLACAO'),
#     (4337, 4339, 'I-LEGISLACAO'),
#     (4340, 4343, 'I-LEGISLACAO'),
#     (4346, 4348, 'B-LEGISLACAO'),
#     (4349, 4350, 'I-LEGISLACAO'),
#     (4351, 4353, 'I-LEGISLACAO'),
#     (4354, 4355, 'I-LEGISLACAO'),
#     (4356, 4358, 'I-LEGISLACAO'),
#     (4359, 4371, 'I-LEGISLACAO'),
#     (4372, 4379, 'I-LEGISLACAO'),
#     (4503, 4510, 'B-ORGANIZACAO'),
#     (4511, 4519, 'I-ORGANIZACAO'),
#     (4520, 4527, 'I-ORGANIZACAO'),
#     (4569, 4571, 'B-LEGISLACAO'),
#     (4572, 4574, 'I-LEGISLACAO'),
#     (4575, 4587, 'I-LEGISLACAO'),
#     (4591, 4601, 'B-TEMPO'),
#     (4619, 4633, 'B-ORGANIZACAO'),
#     (4634, 4636, 'I-ORGANIZACAO'),
#     (4637, 4643, 'I-ORGANIZACAO'),
#     (4644, 4652, 'I-ORGANIZACAO'),
#     (4653, 4663, 'I-ORGANIZACAO'),
#     (4666, 4676, 'B-ORGANIZACAO'),
#     (4800, 4807, 'B-ORGANIZACAO'),
#     (4808, 4816, 'I-ORGANIZACAO'),
#     (4817, 4824, 'I-ORGANIZACAO'),
#     (4825, 4827, 'B-JURISPRUDENCIA'),
#     (4828, 4834, 'I-JURISPRUDENCIA'),
#     (4835, 4836, 'I-JURISPRUDENCIA'),
#     (4837, 4839, 'I-JURISPRUDENCIA'),
#     (5312, 5314, 'B-LEGISLACAO'),
#     (5315, 5316, 'I-LEGISLACAO'),
#     (5317, 5320, 'I-LEGISLACAO'),
#     (5321, 5322, 'I-LEGISLACAO'),
#     (5323, 5326, 'I-LEGISLACAO'),
#     (5327, 5328, 'I-LEGISLACAO'),
#     (5329, 5330, 'I-LEGISLACAO'),
#     (5331, 5333, 'I-LEGISLACAO'),
#     (5334, 5335, 'I-LEGISLACAO'),
#     (5336, 5338, 'I-LEGISLACAO'),
#     (5339, 5340, 'I-LEGISLACAO'),
#     (5341, 5343, 'I-LEGISLACAO'),
#     (5344, 5345, 'I-LEGISLACAO'),
#     (5346, 5349, 'I-LEGISLACAO'),
#     (5350, 5353, 'I-LEGISLACAO'),
#     (5354, 5355, 'I-LEGISLACAO'),
#     (5356, 5358, 'I-LEGISLACAO'),
#     (5359, 5360, 'I-LEGISLACAO'),
#     (5361, 5363, 'I-LEGISLACAO'),
#     (5917, 5920, 'B-LEGISLACAO'),
#     (5921, 5922, 'I-LEGISLACAO'),
#     (5923, 5925, 'I-LEGISLACAO'),
#     (5926, 5927, 'I-LEGISLACAO'),
#     (5928, 5930, 'I-LEGISLACAO'),
#     (5931, 5932, 'I-LEGISLACAO'),
#     (5933, 5935, 'I-LEGISLACAO'),
#     (5936, 5948, 'I-LEGISLACAO'),
#     (5949, 5956, 'I-LEGISLACAO'),
#     (5973, 5975, 'B-JURISPRUDENCIA'),
#     (5976, 5984, 'I-JURISPRUDENCIA'),
#     (6001, 6005, 'B-PESSOA'),
#     (6006, 6010, 'I-PESSOA'),
#     (6013, 6015, 'B-ORGANIZACAO'),
#     (6016, 6021, 'I-ORGANIZACAO'),
#     (6030, 6040, 'B-TEMPO'),
#     (6808, 6812, 'B-LEGISLACAO'),
#     (6813, 6814, 'I-LEGISLACAO'),
#     (6815, 6818, 'I-LEGISLACAO'),
#     (6819, 6820, 'I-LEGISLACAO'),
#     (6821, 6822, 'I-LEGISLACAO'),
#     (6823, 6825, 'I-LEGISLACAO'),
#     (6826, 6827, 'I-LEGISLACAO'),
#     (6828, 6830, 'I-LEGISLACAO'),
#     (6831, 6834, 'I-LEGISLACAO'),
#     (6837, 6839, 'B-LEGISLACAO'),
#     (6840, 6841, 'I-LEGISLACAO'),
#     (6842, 6844, 'I-LEGISLACAO'),
#     (6845, 6846, 'I-LEGISLACAO'),
#     (6847, 6849, 'I-LEGISLACAO'),
#     (6850, 6862, 'I-LEGISLACAO'),
#     (6863, 6870, 'I-LEGISLACAO'),
#     (6994, 7001, 'B-ORGANIZACAO'),
#     (7002, 7010, 'I-ORGANIZACAO'),
#     (7060, 7062, 'B-LEGISLACAO'),
#     (7063, 7065, 'I-LEGISLACAO'),
#     (7066, 7078, 'I-LEGISLACAO'),
#     (7082, 7092, 'B-TEMPO'),
#     (7110, 7124, 'B-ORGANIZACAO'),
#     (7125, 7127, 'I-ORGANIZACAO'),
#     (7128, 7134, 'I-ORGANIZACAO'),
#     (7135, 7143, 'I-ORGANIZACAO'),
#     (7144, 7154, 'I-ORGANIZACAO'),
#     (7157, 7167, 'B-ORGANIZACAO'),
#     (7349, 7351, 'B-JURISPRUDENCIA'),
#     (7352, 7358, 'I-JURISPRUDENCIA'),
#     (7359, 7360, 'I-JURISPRUDENCIA'),
#     (7361, 7363, 'I-JURISPRUDENCIA'),
#     (7364, 7372, 'B-ORGANIZACAO'),
#     (7373, 7378, 'I-ORGANIZACAO'),
#     (7382, 7389, 'B-ORGANIZACAO'),
#     (7390, 7398, 'I-ORGANIZACAO'),
#     (7399, 7406, 'I-ORGANIZACAO'),
#     (7446, 7450, 'B-PESSOA'),
#     (7451, 7458, 'I-PESSOA'),
#     (7664, 7672, 'B-LOCAL'),
#     (7675, 7677, 'B-TEMPO'),
#     (7678, 7680, 'I-TEMPO'),
#     (7681, 7689, 'I-TEMPO'),
#     (7690, 7692, 'I-TEMPO'),
#     (7693, 7697, 'I-TEMPO'),
#     (7700, 7704, 'B-PESSOA'),
#     (7705, 7708, 'I-PESSOA'),
#     (7751, 7758, 'B-ORGANIZACAO'),
#     (7759, 7767, 'I-ORGANIZACAO'),
#     (7768, 7775, 'I-ORGANIZACAO'),
#     (7817, 7819, 'B-LEGISLACAO'),
#     (7820, 7822, 'I-LEGISLACAO'),
#     (7823, 7835, 'I-LEGISLACAO'),
#     (7839, 7849, 'B-TEMPO'),
#     (7867, 7881, 'B-ORGANIZACAO'),
#     (7882, 7884, 'I-ORGANIZACAO'),
#     (7885, 7891, 'I-ORGANIZACAO'),
#     (7892, 7900, 'I-ORGANIZACAO'),
#     (7901, 7911, 'I-ORGANIZACAO'),
#     (7914, 7924, 'B-ORGANIZACAO'),
#     (8048, 8055, 'B-ORGANIZACAO'),
#     (8056, 8064, 'I-ORGANIZACAO'),
#     (8065, 8072, 'I-ORGANIZACAO'),
#     (8073, 8075, 'B-JURISPRUDENCIA'),
#     (8076, 8082, 'I-JURISPRUDENCIA'),
#     (8083, 8084, 'I-JURISPRUDENCIA'),
#     (8085, 8087, 'I-JURISPRUDENCIA'),
#     (8088, 8096, 'B-ORGANIZACAO'),
#     (8097, 8102, 'I-ORGANIZACAO'),
#     (8106, 8113, 'B-ORGANIZACAO'),
#     (8114, 8122, 'I-ORGANIZACAO'),
#     (8123, 8130, 'I-ORGANIZACAO'),
#     (8170, 8174, 'B-PESSOA'),
#     (8175, 8182, 'I-PESSOA'),
#     (8388, 8396, 'B-LOCAL'),
#     (8399, 8401, 'B-TEMPO'),
#     (8402, 8404, 'I-TEMPO'),
#     (8405, 8413, 'I-TEMPO'),
#     (8414, 8416, 'I-TEMPO'),
#     (8417, 8421, 'I-TEMPO'),
#     (8424, 8428, 'B-PESSOA'),
#     (8429, 8432, 'I-PESSOA'),
#     (8475, 8482, 'B-ORGANIZACAO'),
#     (8483, 8491, 'I-ORGANIZACAO'),
#     (8492, 8499, 'I-ORGANIZACAO'),
#     (8541, 8543, 'B-LEGISLACAO'),
#     (8544, 8546, 'I-LEGISLACAO'),
#     (8547, 8559, 'I-LEGISLACAO'),
#     (8563, 8573, 'B-TEMPO'),
#     (8591, 8605, 'B-ORGANIZACAO'),
#     (8606, 8608, 'I-ORGANIZACAO'),
#     (8609, 8615, 'I-ORGANIZACAO'),
#     (8616, 8624, 'I-ORGANIZACAO'),
#     (8625, 8635, 'I-ORGANIZACAO'),
#     (8638, 8648, 'B-ORGANIZACAO'),
#     (8823, 8833, 'B-TEMPO'),
#     (8834, 8842, 'B-ORGANIZACAO'),
#     (8843, 8848, 'I-ORGANIZACAO'),
#     (8849, 8855, 'B-JURISPRUDENCIA'),
#     (8856, 8862, 'I-JURISPRUDENCIA'),
#     (8863, 8870, 'I-JURISPRUDENCIA'),
#     (8871, 8874, 'I-JURISPRUDENCIA'),
#     (8875, 8880, 'I-JURISPRUDENCIA'),
#     (8897, 8901, 'B-PESSOA'),
#     (8902, 8905, 'I-PESSOA'),
#     (8922, 8929, 'B-PESSOA'),
#     (8930, 8934, 'I-PESSOA'),
#     (8935, 8942, 'I-PESSOA'),
#     (8943, 8948, 'I-PESSOA'),
#     (8965, 8975, 'B-ORGANIZACAO'),
#     (8976, 8983, 'I-ORGANIZACAO'),
#     (8984, 8986, 'I-ORGANIZACAO'),
#     (8987, 8992, 'I-ORGANIZACAO'),
#     (9072, 9080, 'B-ORGANIZACAO'),
#     (9081, 9089, 'I-ORGANIZACAO'),
#     (9090, 9092, 'I-ORGANIZACAO'),
#     (9093, 9100, 'I-ORGANIZACAO'),
#     (9137, 9141, 'B-PESSOA'),
#     (9142, 9145, 'I-PESSOA'),
#     (9252, 9258, 'B-ORGANIZACAO'),
#     (9259, 9264, 'I-ORGANIZACAO'),
#     (9265, 9267, 'I-ORGANIZACAO'),
#     (9268, 9276, 'I-ORGANIZACAO'),
#     (9277, 9285, 'I-ORGANIZACAO'),
#     (9286, 9288, 'I-ORGANIZACAO'),
#     (9289, 9296, 'I-ORGANIZACAO'),
#     (9799, 9802, 'B-LEGISLACAO'),
#     (9803, 9804, 'I-LEGISLACAO'),
#     (9805, 9807, 'I-LEGISLACAO'),
#     (9808, 9810, 'I-LEGISLACAO'),
#     (9811, 9814, 'I-LEGISLACAO'),
#     (10304, 10311, 'B-ORGANIZACAO'),
#     (10312, 10320, 'I-ORGANIZACAO'),
#     (10321, 10328, 'I-ORGANIZACAO'),
#     (10370, 10372, 'B-LEGISLACAO'),
#     (10373, 10375, 'I-LEGISLACAO'),
#     (10376, 10388, 'I-LEGISLACAO'),
#     (10392, 10402, 'B-TEMPO'),
#     (10420, 10434, 'B-ORGANIZACAO'),
#     (10435, 10437, 'I-ORGANIZACAO'),
#     (10438, 10444, 'I-ORGANIZACAO'),
#     (10445, 10453, 'I-ORGANIZACAO'),
#     (10454, 10464, 'I-ORGANIZACAO'),
#     (10467, 10477, 'B-ORGANIZACAO'),
#     (10601, 10608, 'B-ORGANIZACAO'),
#     (10609, 10617, 'I-ORGANIZACAO'),
#     (10618, 10625, 'I-ORGANIZACAO'),
#     (10626, 10636, 'B-TEMPO'),
#     (10637, 10645, 'B-ORGANIZACAO'),
#     (10646, 10651, 'I-ORGANIZACAO'),
#     (10652, 10658, 'B-JURISPRUDENCIA'),
#     (10659, 10665, 'I-JURISPRUDENCIA'),
#     (10666, 10673, 'I-JURISPRUDENCIA'),
#     (10674, 10677, 'I-JURISPRUDENCIA'),
#     (10678, 10683, 'I-JURISPRUDENCIA'),
#     (10700, 10704, 'B-PESSOA'),
#     (10705, 10708, 'I-PESSOA'),
#     (10725, 10732, 'B-PESSOA'),
#     (10733, 10737, 'I-PESSOA'),
#     (10738, 10745, 'I-PESSOA'),
#     (10746, 10751, 'I-PESSOA'),
#     (10768, 10778, 'B-ORGANIZACAO'),
#     (10779, 10786, 'I-ORGANIZACAO'),
#     (10787, 10789, 'I-ORGANIZACAO'),
#     (10790, 10795, 'I-ORGANIZACAO'),
#     (10875, 10883, 'B-ORGANIZACAO'),
#     (10884, 10892, 'I-ORGANIZACAO'),
#     (10893, 10895, 'I-ORGANIZACAO'),
#     (10896, 10903, 'I-ORGANIZACAO'),
#     (10940, 10944, 'B-PESSOA'),
#     (10945, 10948, 'I-PESSOA'),
#     (11055, 11061, 'B-ORGANIZACAO'),
#     (11062, 11067, 'I-ORGANIZACAO'),
#     (11068, 11070, 'I-ORGANIZACAO'),
#     (11071, 11079, 'I-ORGANIZACAO'),
#     (11080, 11088, 'I-ORGANIZACAO'),
#     (11089, 11091, 'I-ORGANIZACAO'),
#     (11092, 11099, 'I-ORGANIZACAO'),
#     (11602, 11605, 'B-LEGISLACAO'),
#     (11606, 11607, 'I-LEGISLACAO'),
#     (11608, 11610, 'I-LEGISLACAO'),
#     (11611, 11613, 'I-LEGISLACAO'),
#     (11614, 11617, 'I-LEGISLACAO'),
#     (12107, 12114, 'B-ORGANIZACAO'),
#     (12115, 12123, 'I-ORGANIZACAO'),
#     (12124, 12131, 'I-ORGANIZACAO'),
#     (12173, 12175, 'B-LEGISLACAO'),
#     (12176, 12178, 'I-LEGISLACAO'),
#     (12179, 12191, 'I-LEGISLACAO'),
#     (12195, 12205, 'B-TEMPO'),
#     (12223, 12237, 'B-ORGANIZACAO'),
#     (12238, 12240, 'I-ORGANIZACAO'),
#     (12241, 12247, 'I-ORGANIZACAO'),
#     (12248, 12256, 'I-ORGANIZACAO'),
#     (12257, 12267, 'I-ORGANIZACAO'),
#     (12270, 12280, 'B-ORGANIZACAO'),
#     (12455, 12457, 'B-JURISPRUDENCIA'),
#     (12458, 12464, 'I-JURISPRUDENCIA'),
#     (12465, 12466, 'I-JURISPRUDENCIA'),
#     (12467, 12469, 'I-JURISPRUDENCIA'),
#     (13407, 13410, 'B-LEGISLACAO'),
#     (13411, 13412, 'I-LEGISLACAO'),
#     (13413, 13414, 'I-LEGISLACAO'),
#     (13415, 13426, 'I-LEGISLACAO'),
#     (13479, 13487, 'B-ORGANIZACAO'),
#     (13513, 13516, 'B-LEGISLACAO'),
#     (13517, 13518, 'I-LEGISLACAO'),
#     (13519, 13522, 'I-LEGISLACAO'),
#     (13523, 13524, 'I-LEGISLACAO'),
#     (13525, 13526, 'I-LEGISLACAO'),
#     (13527, 13528, 'I-LEGISLACAO'),
#     (13529, 13531, 'I-LEGISLACAO'),
#     (13532, 13535, 'I-LEGISLACAO'),
#     (13654, 13657, 'B-LEGISLACAO'),
#     (13658, 13659, 'I-LEGISLACAO'),
#     (13660, 13663, 'I-LEGISLACAO'),
#     (13664, 13665, 'I-LEGISLACAO'),
#     (13666, 13667, 'I-LEGISLACAO'),
#     (13668, 13670, 'I-LEGISLACAO'),
#     (13671, 13672, 'I-LEGISLACAO'),
#     (13673, 13675, 'I-LEGISLACAO'),
#     (13676, 13679, 'I-LEGISLACAO'),
#     (14301, 14308, 'B-ORGANIZACAO'),
#     (14309, 14317, 'I-ORGANIZACAO'),
#     (14318, 14325, 'I-ORGANIZACAO'),
#     (14367, 14369, 'B-LEGISLACAO'),
#     (14370, 14372, 'I-LEGISLACAO'),
#     (14373, 14385, 'I-LEGISLACAO'),
#     (14389, 14399, 'B-TEMPO'),
#     (14417, 14431, 'B-ORGANIZACAO'),
#     (14432, 14434, 'I-ORGANIZACAO'),
#     (14435, 14441, 'I-ORGANIZACAO'),
#     (14442, 14450, 'I-ORGANIZACAO'),
#     (14451, 14461, 'I-ORGANIZACAO'),
#     (14464, 14474, 'B-ORGANIZACAO'),
#     (14598, 14605, 'B-ORGANIZACAO'),
#     (14606, 14614, 'I-ORGANIZACAO'),
#     (14615, 14622, 'I-ORGANIZACAO'),
#     (14623, 14625, 'B-JURISPRUDENCIA'),
#     (14626, 14632, 'I-JURISPRUDENCIA'),
#     (14633, 14634, 'I-JURISPRUDENCIA'),
#     (14635, 14637, 'I-JURISPRUDENCIA'),
#     (15575, 15578, 'B-LEGISLACAO'),
#     (15579, 15580, 'I-LEGISLACAO'),
#     (15581, 15582, 'I-LEGISLACAO'),
#     (15583, 15594, 'I-LEGISLACAO'),
#     (15647, 15655, 'B-ORGANIZACAO'),
#     (15681, 15684, 'B-LEGISLACAO'),
#     (15685, 15686, 'I-LEGISLACAO'),
#     (15687, 15690, 'I-LEGISLACAO'),
#     (15691, 15692, 'I-LEGISLACAO'),
#     (15693, 15694, 'I-LEGISLACAO'),
#     (15695, 15696, 'I-LEGISLACAO'),
#     (15697, 15699, 'I-LEGISLACAO'),
#     (15700, 15703, 'I-LEGISLACAO'),
#     (15822, 15825, 'B-LEGISLACAO'),
#     (15826, 15827, 'I-LEGISLACAO'),
#     (15828, 15831, 'I-LEGISLACAO'),
#     (15832, 15833, 'I-LEGISLACAO'),
#     (15834, 15835, 'I-LEGISLACAO'),
#     (15836, 15838, 'I-LEGISLACAO'),
#     (15839, 15840, 'I-LEGISLACAO'),
#     (15841, 15843, 'I-LEGISLACAO'),
#     (15844, 15847, 'I-LEGISLACAO'),
#     (16469, 16476, 'B-ORGANIZACAO'),
#     (16477, 16485, 'I-ORGANIZACAO'),
#     (16486, 16493, 'I-ORGANIZACAO'),
#     (16535, 16537, 'B-LEGISLACAO'),
#     (16538, 16540, 'I-LEGISLACAO'),
#     (16541, 16553, 'I-LEGISLACAO'),
#     (16557, 16567, 'B-TEMPO'),
#     (16585, 16599, 'B-ORGANIZACAO'),
#     (16600, 16602, 'I-ORGANIZACAO'),
#     (16603, 16609, 'I-ORGANIZACAO'),
#     (16610, 16618, 'I-ORGANIZACAO'),
#     (16619, 16629, 'I-ORGANIZACAO'),
#     (16632, 16642, 'B-ORGANIZACAO'),
#     (16817, 16819, 'B-JURISPRUDENCIA'),
#     (16820, 16826, 'I-JURISPRUDENCIA'),
#     (16827, 16828, 'I-JURISPRUDENCIA'),
#     (16829, 16831, 'I-JURISPRUDENCIA'),
#     (16921, 16931, 'B-ORGANIZACAO'),
#     (16932, 16939, 'I-ORGANIZACAO'),
#     (17267, 17277, 'B-TEMPO'),
#     (17305, 17311, 'B-LEGISLACAO'),
#     (17312, 17315, 'I-LEGISLACAO'),
#     (17316, 17317, 'I-LEGISLACAO'),
#     (17318, 17319, 'I-LEGISLACAO'),
#     (17320, 17322, 'I-LEGISLACAO'),
#     (17323, 17324, 'I-LEGISLACAO'),
#     (17325, 17332, 'I-LEGISLACAO'),
#     (17333, 17335, 'I-LEGISLACAO'),
#     (17336, 17337, 'I-LEGISLACAO'),
#     (17338, 17340, 'I-LEGISLACAO'),
#     (17341, 17342, 'I-LEGISLACAO'),
#     (17343, 17346, 'I-LEGISLACAO'),
#     (17347, 17349, 'I-LEGISLACAO'),
#     (17350, 17357, 'I-LEGISLACAO'),
#     (17358, 17360, 'I-LEGISLACAO'),
#     (17361, 17362, 'I-LEGISLACAO'),
#     (17363, 17369, 'I-LEGISLACAO'),
#     (17370, 17372, 'I-LEGISLACAO'),
#     (17373, 17374, 'I-LEGISLACAO'),
#     (17375, 17381, 'I-LEGISLACAO'),
#     (17382, 17383, 'I-LEGISLACAO'),
#     (17384, 17385, 'I-LEGISLACAO'),
#     (17386, 17387, 'I-LEGISLACAO'),
#     (17388, 17390, 'I-LEGISLACAO'),
#     (17391, 17392, 'I-LEGISLACAO'),
#     (17393, 17395, 'I-LEGISLACAO'),
#     (17396, 17397, 'I-LEGISLACAO'),
#     (17398, 17401, 'I-LEGISLACAO'),
#     (17402, 17406, 'I-LEGISLACAO'),
#     (17407, 17412, 'I-LEGISLACAO'),
#     (17413, 17414, 'I-LEGISLACAO'),
#     (17415, 17416, 'I-LEGISLACAO'),
#     (17417, 17422, 'I-LEGISLACAO'),
#     (17423, 17425, 'I-LEGISLACAO'),
#     (17426, 17432, 'I-LEGISLACAO'),
#     (17433, 17438, 'I-LEGISLACAO'),
#     (17443, 17453, 'B-ORGANIZACAO'),
#     (17454, 17461, 'I-ORGANIZACAO'),
#     (17462, 17464, 'I-ORGANIZACAO'),
#     (17465, 17470, 'I-ORGANIZACAO'),
#     (17697, 17700, 'B-LEGISLACAO'),
#     (17701, 17702, 'I-LEGISLACAO'),
#     (17703, 17705, 'I-LEGISLACAO'),
#     (17706, 17707, 'I-LEGISLACAO'),
#     (17708, 17710, 'I-LEGISLACAO'),
#     (17711, 17712, 'I-LEGISLACAO'),
#     (17713, 17716, 'I-LEGISLACAO'),
#     (17717, 17719, 'I-LEGISLACAO'),
#     (17720, 17722, 'I-LEGISLACAO'),
#     (18034, 18041, 'B-JURISPRUDENCIA'),
#     (18042, 18044, 'I-JURISPRUDENCIA'),
#     (18045, 18052, 'I-JURISPRUDENCIA'),
#     (18053, 18060, 'I-JURISPRUDENCIA'),
#     (18061, 18062, 'I-JURISPRUDENCIA'),
#     (18063, 18064, 'I-JURISPRUDENCIA'),
#     (18065, 18079, 'I-JURISPRUDENCIA'),
#     (18260, 18263, 'B-ORGANIZACAO'),
#     (18478, 18485, 'B-ORGANIZACAO'),
#     (18486, 18494, 'I-ORGANIZACAO'),
#     (18495, 18502, 'I-ORGANIZACAO'),
#     (18544, 18546, 'B-LEGISLACAO'),
#     (18547, 18549, 'I-LEGISLACAO'),
#     (18550, 18562, 'I-LEGISLACAO'),
#     (18566, 18576, 'B-TEMPO'),
#     (18594, 18608, 'B-ORGANIZACAO'),
#     (18609, 18611, 'I-ORGANIZACAO'),
#     (18612, 18618, 'I-ORGANIZACAO'),
#     (18619, 18627, 'I-ORGANIZACAO'),
#     (18628, 18638, 'I-ORGANIZACAO'),
#     (18641, 18651, 'B-ORGANIZACAO'),
#     (18775, 18782, 'B-ORGANIZACAO'),
#     (18783, 18791, 'I-ORGANIZACAO'),
#     (18792, 18799, 'I-ORGANIZACAO'),
#     (18800, 18802, 'B-JURISPRUDENCIA'),
#     (18803, 18809, 'I-JURISPRUDENCIA'),
#     (18810, 18811, 'I-JURISPRUDENCIA'),
#     (18812, 18814, 'I-JURISPRUDENCIA'),
#     (18904, 18914, 'B-ORGANIZACAO'),
#     (18915, 18922, 'I-ORGANIZACAO'),
#     (19250, 19260, 'B-TEMPO'),
#     (19288, 19294, 'B-LEGISLACAO'),
#     (19295, 19298, 'I-LEGISLACAO'),
#     (19299, 19300, 'I-LEGISLACAO'),
#     (19301, 19302, 'I-LEGISLACAO'),
#     (19303, 19305, 'I-LEGISLACAO'),
#     (19306, 19307, 'I-LEGISLACAO'),
#     (19308, 19315, 'I-LEGISLACAO'),
#     (19316, 19318, 'I-LEGISLACAO'),
#     (19319, 19320, 'I-LEGISLACAO'),
#     (19321, 19323, 'I-LEGISLACAO'),
#     (19324, 19325, 'I-LEGISLACAO'),
#     (19326, 19329, 'I-LEGISLACAO'),
#     (19330, 19332, 'I-LEGISLACAO'),
#     (19333, 19340, 'I-LEGISLACAO'),
#     (19341, 19343, 'I-LEGISLACAO'),
#     (19344, 19345, 'I-LEGISLACAO'),
#     (19346, 19352, 'I-LEGISLACAO'),
#     (19353, 19355, 'I-LEGISLACAO'),
#     (19356, 19357, 'I-LEGISLACAO'),
#     (19358, 19364, 'I-LEGISLACAO'),
#     (19365, 19366, 'I-LEGISLACAO'),
#     (19367, 19368, 'I-LEGISLACAO'),
#     (19369, 19370, 'I-LEGISLACAO'),
#     (19371, 19373, 'I-LEGISLACAO'),
#     (19374, 19375, 'I-LEGISLACAO'),
#     (19376, 19378, 'I-LEGISLACAO'),
#     (19379, 19380, 'I-LEGISLACAO'),
#     (19381, 19384, 'I-LEGISLACAO'),
#     (19385, 19389, 'I-LEGISLACAO'),
#     (19390, 19395, 'I-LEGISLACAO'),
#     (19396, 19397, 'I-LEGISLACAO'),
#     (19398, 19399, 'I-LEGISLACAO'),
#     (19400, 19405, 'I-LEGISLACAO'),
#     (19406, 19408, 'I-LEGISLACAO'),
#     (19409, 19415, 'I-LEGISLACAO'),
#     (19416, 19421, 'I-LEGISLACAO'),
#     (19426, 19436, 'B-ORGANIZACAO'),
#     (19437, 19444, 'I-ORGANIZACAO'),
#     (19445, 19447, 'I-ORGANIZACAO'),
#     (19448, 19453, 'I-ORGANIZACAO'),
#     (19680, 19683, 'B-LEGISLACAO'),
#     (19684, 19685, 'I-LEGISLACAO'),
#     (19686, 19688, 'I-LEGISLACAO'),
#     (19689, 19690, 'I-LEGISLACAO'),
#     (19691, 19693, 'I-LEGISLACAO'),
#     (19694, 19695, 'I-LEGISLACAO'),
#     (19696, 19699, 'I-LEGISLACAO'),
#     (19700, 19702, 'I-LEGISLACAO'),
#     (19703, 19705, 'I-LEGISLACAO'),
#     (20017, 20024, 'B-JURISPRUDENCIA'),
#     (20025, 20027, 'I-JURISPRUDENCIA'),
#     (20028, 20035, 'I-JURISPRUDENCIA'),
#     (20036, 20043, 'I-JURISPRUDENCIA'),
#     (20044, 20045, 'I-JURISPRUDENCIA'),
#     (20046, 20047, 'I-JURISPRUDENCIA'),
#     (20048, 20062, 'I-JURISPRUDENCIA'),
#     (20243, 20246, 'B-ORGANIZACAO'),
#     (20461, 20468, 'B-ORGANIZACAO'),
#     (20469, 20477, 'I-ORGANIZACAO'),
#     (20478, 20485, 'I-ORGANIZACAO'),
#     (20527, 20529, 'B-LEGISLACAO'),
#     (20530, 20532, 'I-LEGISLACAO'),
#     (20533, 20545, 'I-LEGISLACAO'),
#     (20549, 20559, 'B-TEMPO'),
#     (20577, 20591, 'B-ORGANIZACAO'),
#     (20592, 20594, 'I-ORGANIZACAO'),
#     (20595, 20601, 'I-ORGANIZACAO'),
#     (20602, 20610, 'I-ORGANIZACAO'),
#     (20611, 20621, 'I-ORGANIZACAO'),
#     (20624, 20634, 'B-ORGANIZACAO'),
#     (20809, 20811, 'B-JURISPRUDENCIA'),
#     (20812, 20818, 'I-JURISPRUDENCIA'),
#     (20819, 20820, 'I-JURISPRUDENCIA'),
#     (20821, 20823, 'I-JURISPRUDENCIA'),
#     (21205, 21212, 'B-ORGANIZACAO'),
#     (21213, 21221, 'I-ORGANIZACAO'),
#     (21222, 21229, 'I-ORGANIZACAO'),
#     (21271, 21273, 'B-LEGISLACAO'),
#     (21274, 21276, 'I-LEGISLACAO'),
#     (21277, 21289, 'I-LEGISLACAO'),
#     (21293, 21303, 'B-TEMPO'),
#     (21321, 21335, 'B-ORGANIZACAO'),
#     (21336, 21338, 'I-ORGANIZACAO'),
#     (21339, 21345, 'I-ORGANIZACAO'),
#     (21346, 21354, 'I-ORGANIZACAO'),
#     (21355, 21365, 'I-ORGANIZACAO'),
#     (21368, 21378, 'B-ORGANIZACAO'),
#     (21502, 21509, 'B-ORGANIZACAO'),
#     (21510, 21518, 'I-ORGANIZACAO'),
#     (21519, 21526, 'I-ORGANIZACAO'),
#     (21527, 21529, 'B-JURISPRUDENCIA'),
#     (21530, 21536, 'I-JURISPRUDENCIA'),
#     (21537, 21538, 'I-JURISPRUDENCIA'),
#     (21539, 21541, 'I-JURISPRUDENCIA'),
#     (21923, 21930, 'B-ORGANIZACAO'),
#     (21931, 21939, 'I-ORGANIZACAO'),
#     (21940, 21947, 'I-ORGANIZACAO'),
#     (21989, 21991, 'B-LEGISLACAO'),
#     (21992, 21994, 'I-LEGISLACAO'),
#     (21995, 22007, 'I-LEGISLACAO'),
#     (22011, 22021, 'B-TEMPO'),
#     (22039, 22053, 'B-ORGANIZACAO'),
#     (22054, 22056, 'I-ORGANIZACAO'),
#     (22057, 22063, 'I-ORGANIZACAO'),
#     (22064, 22072, 'I-ORGANIZACAO'),
#     (22073, 22083, 'I-ORGANIZACAO'),
#     (22086, 22096, 'B-ORGANIZACAO'),
#     (22274, 22278, 'B-PESSOA'),
#     (22279, 22282, 'I-PESSOA'),
#     (22283, 22293, 'B-TEMPO'),
#     (22294, 22302, 'B-ORGANIZACAO'),
#     (22303, 22308, 'I-ORGANIZACAO'),
#     (22309, 22315, 'B-JURISPRUDENCIA'),
#     (22316, 22322, 'I-JURISPRUDENCIA'),
#     (22323, 22330, 'I-JURISPRUDENCIA'),
#     (22331, 22334, 'B-LOCAL'),
#     (22335, 22340, 'I-LOCAL'),
#     (22367, 22371, 'B-PESSOA'),
#     (22372, 22375, 'I-PESSOA'),
#     (22418, 22425, 'B-ORGANIZACAO'),
#     (22426, 22434, 'I-ORGANIZACAO'),
#     (22435, 22442, 'I-ORGANIZACAO'),
#     (22515, 22521, 'B-LEGISLACAO'),
#     (22522, 22525, 'I-LEGISLACAO'),
#     (22526, 22527, 'I-LEGISLACAO'),
#     (22528, 22534, 'I-LEGISLACAO'),
#     (22535, 22536, 'I-LEGISLACAO'),
#     (22537, 22538, 'I-LEGISLACAO'),
#     (22539, 22546, 'I-LEGISLACAO'),
#     (22547, 22548, 'I-LEGISLACAO'),
#     (22549, 22550, 'I-LEGISLACAO'),
#     (22551, 22552, 'I-LEGISLACAO'),
#     (22553, 22554, 'I-LEGISLACAO'),
#     (22555, 22556, 'I-LEGISLACAO'),
#     (22557, 22558, 'I-LEGISLACAO'),
#     (22559, 22560, 'I-LEGISLACAO'),
#     (22561, 22562, 'I-LEGISLACAO'),
#     (22563, 22565, 'I-LEGISLACAO'),
#     (22566, 22578, 'I-LEGISLACAO'),
#     (22579, 22586, 'I-LEGISLACAO'),
#     (22621, 22628, 'B-ORGANIZACAO'),
#     (22629, 22637, 'I-ORGANIZACAO'),
#     (22638, 22645, 'I-ORGANIZACAO'),
#     (22934, 22940, 'B-ORGANIZACAO'),
#     (22946, 22952, 'B-ORGANIZACAO'),
#     (22953, 22960, 'I-ORGANIZACAO'),
#     (22966, 22974, 'B-ORGANIZACAO'),
#     (22975, 22977, 'I-ORGANIZACAO'),
#     (22978, 22984, 'I-ORGANIZACAO'),
#     (22985, 22987, 'I-ORGANIZACAO'),
#     (22988, 22993, 'I-ORGANIZACAO'),
#     (23041, 23048, 'B-ORGANIZACAO'),
#     (23049, 23057, 'I-ORGANIZACAO'),
#     (23058, 23065, 'I-ORGANIZACAO'),
#     (23249, 23256, 'B-ORGANIZACAO'),
#     (23257, 23265, 'I-ORGANIZACAO'),
#     (23266, 23273, 'I-ORGANIZACAO'),
#     (23493, 23496, 'B-JURISPRUDENCIA'),
#     (23497, 23506, 'I-JURISPRUDENCIA'),
#     (23523, 23528, 'B-PESSOA'),
#     (23529, 23531, 'I-PESSOA'),
#     (23532, 23537, 'I-PESSOA'),
#     (23552, 23561, 'B-TEMPO'),
#     (23628, 23635, 'B-ORGANIZACAO'),
#     (23636, 23644, 'I-ORGANIZACAO'),
#     (23645, 23652, 'I-ORGANIZACAO'),
#     (23762, 23765, 'B-LEGISLACAO'),
#     (23766, 23767, 'I-LEGISLACAO'),
#     (23768, 23771, 'I-LEGISLACAO'),
#     (23772, 23773, 'I-LEGISLACAO'),
#     (23774, 23777, 'I-LEGISLACAO'),
#     (23794, 23801, 'B-ORGANIZACAO'),
#     (23802, 23810, 'I-ORGANIZACAO'),
#     (23811, 23818, 'I-ORGANIZACAO'),
#     (23860, 23862, 'B-LEGISLACAO'),
#     (23863, 23865, 'I-LEGISLACAO'),
#     (23866, 23878, 'I-LEGISLACAO'),
#     (23882, 23892, 'B-TEMPO'),
#     (23910, 23924, 'B-ORGANIZACAO'),
#     (23925, 23927, 'I-ORGANIZACAO'),
#     (23928, 23934, 'I-ORGANIZACAO'),
#     (23935, 23943, 'I-ORGANIZACAO'),
#     (23944, 23954, 'I-ORGANIZACAO'),
#     (23957, 23967, 'B-ORGANIZACAO'),
#     (24091, 24098, 'B-ORGANIZACAO'),
#     (24099, 24107, 'I-ORGANIZACAO'),
#     (24108, 24115, 'I-ORGANIZACAO'),
#     (24116, 24126, 'B-TEMPO'),
#     (24127, 24135, 'B-ORGANIZACAO'),
#     (24136, 24141, 'I-ORGANIZACAO'),
#     (24142, 24148, 'B-JURISPRUDENCIA'),
#     (24149, 24155, 'I-JURISPRUDENCIA'),
#     (24156, 24163, 'I-JURISPRUDENCIA'),
#     (24164, 24167, 'B-LOCAL'),
#     (24168, 24173, 'I-LOCAL'),
#     (24200, 24204, 'B-PESSOA'),
#     (24205, 24208, 'I-PESSOA'),
#     (24251, 24258, 'B-ORGANIZACAO'),
#     (24259, 24267, 'I-ORGANIZACAO'),
#     (24268, 24275, 'I-ORGANIZACAO'),
#     (24348, 24354, 'B-LEGISLACAO'),
#     (24355, 24358, 'I-LEGISLACAO'),
#     (24359, 24360, 'I-LEGISLACAO'),
#     (24361, 24367, 'I-LEGISLACAO'),
#     (24368, 24369, 'I-LEGISLACAO'),
#     (24370, 24371, 'I-LEGISLACAO'),
#     (24372, 24379, 'I-LEGISLACAO'),
#     (24380, 24381, 'I-LEGISLACAO'),
#     (24382, 24383, 'I-LEGISLACAO'),
#     (24384, 24385, 'I-LEGISLACAO'),
#     (24386, 24387, 'I-LEGISLACAO'),
#     (24388, 24389, 'I-LEGISLACAO'),
#     (24390, 24391, 'I-LEGISLACAO'),
#     (24392, 24393, 'I-LEGISLACAO'),
#     (24394, 24395, 'I-LEGISLACAO'),
#     (24396, 24398, 'I-LEGISLACAO'),
#     (24399, 24411, 'I-LEGISLACAO'),
#     (24412, 24419, 'I-LEGISLACAO'),
#     (24454, 24461, 'B-ORGANIZACAO'),
#     (24462, 24470, 'I-ORGANIZACAO'),
#     (24471, 24478, 'I-ORGANIZACAO'),
#     (24509, 24521, 'B-LEGISLACAO'),
#     (24767, 24773, 'B-ORGANIZACAO'),
#     (24779, 24785, 'B-ORGANIZACAO'),
#     (24786, 24793, 'I-ORGANIZACAO'),
#     (24799, 24807, 'B-ORGANIZACAO'),
#     (24808, 24810, 'I-ORGANIZACAO'),
#     (24811, 24817, 'I-ORGANIZACAO'),
#     (24818, 24820, 'I-ORGANIZACAO'),
#     (24821, 24826, 'I-ORGANIZACAO'),
#     (24874, 24881, 'B-ORGANIZACAO'),
#     (24882, 24890, 'I-ORGANIZACAO'),
#     (24891, 24898, 'I-ORGANIZACAO'),
#     (25082, 25089, 'B-ORGANIZACAO'),
#     (25090, 25098, 'I-ORGANIZACAO'),
#     (25099, 25106, 'I-ORGANIZACAO'),
#     (25326, 25329, 'B-JURISPRUDENCIA'),
#     (25330, 25339, 'I-JURISPRUDENCIA'),
#     (25356, 25361, 'B-PESSOA'),
#     (25362, 25364, 'I-PESSOA'),
#     (25365, 25370, 'I-PESSOA'),
#     (25385, 25394, 'B-TEMPO'),
#     (25461, 25468, 'B-ORGANIZACAO'),
#     (25469, 25477, 'I-ORGANIZACAO'),
#     (25478, 25485, 'I-ORGANIZACAO'),
#     (25595, 25598, 'B-LEGISLACAO'),
#     (25599, 25600, 'I-LEGISLACAO'),
#     (25601, 25604, 'I-LEGISLACAO'),
#     (25605, 25606, 'I-LEGISLACAO'),
#     (25607, 25610, 'I-LEGISLACAO'),
#     (25627, 25634, 'B-ORGANIZACAO'),
#     (25635, 25643, 'I-ORGANIZACAO'),
#     (25644, 25651, 'I-ORGANIZACAO'),
#     (25693, 25695, 'B-LEGISLACAO'),
#     (25696, 25698, 'I-LEGISLACAO'),
#     (25699, 25711, 'I-LEGISLACAO'),
#     (25715, 25725, 'B-TEMPO'),
#     (25743, 25757, 'B-ORGANIZACAO'),
#     (25758, 25760, 'I-ORGANIZACAO'),
#     (25761, 25767, 'I-ORGANIZACAO'),
#     (25768, 25776, 'I-ORGANIZACAO'),
#     (25777, 25787, 'I-ORGANIZACAO'),
#     (25790, 25800, 'B-ORGANIZACAO'),
#     (25978, 25982, 'B-PESSOA'),
#     (25983, 25986, 'I-PESSOA'),
#     (25987, 25989, 'B-JURISPRUDENCIA'),
#     (25990, 25996, 'I-JURISPRUDENCIA'),
#     (25997, 25998, 'I-JURISPRUDENCIA'),
#     (25999, 26001, 'I-JURISPRUDENCIA'),
#     (26028, 26035, 'B-ORGANIZACAO'),
#     (26036, 26044, 'I-ORGANIZACAO'),
#     (26045, 26052, 'I-ORGANIZACAO'),
#     (26255, 26258, 'B-LEGISLACAO'),
#     (26259, 26260, 'I-LEGISLACAO'),
#     (26261, 26264, 'I-LEGISLACAO'),
#     (26265, 26267, 'I-LEGISLACAO'),
#     (26268, 26274, 'I-LEGISLACAO'),
#     (26275, 26277, 'I-LEGISLACAO'),
#     (26278, 26286, 'I-LEGISLACAO'),
#     (26287, 26292, 'I-LEGISLACAO'),
#     (26374, 26383, 'B-ORGANIZACAO'),
#     (26384, 26392, 'I-ORGANIZACAO'),
#     (26449, 26456, 'B-ORGANIZACAO'),
#     (26457, 26465, 'I-ORGANIZACAO'),
#     (26466, 26473, 'I-ORGANIZACAO'),
#     (26558, 26565, 'B-ORGANIZACAO'),
#     (26566, 26574, 'I-ORGANIZACAO'),
#     (26575, 26582, 'I-ORGANIZACAO'),
#     (26616, 26628, 'B-LEGISLACAO'),
#     (26629, 26631, 'I-LEGISLACAO'),
#     (26632, 26641, 'I-LEGISLACAO'),
#     (26715, 26722, 'B-ORGANIZACAO'),
#     (26723, 26731, 'I-ORGANIZACAO'),
#     (26732, 26739, 'I-ORGANIZACAO'),
#     (27058, 27061, 'B-LEGISLACAO'),
#     (27062, 27063, 'I-LEGISLACAO'),
#     (27064, 27067, 'I-LEGISLACAO'),
#     (27068, 27069, 'I-LEGISLACAO'),
#     (27070, 27071, 'I-LEGISLACAO'),
#     (27072, 27073, 'I-LEGISLACAO'),
#     (27074, 27076, 'I-LEGISLACAO'),
#     (27077, 27089, 'I-LEGISLACAO'),
#     (27090, 27092, 'I-LEGISLACAO'),
#     (27093, 27102, 'I-LEGISLACAO'),
#     (27225, 27232, 'B-ORGANIZACAO'),
#     (27233, 27241, 'I-ORGANIZACAO'),
#     (27242, 27249, 'I-ORGANIZACAO'),
#     (27299, 27304, 'B-LEGISLACAO'),
#     (27305, 27313, 'I-LEGISLACAO'),
#     (27735, 27737, 'B-LEGISLACAO'),
#     (27738, 27739, 'I-LEGISLACAO'),
#     (27740, 27743, 'I-LEGISLACAO'),
#     (27744, 27745, 'I-LEGISLACAO'),
#     (27746, 27749, 'I-LEGISLACAO'),
#     (27750, 27751, 'I-LEGISLACAO'),
#     (27752, 27753, 'I-LEGISLACAO'),
#     (27754, 27755, 'I-LEGISLACAO'),
#     (27756, 27757, 'I-LEGISLACAO'),
#     (27758, 27759, 'I-LEGISLACAO'),
#     (27760, 27761, 'I-LEGISLACAO'),
#     (27808, 27813, 'B-ORGANIZACAO'),
#     (27814, 27821, 'I-ORGANIZACAO'),
#     (27916, 27918, 'B-LEGISLACAO'),
#     (27919, 27920, 'I-LEGISLACAO'),
#     (27921, 27924, 'I-LEGISLACAO'),
#     (27925, 27926, 'I-LEGISLACAO'),
#     (27927, 27930, 'I-LEGISLACAO'),
#     (27931, 27932, 'I-LEGISLACAO'),
#     (27933, 27934, 'I-LEGISLACAO'),
#     (27935, 27936, 'I-LEGISLACAO'),
#     (27937, 27938, 'I-LEGISLACAO'),
#     (28020, 28027, 'B-ORGANIZACAO'),
#     (28028, 28036, 'I-ORGANIZACAO'),
#     (28037, 28044, 'I-ORGANIZACAO'),
#     (28086, 28088, 'B-LEGISLACAO'),
#     (28089, 28091, 'I-LEGISLACAO'),
#     (28092, 28104, 'I-LEGISLACAO'),
#     (28108, 28118, 'B-TEMPO'),
#     (28136, 28150, 'B-ORGANIZACAO'),
#     (28151, 28153, 'I-ORGANIZACAO'),
#     (28154, 28160, 'I-ORGANIZACAO'),
#     (28161, 28169, 'I-ORGANIZACAO'),
#     (28170, 28180, 'I-ORGANIZACAO'),
#     (28183, 28193, 'B-ORGANIZACAO'),
#     (28317, 28324, 'B-ORGANIZACAO'),
#     (28325, 28333, 'I-ORGANIZACAO'),
#     (28334, 28341, 'I-ORGANIZACAO'),
#     (28342, 28344, 'B-JURISPRUDENCIA'),
#     (28345, 28351, 'I-JURISPRUDENCIA'),
#     (28352, 28353, 'I-JURISPRUDENCIA'),
#     (28354, 28356, 'I-JURISPRUDENCIA'),
#     (28383, 28390, 'B-ORGANIZACAO'),
#     (28391, 28399, 'I-ORGANIZACAO'),
#     (28400, 28407, 'I-ORGANIZACAO'),
#     (28610, 28613, 'B-LEGISLACAO'),
#     (28614, 28615, 'I-LEGISLACAO'),
#     (28616, 28619, 'I-LEGISLACAO'),
#     (28620, 28622, 'I-LEGISLACAO'),
#     (28623, 28629, 'I-LEGISLACAO'),
#     (28630, 28632, 'I-LEGISLACAO'),
#     (28633, 28641, 'I-LEGISLACAO'),
#     (28642, 28647, 'I-LEGISLACAO'),
#     (28729, 28738, 'B-ORGANIZACAO'),
#     (28739, 28747, 'I-ORGANIZACAO'),
#     (28804, 28811, 'B-ORGANIZACAO'),
#     (28812, 28820, 'I-ORGANIZACAO'),
#     (28821, 28828, 'I-ORGANIZACAO'),
#     (28913, 28920, 'B-ORGANIZACAO'),
#     (28921, 28929, 'I-ORGANIZACAO'),
#     (28930, 28937, 'I-ORGANIZACAO'),
#     (28971, 28983, 'B-LEGISLACAO'),
#     (28984, 28986, 'I-LEGISLACAO'),
#     (28987, 28996, 'I-LEGISLACAO'),
#     (29070, 29077, 'B-ORGANIZACAO'),
#     (29078, 29086, 'I-ORGANIZACAO'),
#     (29087, 29094, 'I-ORGANIZACAO'),
#     (29413, 29416, 'B-LEGISLACAO'),
#     (29417, 29418, 'I-LEGISLACAO'),
#     (29419, 29422, 'I-LEGISLACAO'),
#     (29423, 29424, 'I-LEGISLACAO'),
#     (29425, 29426, 'I-LEGISLACAO'),
#     (29427, 29428, 'I-LEGISLACAO'),
#     (29429, 29431, 'I-LEGISLACAO'),
#     (29432, 29444, 'I-LEGISLACAO'),
#     (29445, 29447, 'I-LEGISLACAO'),
#     (29448, 29457, 'I-LEGISLACAO'),
#     (29580, 29587, 'B-ORGANIZACAO'),
#     (29588, 29596, 'I-ORGANIZACAO'),
#     (29597, 29604, 'I-ORGANIZACAO'),
#     ...]}),
#  ("Documento assinado eletronicamente por Cleonilson Nicácio Silva , Matricula 8553 . Em 14/03/2018 18:12:33 . Para confirmar a validade deste documento , acesse : https : //eproc2g.stm.jus.br/eproc_2g_prod/ e digite o Codigo Verificador 21f1ade7dc RELATOR : Ministro Ten Brig Ar CLEONILSON NICÁCIO SILVA . PACIENTE : JEFERSON DOS SANTOS DO AMARAL . IMPETRANTE : Defensoria Pública da União . IMPETRADO : Juiz-Auditor Substituto da 2ª Auditoria da 3ª CJM - Justiça Militar da União - Bagé/RS . EMENTA HABEAS CORPUS . DESERÇÃO . APRESENTAÇÃO VOLUNTÁRIA . DISPENSA DA AUDIÊNCIA DE CUSTÓDIA . ILEGALIDADE . ORDEM DE HABEAS CORPUS CONCEDIDA . CONFIRMAÇÃO DA LIMINAR . UNANIMIDADE . A Audiência de Custódia constitui garantia do preso e instrumento de controle de legalidade e de verificação da situação do agente quanto à necessidade de manutenção da constrição de sua liberdade . A apresentação voluntária do desertor não constitui excepcionalidade apta a justificar a dispensa da Audiência de Custódia , sendo , inclusive , indiciária de sua necessidade . Habeas corpus concedido . Unanimidade . ACÓRDÃO Vistos , relatados e discutidos estes autos , acordam os ministros do Superior Tribunal Militar , em sessão de julgamento , sob a Presidência do Ministro Dr. JOSÉ COÊLHO FERREIRA , na conformidade do extrato da ata do julgamento , por unanimidade , em conceder a ordem de habeas corpus confirmando o provimento liminar nos termos em que foi deferido . Brasília , 6 de março de 2018 . Ministro Ten Brig Ar CLEONILSON NICÁCIO SILVA Relator RELATOR : Ministro Ten Brig Ar CLEONILSON NICÁCIO SILVA . PACIENTE : JEFERSON DOS SANTOS DO AMARAL . IMPETRANTE : Defensoria Pública da União . IMPETRADO : Juiz-Auditor Substituto da 2ª Auditoria da 3ª CJM - Justiça Militar da União - Bagé/RS . RELATÓRIO Trata-se de Habeas Corpus impetrado pela Defensoria Pública da União em favor do Sd Ex JEFERSON DOS SANTOS DO AMARAL , contra ato do Juiz-Auditor Substituto da 2ª Auditoria da 3ª CJM . Narra a impetração , em síntese , que o Paciente , servindo no 22º Grupo de Artilharia de Campanha Autopropulsado , teria consumado o delito de deserção previsto no art . 187 do Código Penal Militar em 5 de janeiro de 2018 . O referido militar apresentou-se voluntariamente em 21 de janeiro de 2018 tendo sido recolhido à prisão pela Autoridade Militar , que informou ao Juízo apontado como coator sobre a constrição à liberdade do desertor nessa mesma data . O Juiz-Auditor Substituto da 2ª Auditoria da 3ª CJM , por sua vez , `` ( ... ) decidiu pela desnecessidade de realização da audiência de custódia , em caráter excepcional , mantendo a custódia cautelar ( fl . 28 ) . `` , baseando-se , para tanto , no disposto no § 4º do artigo 5º da Resolução nº 228 , de 26 de outubro de 2016 , deste Superior Tribunal Militar . Documento assinado eletronicamente por Cleonilson Nicácio Silva , Matricula 8553 . Em 14/03/2018 18:12:33 . Para confirmar a validade deste documento , acesse : https : //eproc2g.stm.jus.br/eproc_2g_prod/ e digite o Codigo Verificador 21f1ade7dc A Defensoria Pública da União apontou irregularidade no Termo de Deserção no tocante à data consignada no referido documento . Além disso , sustentou que teria sido ilegal a dispensa da Audiência de Custódia , bem como que o Magistrado de primeiro grau não teria motivado a prisão ex lege . Ao final , requereu a concessão de liminar `` ( ... ) a fim de relaxar a prisão ex lege , com a consequente expedição do alvará de soltura em favor do paciente ( ... ) '' . No mérito , requereu : `` ( ... ) seja confirmada pelo Tribunal a liminar concedida , concedendo-se , em definitivo , a ordem de habeas corpus , ou sua concessão em julgamento colegiado , declarando-se nula a decisão que dispensou a audiência de custódia ( ... ) '' . Em Decisão de 2 de fevereiro de 2018 , deferi o pleito liminar e solicitei à Autoridade indigitada coatora que prestasse as informações necessárias ao julgamento do presente mandamus , bem como que se desse vista à Pro ...
#   {'entities': [(39, 49, 'B-PESSOA'),
#     (50, 57, 'I-PESSOA'),
#     (58, 63, 'I-PESSOA'),
#     (86, 96, 'B-TEMPO'),
#     (277, 287, 'B-PESSOA'),
#     (288, 295, 'I-PESSOA'),
#     (296, 301, 'I-PESSOA'),
#     (315, 323, 'B-PESSOA'),
#     (324, 327, 'I-PESSOA'),
#     (328, 334, 'I-PESSOA'),
#     (335, 337, 'I-PESSOA'),
#     (338, 344, 'I-PESSOA'),
#     (360, 370, 'B-ORGANIZACAO'),
#     (371, 378, 'I-ORGANIZACAO'),
#     (379, 381, 'I-ORGANIZACAO'),
#     (382, 387, 'I-ORGANIZACAO'),
#     (429, 431, 'B-ORGANIZACAO'),
#     (432, 441, 'I-ORGANIZACAO'),
#     (442, 444, 'I-ORGANIZACAO'),
#     (445, 447, 'I-ORGANIZACAO'),
#     (448, 451, 'I-ORGANIZACAO'),
#     (481, 488, 'B-LOCAL'),
#     (1169, 1177, 'B-ORGANIZACAO'),
#     (1178, 1186, 'I-ORGANIZACAO'),
#     (1187, 1194, 'I-ORGANIZACAO'),
#     (1257, 1261, 'B-PESSOA'),
#     (1262, 1268, 'I-PESSOA'),
#     (1269, 1277, 'I-PESSOA'),
#     (1451, 1459, 'B-LOCAL'),
#     (1462, 1463, 'B-TEMPO'),
#     (1464, 1466, 'I-TEMPO'),
#     (1467, 1472, 'I-TEMPO'),
#     (1473, 1475, 'I-TEMPO'),
#     (1476, 1480, 'I-TEMPO'),
#     (1504, 1514, 'B-PESSOA'),
#     (1515, 1522, 'I-PESSOA'),
#     (1523, 1528, 'I-PESSOA'),
#     (1568, 1578, 'B-PESSOA'),
#     (1579, 1586, 'I-PESSOA'),
#     (1587, 1592, 'I-PESSOA'),
#     (1606, 1614, 'B-PESSOA'),
#     (1615, 1618, 'I-PESSOA'),
#     (1619, 1625, 'I-PESSOA'),
#     (1626, 1628, 'I-PESSOA'),
#     (1629, 1635, 'I-PESSOA'),
#     (1651, 1661, 'B-ORGANIZACAO'),
#     (1662, 1669, 'I-ORGANIZACAO'),
#     (1670, 1672, 'I-ORGANIZACAO'),
#     (1673, 1678, 'I-ORGANIZACAO'),
#     (1720, 1722, 'B-ORGANIZACAO'),
#     (1723, 1732, 'I-ORGANIZACAO'),
#     (1733, 1735, 'I-ORGANIZACAO'),
#     (1736, 1738, 'I-ORGANIZACAO'),
#     (1739, 1742, 'I-ORGANIZACAO'),
#     (1772, 1779, 'B-LOCAL'),
#     (1833, 1843, 'B-ORGANIZACAO'),
#     (1844, 1851, 'I-ORGANIZACAO'),
#     (1852, 1854, 'I-ORGANIZACAO'),
#     (1855, 1860, 'I-ORGANIZACAO'),
#     (1879, 1887, 'B-PESSOA'),
#     (1888, 1891, 'I-PESSOA'),
#     (1892, 1898, 'I-PESSOA'),
#     (1899, 1901, 'I-PESSOA'),
#     (1902, 1908, 'I-PESSOA'),
#     (1952, 1954, 'B-ORGANIZACAO'),
#     (1955, 1964, 'I-ORGANIZACAO'),
#     (1965, 1967, 'I-ORGANIZACAO'),
#     (1968, 1970, 'I-ORGANIZACAO'),
#     (1971, 1974, 'I-ORGANIZACAO'),
#     (2040, 2043, 'B-ORGANIZACAO'),
#     (2044, 2049, 'I-ORGANIZACAO'),
#     (2050, 2052, 'I-ORGANIZACAO'),
#     (2053, 2063, 'I-ORGANIZACAO'),
#     (2064, 2066, 'I-ORGANIZACAO'),
#     (2067, 2075, 'I-ORGANIZACAO'),
#     (2076, 2090, 'I-ORGANIZACAO'),
#     (2142, 2145, 'B-LEGISLACAO'),
#     (2146, 2147, 'I-LEGISLACAO'),
#     (2148, 2151, 'I-LEGISLACAO'),
#     (2152, 2154, 'I-LEGISLACAO'),
#     (2155, 2161, 'I-LEGISLACAO'),
#     (2162, 2167, 'I-LEGISLACAO'),
#     (2168, 2175, 'I-LEGISLACAO'),
#     (2179, 2180, 'B-TEMPO'),
#     (2181, 2183, 'I-TEMPO'),
#     (2184, 2191, 'I-TEMPO'),
#     (2192, 2194, 'I-TEMPO'),
#     (2195, 2199, 'I-TEMPO'),
#     (2254, 2256, 'B-TEMPO'),
#     (2257, 2259, 'I-TEMPO'),
#     (2260, 2267, 'I-TEMPO'),
#     (2268, 2270, 'I-TEMPO'),
#     (2271, 2275, 'I-TEMPO'),
#     (2466, 2468, 'B-ORGANIZACAO'),
#     (2469, 2478, 'I-ORGANIZACAO'),
#     (2479, 2481, 'I-ORGANIZACAO'),
#     (2482, 2484, 'I-ORGANIZACAO'),
#     (2485, 2488, 'I-ORGANIZACAO'),
#     (2700, 2701, 'B-LEGISLACAO'),
#     (2702, 2704, 'I-LEGISLACAO'),
#     (2705, 2707, 'I-LEGISLACAO'),
#     (2708, 2714, 'I-LEGISLACAO'),
#     (2715, 2717, 'I-LEGISLACAO'),
#     (2718, 2720, 'I-LEGISLACAO'),
#     (2721, 2730, 'I-LEGISLACAO'),
#     (2731, 2733, 'I-LEGISLACAO'),
#     (2734, 2737, 'I-LEGISLACAO'),
#     (2743, 2745, 'B-TEMPO'),
#     (2746, 2748, 'I-TEMPO'),
#     (2749, 2756, 'I-TEMPO'),
#     (2757, 2759, 'I-TEMPO'),
#     (2760, 2764, 'I-TEMPO'),
#     (2773, 2781, 'B-ORGANIZACAO'),
#     (2782, 2790, 'I-ORGANIZACAO'),
#     (2791, 2798, 'I-ORGANIZACAO'),
#     (2840, 2850, 'B-PESSOA'),
#     (2851, 2858, 'I-PESSOA'),
#     (2859, 2864, 'I-PESSOA'),
#     (2887, 2897, 'B-TEMPO'),
#     (3049, 3059, 'B-ORGANIZACAO'),
#     (3060, 3067, 'I-ORGANIZACAO'),
#     (3068, 3070, 'I-ORGANIZACAO'),
#     (3071, 3076, 'I-ORGANIZACAO'),
#     (3793, 3794, 'B-TEMPO'),
#     (3795, 3797, 'I-TEMPO'),
#     (3798, 3807, 'I-TEMPO'),
#     (3808, 3810, 'I-TEMPO'),
#     (3811, 3815, 'I-TEMPO'),
#     (3994, 4012, 'B-ORGANIZACAO'),
#     (4013, 4015, 'I-ORGANIZACAO'),
#     (4016, 4023, 'I-ORGANIZACAO'),
#     (4024, 4031, 'I-ORGANIZACAO'),
#     (4046, 4047, 'B-LEGISLACAO'),
#     (4048, 4050, 'I-LEGISLACAO'),
#     (4051, 4053, 'I-LEGISLACAO'),
#     (4054, 4060, 'I-LEGISLACAO'),
#     (4061, 4064, 'I-LEGISLACAO'),
#     (4065, 4067, 'I-LEGISLACAO'),
#     (4068, 4072, 'I-LEGISLACAO'),
#     (4077, 4079, 'B-ORGANIZACAO'),
#     (4080, 4089, 'I-ORGANIZACAO'),
#     (4090, 4092, 'I-ORGANIZACAO'),
#     (4093, 4095, 'I-ORGANIZACAO'),
# ...
#     (17813, 17816, 'B-LOCAL'),
#     (17817, 17822, 'I-LOCAL'),
#     (17867, 17870, 'B-LOCAL'),
#     (17871, 17879, 'I-LOCAL'),
#     (17897, 17902, 'B-JURISPRUDENCIA'),
#     (17903, 17906, 'I-JURISPRUDENCIA'),
#     (17907, 17932, 'I-JURISPRUDENCIA'),
#     (18597, 18600, 'B-LEGISLACAO'),
#     (18601, 18602, 'I-LEGISLACAO'),
#     (18603, 18606, 'I-LEGISLACAO'),
#     (18607, 18608, 'I-LEGISLACAO'),
#     (18609, 18611, 'I-LEGISLACAO'),
#     (18612, 18613, 'I-LEGISLACAO'),
#     (18614, 18616, 'I-LEGISLACAO'),
#     (18617, 18620, 'I-LEGISLACAO'),
#     (18666, 18674, 'B-ORGANIZACAO'),
#     (18675, 18683, 'I-ORGANIZACAO'),
#     (18684, 18686, 'I-ORGANIZACAO'),
#     (18687, 18694, 'I-ORGANIZACAO'),
#     (19066, 19074, 'B-LEGISLACAO'),
#     (19260, 19263, 'B-LEGISLACAO'),
#     (19264, 19265, 'I-LEGISLACAO'),
#     (19266, 19268, 'I-LEGISLACAO'),
#     (19269, 19270, 'I-LEGISLACAO'),
#     (19271, 19273, 'I-LEGISLACAO'),
#     (19274, 19275, 'I-LEGISLACAO'),
#     (19276, 19278, 'I-LEGISLACAO'),
#     (19279, 19280, 'I-LEGISLACAO'),
#     (19281, 19284, 'I-LEGISLACAO'),
#     (19285, 19286, 'I-LEGISLACAO'),
#     (19287, 19290, 'I-LEGISLACAO'),
#     (19291, 19293, 'I-LEGISLACAO'),
#     (19294, 19297, 'I-LEGISLACAO'),
#     (19440, 19446, 'B-ORGANIZACAO'),
#     (19540, 19546, 'B-LOCAL'),
#     (19547, 19549, 'I-LOCAL'),
#     (19550, 19554, 'I-LOCAL'),
#     (19555, 19562, 'B-ORGANIZACAO'),
#     (19563, 19569, 'I-ORGANIZACAO'),
#     (19570, 19575, 'I-ORGANIZACAO'),
#     (19590, 19593, 'B-LOCAL'),
#     (19594, 19602, 'I-LOCAL'),
#     (19603, 19605, 'I-LOCAL'),
#     (19606, 19613, 'I-LOCAL'),
#     (19622, 19625, 'B-LOCAL'),
#     (19626, 19631, 'I-LOCAL'),
#     (19676, 19679, 'B-LOCAL'),
#     (19680, 19688, 'I-LOCAL'),
#     (19706, 19711, 'B-JURISPRUDENCIA'),
#     (19712, 19715, 'I-JURISPRUDENCIA'),
#     (19716, 19741, 'I-JURISPRUDENCIA'),
#     (19891, 19895, 'B-JURISPRUDENCIA'),
#     (19896, 19906, 'I-JURISPRUDENCIA'),
#     (19924, 19930, 'B-PESSOA'),
#     (19931, 19939, 'I-PESSOA'),
#     (19942, 19949, 'B-ORGANIZACAO'),
#     (19950, 19955, 'I-ORGANIZACAO'),
#     (19969, 19979, 'B-TEMPO'),
#     (19986, 19996, 'B-TEMPO'),
#     (20103, 20106, 'B-LEGISLACAO'),
#     (20107, 20108, 'I-LEGISLACAO'),
#     (20109, 20112, 'I-LEGISLACAO'),
#     (20113, 20114, 'I-LEGISLACAO'),
#     (20115, 20117, 'I-LEGISLACAO'),
#     (20118, 20120, 'I-LEGISLACAO'),
#     (20121, 20124, 'I-LEGISLACAO'),
#     (20165, 20168, 'B-LEGISLACAO'),
#     (20169, 20170, 'I-LEGISLACAO'),
#     (20171, 20174, 'I-LEGISLACAO'),
#     (20175, 20177, 'I-LEGISLACAO'),
#     (20178, 20181, 'I-LEGISLACAO'),
#     (20271, 20277, 'B-JURISPRUDENCIA'),
#     (20278, 20285, 'I-JURISPRUDENCIA'),
#     (20298, 20301, 'B-LEGISLACAO'),
#     (20302, 20303, 'I-LEGISLACAO'),
#     (20304, 20307, 'I-LEGISLACAO'),
#     (20308, 20310, 'I-LEGISLACAO'),
#     (20311, 20314, 'I-LEGISLACAO'),
#     (20580, 20590, 'B-JURISPRUDENCIA'),
#     (20605, 20611, 'B-PESSOA'),
#     (20612, 20620, 'I-PESSOA'),
#     (20627, 20637, 'B-TEMPO'),
#     (20640, 20642, 'B-JURISPRUDENCIA'),
#     (20643, 20651, 'I-JURISPRUDENCIA'),
#     (20666, 20670, 'B-PESSOA'),
#     (20671, 20677, 'I-PESSOA'),
#     (20678, 20685, 'I-PESSOA'),
#     (20692, 20700, 'B-TEMPO'),
#     (21046, 21055, 'B-ORGANIZACAO'),
#     (21056, 21064, 'I-ORGANIZACAO'),
#     (21065, 21067, 'I-ORGANIZACAO'),
#     (21068, 21076, 'I-ORGANIZACAO'),
#     (21077, 21081, 'I-ORGANIZACAO'),
#     (21097, 21101, 'B-JURISPRUDENCIA'),
#     (21102, 21104, 'I-JURISPRUDENCIA'),
#     (21105, 21109, 'I-JURISPRUDENCIA'),
#     (21110, 21120, 'I-JURISPRUDENCIA'),
#     (21138, 21146, 'B-PESSOA'),
#     (21147, 21152, 'I-PESSOA'),
#     (21153, 21157, 'I-PESSOA'),
#     (21158, 21163, 'I-PESSOA'),
#     (21166, 21174, 'B-ORGANIZACAO'),
#     (21175, 21180, 'I-ORGANIZACAO'),
#     (21194, 21204, 'B-TEMPO'),
#     (21211, 21221, 'B-TEMPO'),
#     (21351, 21357, 'B-LOCAL'),
#     (21358, 21360, 'I-LOCAL'),
#     (21361, 21365, 'I-LOCAL'),
#     (21366, 21373, 'B-ORGANIZACAO'),
#     (21374, 21380, 'I-ORGANIZACAO'),
#     (21381, 21386, 'I-ORGANIZACAO'),
#     (21401, 21404, 'B-LOCAL'),
#     (21405, 21413, 'I-LOCAL'),
#     (21414, 21416, 'I-LOCAL'),
#     (21417, 21424, 'I-LOCAL'),
#     (21433, 21436, 'B-LOCAL'),
#     (21437, 21442, 'I-LOCAL'),
#     (21487, 21490, 'B-LOCAL'),
#     (21491, 21499, 'I-LOCAL'),
#     (21517, 21522, 'B-JURISPRUDENCIA'),
#     (21523, 21526, 'I-JURISPRUDENCIA'),
#     (21527, 21552, 'I-JURISPRUDENCIA'),
#     (22045, 22048, 'B-LEGISLACAO'),
#     (22049, 22050, 'I-LEGISLACAO'),
#     (22051, 22054, 'I-LEGISLACAO'),
#     (22055, 22056, 'I-LEGISLACAO'),
#     (22057, 22058, 'I-LEGISLACAO'),
#     (22059, 22061, 'I-LEGISLACAO'),
#     (22062, 22063, 'I-LEGISLACAO'),
#     (22064, 22066, 'I-LEGISLACAO'),
#     (22067, 22068, 'I-LEGISLACAO'),
#     (22069, 22071, 'I-LEGISLACAO'),
#     (22072, 22076, 'I-LEGISLACAO'),
#     (23037, 23043, 'B-LOCAL'),
#     (23044, 23046, 'I-LOCAL'),
#     (23047, 23051, 'I-LOCAL'),
#     (23052, 23059, 'B-ORGANIZACAO'),
#     (23060, 23066, 'I-ORGANIZACAO'),
#     (23067, 23072, 'I-ORGANIZACAO'),
#     (23087, 23090, 'B-LOCAL'),
#     (23091, 23099, 'I-LOCAL'),
#     (23100, 23102, 'I-LOCAL'),
#     (23103, 23110, 'I-LOCAL'),
#     (23119, 23122, 'B-LOCAL'),
#     (23123, 23128, 'I-LOCAL'),
#     (23173, 23176, 'B-LOCAL'),
#     (23177, 23185, 'I-LOCAL'),
#     (23203, 23208, 'B-JURISPRUDENCIA'),
#     (23209, 23212, 'I-JURISPRUDENCIA'),
#     (23213, 23238, 'I-JURISPRUDENCIA'),
#     (24261, 24264, 'B-ORGANIZACAO'),
#     (24757, 24763, 'B-LOCAL'),
#     (24764, 24766, 'I-LOCAL'),
#     (24767, 24771, 'I-LOCAL'),
#     (24772, 24779, 'B-ORGANIZACAO'),
#     (24780, 24786, 'I-ORGANIZACAO'),
#     (24787, 24792, 'I-ORGANIZACAO'),
#     (24807, 24810, 'B-LOCAL'),
#     (24811, 24819, 'I-LOCAL'),
#     (24820, 24822, 'I-LOCAL'),
#     (24823, 24830, 'I-LOCAL'),
#     (24839, 24842, 'B-LOCAL'),
#     (24843, 24848, 'I-LOCAL'),
#     (24893, 24896, 'B-LOCAL'),
#     (24897, 24905, 'I-LOCAL'),
#     (24923, 24928, 'B-JURISPRUDENCIA'),
#     (24929, 24932, 'I-JURISPRUDENCIA'),
#     (24933, 24958, 'I-JURISPRUDENCIA'),
#     (25254, 25258, 'B-JURISPRUDENCIA'),
#     (25259, 25261, 'I-JURISPRUDENCIA'),
#     (25262, 25267, 'I-JURISPRUDENCIA'),
#     (25268, 25278, 'I-JURISPRUDENCIA'),
#     (25296, 25303, 'B-PESSOA'),
#     (25304, 25310, 'I-PESSOA'),
#     (25311, 25315, 'I-PESSOA'),
#     (25316, 25321, 'I-PESSOA'),
#     (25324, 25332, 'B-ORGANIZACAO'),
#     (25333, 25338, 'I-ORGANIZACAO'),
#     (25352, 25362, 'B-TEMPO'),
#     (25369, 25379, 'B-TEMPO'),
#     (25755, 25759, 'B-JURISPRUDENCIA'),
#     (25760, 25762, 'I-JURISPRUDENCIA'),
#     (25763, 25767, 'I-JURISPRUDENCIA'),
#     (25768, 25778, 'I-JURISPRUDENCIA'),
#     (25796, 25800, 'B-PESSOA'),
#     (25801, 25807, 'I-PESSOA'),
#     (25808, 25815, 'I-PESSOA'),
#     (25818, 25824, 'B-ORGANIZACAO'),
#     (25825, 25830, 'I-ORGANIZACAO'),
#     (25844, 25854, 'B-TEMPO'),
#     (25861, 25871, 'B-TEMPO'),
#     (26393, 26399, 'B-LOCAL'),
#     (26400, 26402, 'I-LOCAL'),
#     (26403, 26407, 'I-LOCAL'),
#     (26408, 26415, 'B-ORGANIZACAO'),
#     (26416, 26422, 'I-ORGANIZACAO'),
#     (26423, 26428, 'I-ORGANIZACAO'),
#     (26443, 26446, 'B-LOCAL'),
#     (26447, 26455, 'I-LOCAL'),
#     (26456, 26458, 'I-LOCAL'),
#     (26459, 26466, 'I-LOCAL'),
#     (26475, 26478, 'B-LOCAL'),
#     (26479, 26484, 'I-LOCAL'),
#     (26529, 26532, 'B-LOCAL'),
#     (26533, 26541, 'I-LOCAL'),
#     (26559, 26564, 'B-JURISPRUDENCIA'),
#     (26565, 26568, 'I-JURISPRUDENCIA'),
#     (26569, 26594, 'I-JURISPRUDENCIA'),
#     (26660, 26668, 'B-ORGANIZACAO'),
#     (26669, 26671, 'I-ORGANIZACAO'),
#     (26672, 26679, 'I-ORGANIZACAO'),
#     (26680, 26682, 'I-ORGANIZACAO'),
#     (26683, 26688, 'I-ORGANIZACAO'),
#     (26689, 26695, 'I-ORGANIZACAO'),
#     (26916, 26919, 'B-LEGISLACAO'),
#     (26920, 26921, 'I-LEGISLACAO'),
#     (26922, 26924, 'I-LEGISLACAO'),
#     (26925, 26926, 'I-LEGISLACAO'),
#     (26927, 26928, 'I-LEGISLACAO'),
#     (26929, 26931, 'I-LEGISLACAO'),
#     (26932, 26933, 'I-LEGISLACAO'),
#     (26934, 26937, 'I-LEGISLACAO'),
#     (27277, 27280, 'B-ORGANIZACAO'),
#     (27324, 27327, 'B-LEGISLACAO'),
#     (27415, 27425, 'B-LEGISLACAO'),
#     (27433, 27437, 'B-JURISPRUDENCIA'),
#     (27438, 27440, 'I-JURISPRUDENCIA'),
#     (27441, 27446, 'I-JURISPRUDENCIA'),
#     (27447, 27456, 'I-JURISPRUDENCIA'),
#     (27474, 27481, 'B-PESSOA'),
#     (27482, 27488, 'I-PESSOA'),
#     (27489, 27497, 'I-PESSOA'),
#     (27504, 27508, 'B-ORGANIZACAO'),
#     (27511, 27519, 'B-JURISPRUDENCIA'),
#     (27520, 27525, 'I-JURISPRUDENCIA'),
#     (27526, 27548, 'I-JURISPRUDENCIA'),
#     (27579, 27590, 'B-PESSOA'),
#     (27591, 27595, 'I-PESSOA'),
#     (27598, 27601, 'B-ORGANIZACAO'),
#     (27602, 27608, 'I-ORGANIZACAO'),
#     (27609, 27614, 'I-ORGANIZACAO'),
#     (27631, 27641, 'B-TEMPO'),
#     (27668, 27678, 'B-TEMPO'),
#     (28117, 28123, 'B-LOCAL'),
#     (28124, 28126, 'I-LOCAL'),
#     (28127, 28131, 'I-LOCAL'),
#     (28132, 28139, 'B-ORGANIZACAO'),
#     (28140, 28146, 'I-ORGANIZACAO'),
#     (28147, 28152, 'I-ORGANIZACAO'),
#     (28167, 28170, 'B-LOCAL'),
#     (28171, 28179, 'I-LOCAL'),
#     (28180, 28182, 'I-LOCAL'),
#     (28183, 28190, 'I-LOCAL'),
#     (28199, 28202, 'B-LOCAL'),
#     (28203, 28208, 'I-LOCAL'),
#     (28253, 28256, 'B-LOCAL'),
#     (28257, 28265, 'I-LOCAL'),
#     (28283, 28288, 'B-JURISPRUDENCIA'),
#     (28289, 28292, 'I-JURISPRUDENCIA'),
#     (28293, 28318, 'I-JURISPRUDENCIA'),
#     (28645, 28651, 'B-LEGISLACAO'),
#     (28652, 28655, 'I-LEGISLACAO'),
#     (28656, 28658, 'I-LEGISLACAO'),
#     (28659, 28665, 'I-LEGISLACAO'),
#     (28666, 28671, 'I-LEGISLACAO'),
#     (29715, 29718, 'B-LEGISLACAO'),
#     (29719, 29720, 'I-LEGISLACAO'),
#     (29721, 29724, 'I-LEGISLACAO'),
#     (29725, 29726, 'I-LEGISLACAO'),
#     (29727, 29729, 'I-LEGISLACAO'),
#     (29730, 29737, 'I-LEGISLACAO'),
#     (29760, 29766, 'B-LOCAL'),
#     (29767, 29769, 'I-LOCAL'),
#     (29770, 29774, 'I-LOCAL'),
#     (29775, 29782, 'B-ORGANIZACAO'),
#     (29783, 29789, 'I-ORGANIZACAO'),
#     (29790, 29795, 'I-ORGANIZACAO'),
#     (29810, 29813, 'B-LOCAL'),
#     (29814, 29822, 'I-LOCAL'),
#     (29823, 29825, 'I-LOCAL'),
#     (29826, 29833, 'I-LOCAL'),
#     (29842, 29845, 'B-LOCAL'),
#     (29846, 29851, 'I-LOCAL'),
#     (29896, 29899, 'B-LOCAL'),
#     (29900, 29908, 'I-LOCAL'),
#     (29926, 29931, 'B-JURISPRUDENCIA'),
#     (29932, 29935, 'I-JURISPRUDENCIA'),
#     (29936, 29961, 'I-JURISPRUDENCIA'),
#     (30033, 30041, 'B-ORGANIZACAO'),
#     (30042, 30044, 'I-ORGANIZACAO'),
#     (30045, 30052, 'I-ORGANIZACAO'),
#     (30053, 30055, 'I-ORGANIZACAO'),
#     (30056, 30061, 'I-ORGANIZACAO'),
#     (30062, 30068, 'I-ORGANIZACAO'),
#     (30508, 30511, 'B-LEGISLACAO'),
#     (30512, 30513, 'I-LEGISLACAO'),
#     (30514, 30517, 'I-LEGISLACAO'),
#     (30518, 30520, 'I-LEGISLACAO'),
#     (30521, 30523, 'I-LEGISLACAO'),
#     (30889, 30893, 'B-ORGANIZACAO'),
#     (30894, 30902, 'B-JURISPRUDENCIA'),
#     (30903, 30908, 'I-JURISPRUDENCIA'),
#     (30909, 30931, 'I-JURISPRUDENCIA'),
#     (30962, 30968, 'B-PESSOA'),
#     (30969, 30974, 'I-PESSOA'),
#     (30975, 30982, 'I-PESSOA'),
#     (30985, 30988, 'B-ORGANIZACAO'),
#     (30989, 30995, 'I-ORGANIZACAO'),
#     (30996, 31001, 'I-ORGANIZACAO'),
#     (31018, 31028, 'B-TEMPO'),
#     (31055, 31065, 'B-TEMPO'),
#     (31350, 31356, 'B-LOCAL'),
#     (31357, 31359, 'I-LOCAL'),
#     (31360, 31364, 'I-LOCAL'),
#     (31365, 31372, 'B-ORGANIZACAO'),
#     (31373, 31379, 'I-ORGANIZACAO'),
#     (31380, 31385, 'I-ORGANIZACAO'),
#     (31400, 31403, 'B-LOCAL'),
#     (31404, 31412, 'I-LOCAL'),
#     (31413, 31415, 'I-LOCAL'),
#     (31416, 31423, 'I-LOCAL'),
#     (31432, 31435, 'B-LOCAL'),
#     (31436, 31441, 'I-LOCAL'),
#     (31486, 31489, 'B-LOCAL'),
#     (31490, 31498, 'I-LOCAL'),
#     (31516, 31521, 'B-JURISPRUDENCIA'),
#     (31522, 31525, 'I-JURISPRUDENCIA'),
#     (31526, 31551, 'I-JURISPRUDENCIA'),
#     (31577, 31580, 'B-LEGISLACAO'),
#     (31581, 31582, 'I-LEGISLACAO'),
#     (31583, 31585, 'I-LEGISLACAO'),
#     (31586, 31587, 'I-LEGISLACAO'),
#     (31588, 31597, 'I-LEGISLACAO'),
#     (31598, 31603, 'I-LEGISLACAO'),
#     (31604, 31605, 'I-LEGISLACAO'),
#     (31606, 31608, 'I-LEGISLACAO'),
#     (31609, 31613, 'I-LEGISLACAO'),
#     (31762, 31770, 'B-ORGANIZACAO'),
#     (31771, 31779, 'I-ORGANIZACAO'),
#     (31780, 31782, 'I-ORGANIZACAO'),
#     (31783, 31790, 'I-ORGANIZACAO'),
#     (32293, 32296, 'B-LEGISLACAO'),
#     (32297, 32298, 'I-LEGISLACAO'),
#     (32299, 32302, 'I-LEGISLACAO'),
#     (32303, 32305, 'I-LEGISLACAO'),
#     (32306, 32309, 'I-LEGISLACAO'),
#     (32621, 32624, 'B-LEGISLACAO'),
#     (32625, 32626, 'I-LEGISLACAO'),
#     (32627, 32630, 'I-LEGISLACAO'),
#     (32631, 32632, 'I-LEGISLACAO'),
#     (32633, 32635, 'I-LEGISLACAO'),
#     (32636, 32637, 'I-LEGISLACAO'),
#     (32638, 32640, 'I-LEGISLACAO'),
#     (32641, 32644, 'I-LEGISLACAO'),
#     (32676, 32681, 'B-ORGANIZACAO'),
#     (32682, 32690, 'I-ORGANIZACAO'),
#     (32691, 32693, 'I-ORGANIZACAO'),
#     (32694, 32697, 'I-ORGANIZACAO'),
#     (32810, 32816, 'B-LEGISLACAO'),
#     (32817, 32819, 'I-LEGISLACAO'),
#     (32820, 32821, 'I-LEGISLACAO'),
#     (32822, 32831, 'I-LEGISLACAO'),
#     (32832, 32834, 'I-LEGISLACAO'),
#     (32835, 32836, 'I-LEGISLACAO'),
#     (32837, 32839, 'I-LEGISLACAO'),
#     (32840, 32846, 'I-LEGISLACAO'),
#     (32847, 32849, 'I-LEGISLACAO'),
#     (32850, 32858, 'I-LEGISLACAO'),
#     (32859, 32864, 'I-LEGISLACAO'),
#     (33264, 33270, 'B-LOCAL'),
#     (33271, 33273, 'I-LOCAL'),
#     (33274, 33278, 'I-LOCAL'),
#     (33279, 33286, 'B-ORGANIZACAO'),
#     (33287, 33293, 'I-ORGANIZACAO'),
#     (33294, 33299, 'I-ORGANIZACAO'),
#     (33314, 33317, 'B-LOCAL'),
#     (33318, 33326, 'I-LOCAL'),
#     (33327, 33329, 'I-LOCAL'),
#     (33330, 33337, 'I-LOCAL'),
#     (33346, 33349, 'B-LOCAL'),
#     (33350, 33355, 'I-LOCAL'),
#     (33400, 33403, 'B-LOCAL'),
#     (33404, 33412, 'I-LOCAL'),
#     (33430, 33435, 'B-JURISPRUDENCIA'),
#     (33436, 33439, 'I-JURISPRUDENCIA'),
#     (33440, 33465, 'I-JURISPRUDENCIA'),
#     (33688, 33691, 'B-ORGANIZACAO'),
#     (34023, 34027, 'B-JURISPRUDENCIA'),
#     (34028, 34038, 'I-JURISPRUDENCIA'),
#     (34053, 34058, 'B-PESSOA'),
#     (34059, 34067, 'I-PESSOA'),
#     (34070, 34072, 'B-ORGANIZACAO'),
#     (34073, 34078, 'I-ORGANIZACAO'),
#     (34085, 34095, 'B-TEMPO'),
#     (34944, 34950, 'B-LOCAL'),
#     (34951, 34953, 'I-LOCAL'),
#     (34954, 34958, 'I-LOCAL'),
#     (34959, 34966, 'B-ORGANIZACAO'),
#     (34967, 34973, 'I-ORGANIZACAO'),
#     (34974, 34979, 'I-ORGANIZACAO'),
#     (34994, 34997, 'B-LOCAL'),
#     (34998, 35006, 'I-LOCAL'),
#     (35007, 35009, 'I-LOCAL'),
#     (35010, 35017, 'I-LOCAL'),
#     (35026, 35029, 'B-LOCAL'),
#     (35030, 35035, 'I-LOCAL'),
#     (35080, 35083, 'B-LOCAL'),
#     (35084, 35092, 'I-LOCAL'),
#     (35110, 35115, 'B-JURISPRUDENCIA'),
#     (35116, 35119, 'I-JURISPRUDENCIA'),
#     (35120, 35145, 'I-JURISPRUDENCIA'),
#     (35670, 35673, 'B-LEGISLACAO'),
#     (35674, 35675, 'I-LEGISLACAO'),
#     (35676, 35678, 'I-LEGISLACAO'),
#     (35679, 35680, 'I-LEGISLACAO'),
#     (35681, 35690, 'I-LEGISLACAO'),
#     (35691, 35696, 'I-LEGISLACAO'),
#     (35697, 35698, 'I-LEGISLACAO'),
#     (35699, 35701, 'I-LEGISLACAO'),
#     (35702, 35705, 'I-LEGISLACAO'),
#     (36431, 36437, 'B-LOCAL'),
#     (36438, 36440, 'I-LOCAL'),
#     (36441, 36445, 'I-LOCAL'),
#     (36446, 36453, 'B-ORGANIZACAO'),
#     (36454, 36460, 'I-ORGANIZACAO'),
#     (36461, 36466, 'I-ORGANIZACAO'),
#     (36481, 36484, 'B-LOCAL'),
#     (36485, 36493, 'I-LOCAL'),
#     (36494, 36496, 'I-LOCAL'),
#     (36497, 36504, 'I-LOCAL'),
#     (36513, 36516, 'B-LOCAL'),
#     (36517, 36522, 'I-LOCAL'),
#     (36567, 36570, 'B-LOCAL'),
#     (36571, 36579, 'I-LOCAL'),
#     (36597, 36602, 'B-JURISPRUDENCIA'),
#     (36603, 36606, 'I-JURISPRUDENCIA'),
#     (36607, 36632, 'I-JURISPRUDENCIA'),
#     (37208, 37211, 'B-LEGISLACAO'),
#     (37212, 37213, 'I-LEGISLACAO'),
#     (37214, 37216, 'I-LEGISLACAO'),
#     (37217, 37218, 'I-LEGISLACAO'),
#     (37219, 37220, 'I-LEGISLACAO'),
#     (37221, 37223, 'I-LEGISLACAO'),
#     (37224, 37225, 'I-LEGISLACAO'),
#     (37226, 37228, 'I-LEGISLACAO'),
#     (37229, 37232, 'I-LEGISLACAO'),
#     (37475, 37482, 'B-ORGANIZACAO'),
#     (37483, 37489, 'I-ORGANIZACAO'),
#     (37490, 37495, 'I-ORGANIZACAO'),
#     (37670, 37677, 'B-PESSOA'),
#     (37678, 37684, 'I-PESSOA'),
#     (37714, 37720, 'B-PESSOA'),
#     (37721, 37728, 'I-PESSOA'),
#     (37746, 37750, 'B-PESSOA'),
#     (37751, 37759, 'I-PESSOA'),
#     (37760, 37762, 'I-PESSOA'),
#     (37763, 37774, 'I-PESSOA'),
#     (37775, 37780, 'I-PESSOA')]})]

# %% [markdown]
# # Construindo função de treinamento

# %%
from tqdm import tqdm
from spacy.training import Example

# %%
def treinar_modelo_ner(dados_treino, dados_validacao, epocas):
    # Carrega um modelo pré-treinado da spaCy para o idioma português
    modelo = spacy.load('pt_core_news_sm')
    
    # Verifica se o pipeline de NER já existe no modelo
    if 'ner' not in modelo.pipe_names:
        ner = modelo.create_pipe('ner')  # Cria um novo pipeline de NER
        modelo.add_pipe(ner, last=True)  # Adiciona o pipeline ao modelo
    else:
        ner = modelo.get_pipe('ner')  # Obtém o pipeline de NER existente
    
    # Adiciona rótulos das entidades ao pipeline de NER
    for _, anotacoes in dados_treino:
        for ent in anotacoes.get('entities'):
            ner.add_label(ent[2])
    
    # Desativa outros pipelines para treinar apenas o NER
    outros_pipelines = [pipeline for pipeline in modelo.pipe_names if pipeline != 'ner']
    with modelo.disable_pipes(*outros_pipelines):
        
        # Define uma semente para garantir reprodutibilidade nos resultados
        spacy.util.fix_random_seed()
        
        # Cria um otimizador para o modelo
        otimizador = modelo.create_optimizer()
        
        # Loop de treinamento por número de épocas
        for epoca in tqdm(range(epocas), desc='Treinando o modelo'):
            
            random.seed(10)  # Define semente para aleatoriedade controlada
            random.shuffle(dados_treino)  # Embaralha os dados de treinamento
            losses = {'ner': 0.0}  # Inicializa a variável de perda do modelo
            
            # Treina o modelo com os dados de treinamento
            for textos, anotacoes in dados_treino:
                exemplo = Example.from_dict(modelo.make_doc(textos), anotacoes)  # Cria um exemplo para treinamento
                modelo.update([exemplo], drop=0.2, sgd=otimizador, losses=losses)  # Atualiza o modelo
            
            # Exibe a perda média por amostra na época atual
            print(f'\nÉpoca {epoca+1} - Loss médio de treino: {losses["ner"] / len(dados_treino)}')
            
            # Inicializa a perda de validação
            val_losses = {'ner': 0.0}
            exemplos = []
            
            # Cria exemplos de validação
            for textos, anotacoes in dados_validacao:
                exemplo = Example.from_dict(modelo.make_doc(textos), anotacoes)
                exemplos.append(exemplo)
            
            # Avalia o modelo nos dados de validação
            for exemplo in exemplos:
                modelo.update([exemplo], sgd=None, drop=0, losses=val_losses)
            
            # Exibe a perda média de validação na época atual
            print(f'\nÉpoca {epoca+1} - Loss médio de validação: {val_losses["ner"] / len(dados_validacao)}')
    
    return modelo

# %% [markdown]
# **Treinando e salvando o modelo**

# %%
modelo_ner = treinar_modelo_ner(dados_treino, dados_validacao, epocas = 30)

# %%
modelo_ner.to_disk('/content/modelo')

# %%
# !zip -r /content/modelo.zip /content/modelo

# %% [markdown]
# # Carregando e testando o modelo

# %%
# !unzip /content/modelo.zip

# %%
modelo_ner = spacy.load('/content/content/modelo')

# %%
doc = modelo_ner('João nasceu no dia 10/04/2010 em Florianópolis')

# %%
for entidade in doc.ents:
    print(f'{entidade.text} -> {entidade.label_}')
# Out:
# João -> B-PESSOA
# 10/04/2010 -> B-TEMPO
# Florianópolis -> B-LOCAL

# %%
spacy.displacy.render(doc, style = 'ent', jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     João
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PESSOA</span>
# </mark>
#  nasceu no dia
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10/04/2010
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-TEMPO</span>
# </mark>
#  em
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Florianópolis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-LOCAL</span>
# </mark>
# </div></span>

# %%
with open('/content/20150110436469APC.txt', encoding = 'utf-8') as arquivo:
    texto = arquivo.read()

# %%
# print(texto)

# %%
doc = modelo_ner(texto)

spacy.displacy.render(doc, style = 'ent', jupyter = True)

# %% [markdown]
# **Alterando a visualização das cores**

# %%
rotulos = list(modelo_ner.get_pipe('ner').labels)
rotulos
# Out:
# ['B-JURISPRUDENCIA',
#  'B-LEGISLACAO',
#  'B-LOCAL',
#  'B-ORGANIZACAO',
#  'B-PESSOA',
#  'B-TEMPO',
#  'I-JURISPRUDENCIA',
#  'I-LEGISLACAO',
#  'I-LOCAL',
#  'I-ORGANIZACAO',
#  'I-PESSOA',
#  'I-TEMPO',
#  'LOC',
#  'MISC',
#  'ORG',
#  'PER']

# %% [markdown]
# Cores:
#
# - Azul: #F0F8FF
# - Vermelho: #FA8072
# - Verde: #98FB98
# - Roxo: #DDA0DD
# - Amarelo: #F0E68C
# - Rosa: #FFB6C1
# - Cinza: #D3D3D3

# %%
cores = {
'B-JURISPRUDENCIA': '#F0F8FF',
 'B-LEGISLACAO': '#FA8072',
 'B-LOCAL': '#98FB98',
 'B-ORGANIZACAO': '#DDA0DD',
 'B-PESSOA': '#F0E68C',
 'B-TEMPO': '#FFB6C1',
 'I-JURISPRUDENCIA': '#F0F8FF',
 'I-LEGISLACAO': '#FA8072',
 'I-LOCAL': '#98FB98',
 'I-ORGANIZACAO': '#DDA0DD',
 'I-PESSOA': '#F0E68C',
 'I-TEMPO': '#FFB6C1',
 'LOC': '#D3D3D3',
 'MISC': '#D3D3D3',
 'ORG': '#D3D3D3',
 'PER': '#D3D3D3'
}
opcoes = {'ents': rotulos, 'colors': cores}
spacy.displacy.render(doc, style = 'ent', jupyter = True, options = opcoes)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">E M E N T A<br>Poder Judiciário da União<br>
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TRIBUNAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JUSTIÇA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DISTRITO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #98FB98; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FEDERAL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOCAL</span>
# </mark>
#  E TERRITÓRIOS Fls. _____<br>Órgão :
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8ª
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TURMA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CÍVEL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
# <br>Classe : APELAÇÃO CÍVEL<br>N. Processo :
# <mark class="entity" style="background: #F0F8FF; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20150110436469APC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-JURISPRUDENCIA</span>
# </mark>
# <br>(
# <mark class="entity" style="background: #FFB6C1; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0012843-03.2015.8.07.0001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-TEMPO</span>
# </mark>
# )<br>Apelante(s) :
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BRASILIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CURSOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     E
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CONCURSOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
#
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LTDA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORGANIZACAO</span>
# </mark>
# <br>GRANCURSOS ESCOLA PARA<br>
# <mark class="entity" style="background: #DDA0DD; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CONCURSOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORGANIZACAO</span>
# </mark>
#  PUBLICOS LTDA<br>Apelado(s) :
# <mark class="entity" style="background: #F0E68C; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ALISSON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #F0E68C; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SILVA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #F0E68C; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BATISTA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #F0E68C; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #F0E68C; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MORAES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PESSOA</span>
# </mark>
# <br>Relatora : Desembargadora
# <mark class="entity" style="background: #F0E68C; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NÍDIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #F0E68C; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CORRÊA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PESSOA</span>
# </mark>
#
# <mark class="entity" style="background: #F0E68C; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LIMA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; v
